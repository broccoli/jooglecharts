# %% [markdown]
# # Custom Filters
# In addition to the filters documented in Google Charts, JoogleCharts provides some custom filters.  The custom filters are typically extensions of the filters provided by Google Charts, so be sure to read about how to use the regular filters in JoogleCharts.

# %%
import pandas as pd
from jooglechart import JoogleChart, Filter, SeriesFilter, SuperCategoryFilter, ChartRow

# import of display functions is not needed for jooglechart
from IPython.display import display, HTML

# %% [markdown]
# ## Series Filter
# JoogleCharts has a custom filter that allows the user to filter on columns of the data, rather than rows.  The data model used in the chart must have a column of categories, followed by columns with data series, as with a line chart or column chart.  If a SeriesFilter is applied to a line chart, for example, lines will appear or disappear as the series of data are selected or deselected.
#
# The SeriesFilter will be most effective with a chart like line chart or ***stacked*** column chart, where series can be toggled on and off without leaving gaps along the axis where the data is now "missing."
#
# The SeriesFilter under the hood is a re-purporsed CategoryFilter, so any options CategoryFilter takes can be applied to SeriesFilter.  However, not all will be relevant; filterColumnLabel and filterColumnIndex cannot be used.
#
# By default, all available series will be selected on rendering.  The filter can be initialized with selections by passing SelectedValues as added filter state.  The default label for the filter is "Columns," which can be overriden with the ui.label filter option.
#
# SeriesFilter can be combined with other types of filters.  In that case, the SeriesFilter will be rendered on top.
#
# SeriesFilter will work even when the view_cols have been set (i.e., where some columns have been hidden), and when columns have been set as roles, including tooltips.

# %%
bradys = ['Bobby', 'Cindy', 'Jan']
snickers = [34, 64, 24]
mounds = [20, 32, 41]
milky_way = [35, 32, 50]
payday = [23, 64, 27]

d = {}
d['Kids'] = bradys
d['Snickers'] = snickers
d['Mounds'] = mounds
d['Milky Way'] = milky_way
d['Payday'] = payday
sf_df = pd.DataFrame(d, columns=['Kids', 'Snickers', 'Mounds', 'Milky Way', 'Payday'])

chart = JoogleChart(sf_df, chart_type="ColumnChart")
chart.add_chart_options(isStacked=True, chartArea_left=40, chartArea_width=600, width=640, legend_position="top")
sf = SeriesFilter()
sf.add_options(ui_label="Candy Bars")
chart.add_filter(sf)
chart.show()
# Out:
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#     // Check if google jsapi is already loaded.  If not, load it.
#     if (typeof window.google == 'undefined') {
#         jQuery.getScript('https://www.google.com/jsapi', function( data, textStatus, jqxhr) {
#             google_loader_1();
#         });
#     } else {
#         google_loader_1();
#     }
#
#     <!-- taken from http://stackoverflow.com/questions/8618464/how-to-wait-for-another-js-to-load-to-proceed-operation/8618519#8618519 -->
#     function whenDivAvailable(name, callback) {
#         var intervalInMs = 10;
#         window.setTimeout(function() {
#             if (window[name]) {
#                 callback();
#             } else {
#                 window.setTimeout(arguments.callee, intervalInMs);
#             }
#
#         }, intervalInMs);
#     }
#
#     // load visualization library
#     function google_loader_1() {
#
#         google.load('visualization', '1.0', {'callback': doStuff_1});
#     }
# });
#
#
#     function doStuff_1() {
#
#
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jooglechart_1_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"Bobby"},{"v":34},{"v":20},{"v":35},{"v":23}]},{"c":[{"v":"Cindy"},{"v":64},{"v":32},{"v":32},{"v":64}]},{"c":[{"v":"Jan"},{"v":24},{"v":41},{"v":50},{"v":27}]}],"cols":[{"type":"string","id":"Kids","label":"Kids"},{"type":"number","id":"Snickers","label":"Snickers"},{"type":"number","id":"Mounds","label":"Mounds"},{"type":"number","id":"Milky Way","label":"Milky Way"},{"type":"number","id":"Payday","label":"Payday"}]});
#
#         // Add formatters, if any
#
#         // Create ChartWrapper
#         var google_chart_2 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_2_div_id",
#             "dataTable": jooglechart_1_data,
#             "chartType": "ColumnChart",
#             "options": {"width": 640, "isStacked": true, "legend": {"position": "top"}, "chartArea": {"width": 600, "left": 40}}
#         });
#
#
#           google_chart_2.draw();
#
#
#
#
#
# 		/*
# 			For the series filter, we will use a category filter.  We
# 			have to create a special DataTable out of the main data column
# 			that will be used by the series filter.
#
# 			The series filter is not bound to data, so it doesn't dirctly
# 			filter any data.  Instead, it triggers a callback to
# 			create a new view for redrawing the chart(s).
# 		*/
#
# 		var series_filter_table = new google.visualization.DataTable({"rows":[{"c":[{"v":"Snickers"}]},{"c":[{"v":"Mounds"}]},{"c":[{"v":"Milky Way"}]},{"c":[{"v":"Payday"}]}],"cols":[{"type":"string","id":"columns","label":"columns"}]});
#
# 	    var google_filter_3 = new google.visualization.ControlWrapper({
# 	      controlType: 'CategoryFilter',
# 	      containerId: 'google_filter_3_div_id',
# 	      dataTable: series_filter_table,
# 	      options: {"ui": {"label": "Candy Bars"}, "filterColumnIndex": 0},
# 	      state: {"selectedValues": ["Snickers", "Mounds", "Milky Way", "Payday"]}
# 	    });
#
# 	    google_filter_3.draw();
#
# 		// pass an array of the series' columns in the orignal datatable from python
# 		// series cols are the viewable, non-role, non-category cols
# 		var series_cols = [1, 2, 3, 4];
#
# 		// initialize the array of dataTable column indices, e.g, [0, 1, 2, etc.]
# 	    var columns = [];
# 	    for (var i = 0; i < jooglechart_1_data.getNumberOfColumns(); i++) {
# 	        columns.push(i);
# 	    }
#
# 		// an object of series properties will be passed to the chart wrapper for setting color
# 	    var series = {};
#
# 		function series_filter_update_chart() {
#
# 			var selectedValues = google_filter_3.getState().selectedValues;
#
# 			// Loop through series cols
# 			for (var i = 0; i < series_cols.length; i++) {
#
# 				// initialize series object
# 				series[i] = {}
#
# 				// get series column index in the original data table
# 				var ix = series_cols[i]
#
# 				// check if series has been selected
# 				var test_val = jooglechart_1_data.getColumnLabel(ix);
# 				if ($.inArray(test_val, selectedValues) >= 0) {
# 					// if the series is selected, just pass the normal column
# 					// and get the default color
# 					columns[ix] = ix;
# 					series[i].color = null;
# 				} else {
#
# 					// create a column object that returns null, hiding the series on the chart
# 	                columns[ix] = {
# 	                    label: jooglechart_1_data.getColumnLabel(ix),
# 	                    type: jooglechart_1_data.getColumnType(ix),
# 	                    calc: function () {
# 	                        return null;
# 	                    }
# 	                };
#
# 					// gray out the series color for the legend
# 					series[i].color = '#CCCCCC';
# 				}
#
# 			}
#
#             var view = new google.visualization.DataView(jooglechart_1_data);
#             view.setColumns(columns);
#
# 				google_chart_2.setDataTable(view);
# 				google_chart_2.setOption('series', series);
# 	            google_chart_2.draw();
#
# 		}
#
# 		/*
# 			including both ready and statechange listeners as hack. The statechange event won't fire
# 			for the SuperCategoryFilter but the ready event will.
# 		*/
# 	    google.visualization.events.addListener(google_filter_3, 'ready', series_filter_update_chart);
# 	    google.visualization.events.addListener(google_filter_3, 'statechange', series_filter_update_chart);
# 		series_filter_update_chart();
#
#     }
#
# </script>
#
# <noscript>
# </noscript>
#
# <style>
#
# /*
# 	Setting overflow: scroll prevents buggy behavior in CategoryFilter dropdown
# 	that occurs when the list of menu options is very long.
# */
# .charts-menu {
#     overflow: scroll;
#     max-height: 250px;
# }
# </style>
# <div id="google_filter_3_div_id"></div>
#
#
# <div id="google_chart_2_div_id" ></div>

# %% [markdown]
# ## SuperCategoryFilter
# The SuperCategoryFilter is a category filter that can control the category filters of distinct JoogleCharts.  At times, you might have different data sets that you want to chart, but you want to control them with one filter.  The SuperCategoryFilter will allow you to do that if you have applied Category Filters to the charts.  To work predictably, the categories in the data sets should be the same.
#
# There are several steps that must be taken to apply a SuperCategoryFilter.  First, you must instantiate the SuperCategoryFilter with a list or pandas Series of options that will appear in the filter.  Next, you must add to the SuperCategoryFilter labels for the filters that it will control.  Lastly, you must give those filters the same labels that were added to the SuperCategoryFilter.  The labels are used to create names for the filters.
#
# Normally, you don't need to worry about the names that will be used in the javascript and html with jooglechart.  The SuperCategoryFilter is different, because the components involved will all be rendered separately, and the names must match across the rendered scripts.  Note:  **you must give the controlled filters different labels to avoid collision.**
#
# #### Applying options and state
# As a repurposed Category Filter, the SuperCategoryFilter can take the same options and state as a Category Filter.  The filterColumnIndex cannot be set, however.
#
# It is recommended that if selectedValues are to be added to the filter states, they be added uniformly to the super filter and child filters so that display of filter and charts will be sensible when they are first rendered.
#
# #### Showing the child filters
# By default, the filters that are controlled by the super filter are hidden.  However, the controlled filters can be shown, which may be useful during development.  To show the filters, set the property **show_child_filters=True** at instantiation or later.
#
# #### SuperCategoryFilter with SeriesFilter
# Since a SeriesFilter is a Category Filter, it can also be controlled by a SuperCategoryFilter.  An importance difference is that the SuperCategoryFilter has no options selected by default, and the SeriesFilter has all options selected by default.  It is recommended that the selectedValues state property be set on the SeriesFilters and/or the super filter so that the initial rendering of the charts appears sensible.

# %%
# create two DataFrames
categories = ['Baltic', 'Mediterranean', 'Park Place']
hotels = [5, 7, 3]
houses = [20, 32, 41]
d1 = {}
d1['categories'] = categories
d1['hotels'] = hotels
d2 = {}
d2['categories'] = categories
d2['houses'] = houses
df1 = pd.DataFrame(d1, columns=['categories', 'hotels'])
df2 = pd.DataFrame(d2, columns=['categories', 'houses'])

# create two charts
chart1 = JoogleChart(df1)
chart2 = JoogleChart(df2)

# create two filters, giving them DIFFERENT labels; using a variable is recommended.
filter1_label = "filter1"
filter1 = Filter("CategoryFilter")
filter1.set_filter_label(filter1_label)
filter1.add_options(filterColumnIndex=0)
chart1.add_filter(filter1)

filter2_label = "filter2"
filter2 = Filter("CategoryFilter")
filter2.set_filter_label(filter2_label)
filter2.add_options(filterColumnIndex=0)
chart2.add_filter(filter2)

# create the super filter, passing the same labels used on the filters
scf = SuperCategoryFilter(df1.categories)
scf.add_filter_label(filter1_label)
scf.add_filter_label(filter2_label)

# ----------------------------------------------------------------------------------------------
# To show the child filters, either pass a parameter or set the property
# scf = SuperCategoryFilter(df1.categories, show_child_filters=True)
#      OR
# scf.show_child_filters = True
# ----------------------------------------------------------------------------------------------

# add chart options
chart1.add_chart_options(colors=['darkcyan'], chartArea_left=40, width=500, chartArea_width=350)
chart2.add_chart_options(colors=['coral'], chartArea_left=40, width=500, chartArea_width=350)

# set a common list of selectedValues, if selectedValues are desired
selected_values = ['Baltic', 'Park Place']
filter1.add_state(selectedValues=selected_values)
filter2.add_state(selectedValues=selected_values)
scf.add_state(selectedValues=selected_values)

# display all three elements, here using a common header
display(HTML("<h2>Houses and Hotels on Three Select Properties</h2></br>"))
scf.show()
row = ChartRow(chart1, chart2)
row.show()
# Out:
# <h2>Houses and Hotels on Three Select Properties</h2></br>
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#     // Check if google jsapi is already loaded.  If not, load it.
#     if (typeof window.google == 'undefined') {
#         jQuery.getScript('https://www.google.com/jsapi', function( data, textStatus, jqxhr) {
#             google_loader_4();
#         });
#     } else {
#         google_loader_4();
#     }
#
#     <!-- taken from http://stackoverflow.com/questions/8618464/how-to-wait-for-another-js-to-load-to-proceed-operation/8618519#8618519 -->
#     function whenDivAvailable(name, callback) {
#         var intervalInMs = 10;
#         window.setTimeout(function() {
#             if (window[name]) {
#                 callback();
#             } else {
#                 window.setTimeout(arguments.callee, intervalInMs);
#             }
#
#         }, intervalInMs);
#     }
#
#     // load visualization library
#     function google_loader_4() {
#         google.load('visualization', '1.0', {'packages':['controls'], 'callback': doStuff_4});
#     }
# });
#
#
#     function doStuff_4() {
#
#
#     	// The superfilter controls the filters of other charts on the page.
#
#
#
# 		// Create superfilter table
# 		var superFilterTable = new google.visualization.DataTable({"rows":[{"c":[{"v":"Baltic"}]},{"c":[{"v":"Mediterranean"}]},{"c":[{"v":"Park Place"}]}],"cols":[{"type":"string","id":"options","label":"options"}]});
#
# 		// create superfilter CategoryFilter
# 		var superFilter = new google.visualization.ControlWrapper({
# 			controlType: 'CategoryFilter',
# 			containerId: 'super_category_filter_4_div_id',
# 			dataTable: superFilterTable,
# 			options: {"ui": {"label": "Options"}, "filterColumnIndex": 0},
# 			state: {"selectedValues": ["Baltic", "Park Place"]}
# 		});
#
# 		superFilter.draw();
#
# 		function superfilter_update() {
#
# 			// update bound filters with the selected values of the superfilter.
#
# 			var selected_values = superFilter.getState().selectedValues;
#
#
# 			var filter1__jooglechart_user_filter_name_state = filter1__jooglechart_user_filter_name.getState();
# 			filter1__jooglechart_user_filter_name_state.selectedValues = selected_values;
# 			filter1__jooglechart_user_filter_name.setState(filter1__jooglechart_user_filter_name_state);
# 			filter1__jooglechart_user_filter_name.draw()
#
# 			var filter2__jooglechart_user_filter_name_state = filter2__jooglechart_user_filter_name.getState();
# 			filter2__jooglechart_user_filter_name_state.selectedValues = selected_values;
# 			filter2__jooglechart_user_filter_name.setState(filter2__jooglechart_user_filter_name_state);
# 			filter2__jooglechart_user_filter_name.draw()
# 		}
#
#
# 		// fix overflow setting on IPython output area that constrains dropdown.
# 		$("#super_category_filter_4_div_id").closest("div.output_subarea").css("overflow-x", "inherit");
#
# 		google.visualization.events.addListener(superFilter, 'statechange', superfilter_update);
#
#     }
# </script>
#
# <style>
# /* Hide filters controlled by the super filter. */
# #filter1__jooglechart_user_filter_name_div_id {
# 	display:none;
# }
# #filter2__jooglechart_user_filter_name_div_id {
# 	display:none;
# }
# </style><div id="super_category_filter_4_div_id" ></div>
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#     // Check if google jsapi is already loaded.  If not, load it.
#     if (typeof window.google == 'undefined') {
#         jQuery.getScript('https://www.google.com/jsapi', function( data, textStatus, jqxhr) {
#             google_loader_5();
#         });
#     } else {
#         google_loader_5();
#     }
#
#     <!-- taken from http://stackoverflow.com/questions/8618464/how-to-wait-for-another-js-to-load-to-proceed-operation/8618519#8618519 -->
#     function whenDivAvailable(name, callback) {
#         var intervalInMs = 10;
#         window.setTimeout(function() {
#             if (window[name]) {
#                 callback();
#             } else {
#                 window.setTimeout(arguments.callee, intervalInMs);
#             }
#
#         }, intervalInMs);
#     }
#
#     // load visualization library
#     function google_loader_5() {
#         google.load('visualization', '1.0', {'packages':['controls'], 'callback': doStuff_5});
#     }
# });
#
#     function doStuff_5() {
#
#     // ==================== CHARTROW CHART 1 ============================= //
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jooglechart_6_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"Baltic"},{"v":5}]},{"c":[{"v":"Mediterranean"},{"v":7}]},{"c":[{"v":"Park Place"},{"v":3}]}],"cols":[{"type":"string","id":"categories","label":"categories"},{"type":"number","id":"hotels","label":"hotels"}]});
#
#         // Add formatters, if any
#
#         // Create ChartWrapper
#         var google_chart_7 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_7_div_id",
#             "dataTable": jooglechart_6_data,
#             "chartType": "ColumnChart",
#             "options": {"width": 500, "colors": ["darkcyan"], "chartArea": {"width": 350, "left": 40}}
#         });
#
#         // Create a dashboard.
#         var jooglechart_6_dashboard = new google.visualization.Dashboard(
#             document.getElementById('jooglechart_6_dashboard_div_id'));
#
#         // Create controls
#
#         filter1__jooglechart_user_filter_name = new google.visualization.ControlWrapper({
#
#           'controlType': 'CategoryFilter',
#           'containerId': 'filter1__jooglechart_user_filter_name_div_id',
#           'options': {"filterColumnIndex": 0},
#           'state': {"selectedValues": ["Baltic", "Park Place"]}
#         });
#
#         // Establish dependencies.
# 		jooglechart_6_dashboard.bind(filter1__jooglechart_user_filter_name, google_chart_7);
#
#         // Draw the dashboard.
#         jooglechart_6_dashboard.draw(jooglechart_6_data);
#
#
#     // ==================================================================== //
#
#     // ==================== CHARTROW CHART 2 ============================= //
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jooglechart_9_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"Baltic"},{"v":20}]},{"c":[{"v":"Mediterranean"},{"v":32}]},{"c":[{"v":"Park Place"},{"v":41}]}],"cols":[{"type":"string","id":"categories","label":"categories"},{"type":"number","id":"houses","label":"houses"}]});
#
#         // Add formatters, if any
#
#         // Create ChartWrapper
#         var google_chart_10 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_10_div_id",
#             "dataTable": jooglechart_9_data,
#             "chartType": "ColumnChart",
#             "options": {"width": 500, "colors": ["coral"], "chartArea": {"width": 350, "left": 40}}
#         });
#
#         // Create a dashboard.
#         var jooglechart_9_dashboard = new google.visualization.Dashboard(
#             document.getElementById('jooglechart_9_dashboard_div_id'));
#
#         // Create controls
#
#         filter2__jooglechart_user_filter_name = new google.visualization.ControlWrapper({
#
#           'controlType': 'CategoryFilter',
#           'containerId': 'filter2__jooglechart_user_filter_name_div_id',
#           'options': {"filterColumnIndex": 0},
#           'state': {"selectedValues": ["Baltic", "Park Place"]}
#         });
#
#         // Establish dependencies.
# 		jooglechart_9_dashboard.bind(filter2__jooglechart_user_filter_name, google_chart_10);
#
#         // Draw the dashboard.
#         jooglechart_9_dashboard.draw(jooglechart_9_data);
#
#
#     // ==================================================================== //
#
#     }
#
# </script>
# <noscript>
# </noscript>
#
# <style>
#
# /*
# 	Setting overflow: scroll prevents buggy behavior in CategoryFilter dropdown
# 	that occurs when the list of menu options is very long.
# */
# .charts-menu {
#     overflow: scroll;
#     max-height: 250px;
# }
# </style>
# <div class="row">
#     <div class="col-sm-6">
#
#
# <div id="jooglechart_6_dashboard_div_id">
# 	<div id="filter1__jooglechart_user_filter_name_div_id"></div>
# 	<div id="google_chart_7_div_id" ></div>
# </div>
#     </div>
#     <div class="col-sm-6">
#
#
# <div id="jooglechart_9_dashboard_div_id">
# 	<div id="filter2__jooglechart_user_filter_name_div_id"></div>
# 	<div id="google_chart_10_div_id" ></div>
# </div>
#     </div>
# </div>
