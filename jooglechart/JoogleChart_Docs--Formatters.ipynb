# %% [markdown]
# # Google Chart Formatters
# Google Charts provide Formatters that can change the way data is displayed without changing the underlying data.  The display of data in tables or in chart tooltips is changed.  To change the way labels are displayed along an axis, see the hAxis.format and vAxis.format configuration options in the GoogleCharts documentation.
#
# The Google Charts documentation currently lists six available formatters:  ArrowFormat, BarFormat, ColorFormat, DateFormat, NumberFormat, PatternFormat.  JoogleCharts provides formatter support.
#
# ** ColorFormat is not currently supported. **
#
# ArrowFormat, BarFormat, and ColorFormat are only for use in Table charts.  ** NOTE:  ArrowFormat and BarFormat may not be functioning. This does not appear to be an issue with Jooglechart.**
#
# Example usage of supported formats follows.
#
# ## Formatter basics
# To add a formatter, call **JoogleChart.add_formatter()**, passing arguments.
#
# JoogleChart.add_formatter() signature:
#
# ```
#     def add_formatter(self, formatter, options=None, cols=None, source_cols=None, pattern=None, dest_col=None):
# ```
#
# The Formatter names can be abbreviated as "number", "date", etc.
#
# For ArrowFormat, BarFormat, DateFormat, and NumberFormat, pass an **options** dictionary and the **cols** to apply the format to.  The options for each format can be found in the Google Charts documentation:  https://developers.google.com/chart/interactive/docs/reference#formatters.
#
# For the PatternFormat, pass a **pattern**, **source_cols**, and an optional **dest_col**.

# %%
import pandas as pd
from jooglechart import JoogleChart

# %% [markdown]
# ## DateFormat
# Datetime values in pandas objects default to date values in the chart.  To retain h:m:s in a datetime value, pass **datetime_cols=[*x*]** to the chart constructor.

# %%
# Create a DataFrame with several columns of dates.
df = pd.DataFrame(columns = ['Name', 'custom format', 'short', 'medium', 'long'])
df.loc[0] = ['Mike', pd.to_datetime("2008-01-15 05:30:12"),
             pd.to_datetime("2008-01-15 05:30:12"),
             pd.to_datetime("2008-01-15 05:30:12"),
             pd.to_datetime("2008-01-15 05:30:12")]
df.loc[1] = ['Alice', pd.to_datetime("2011-10-22 14:03:52"),
             pd.to_datetime("2011-10-22 14:03:52"),
             pd.to_datetime("2011-10-22 14:03:52"),
             pd.to_datetime("2011-10-22 14:03:52")]

# Specify any column that is to retain h:m:s.
chart = JoogleChart(df, chart_type="Table", datetime_cols=[1])

# You can specify a custom pattern in the options.
options = {'pattern': "EEE, MMM d, ''yy H:m:s"}

# cols takes a list of columns, or the index of a single column
chart.add_formatter('date', options = options, cols = 1)

# a shortcut for date format is the short, medium, or long formatType.
chart.add_formatter('date', options = {'formatType': 'short'}, cols = [2])
chart.add_formatter('date', options = {'formatType': 'medium'}, cols = [3])
chart.add_formatter('date', options = {'formatType': 'long'}, cols = [4])

chart.show()
# Out:
# <style>
#
# /*
# 	Setting overflow: scroll prevents buggy behavior in CategoryFilter dropdown
# 	that occurs when the list of menu options is very long.
# */
# .charts-menu {
#     overflow: scroll;
#     max-height: 250px;
# }
#
# .google-visualization-table .google-visualization-table-td-number {
# 	text-align: right;
# }
#
# .jooglechart_container {
# 	margin-bottom: 20px;
# }
#
# h1.jooglechart_global_title {
# 	font-size: 20px;
# 	font-weight: bold;
# 	margin-bottom:8px;
# }
#
#
# .joogle_clearfix:after {
#     content:" ";
#     display:block;
#     clear:both;
# }
#
# </style>
#
# <script>
#
# $(document).ready(function() {
#
# 	/* GLOBALS AREA >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> */
#
# 	window.addEventListener('message', function(message) {
# 		// listener for sonar message from iframe parent
# 		if (typeof message.data.msg !== "undefined" && typeof message.data.msg.sonar_key !== "undefined" &&
# 				typeof message.data.msg.sonar_value !== "undefined" &&
# 				message.data.originId !== message.data.destinationId) {
# 			if (joogle_globals.sonar.handler_array !== undefined) {
# 				joogle_globals.sonar.call_handlers(message.data.msg);
# 			}
# 		}
# 	});
#
#
# 	if (typeof window.joogle_globals === "undefined" || window.joogle_globals === null) {
# 		window.joogle_globals = {};
#
# 		window.joogle_globals.sonar = new (function () {
# 			// object for holding all sonar pieces
# 			this.handler_array = [];
# 			this.message_map = {};
# 			this.add_handler = function(handler) { this.handler_array.push(handler)};
# 			this.send = function(key, value) {
# 				this.message_map[key] = value;
# 				var data = { sonar_key: key, sonar_value: value };
# 				if (window.self !== window.top) {
# 					window.parent.postMessage(data, window.location.origin + window.location.pathname);
# 				}
# 				if (joogle_globals.sonar.handler_array !== undefined) {
# 					joogle_globals.sonar.call_handlers(data);
# 				}
# 			}
# 			this.call_handlers = function(data) {
# 				for (var i = 0; i < this.handler_array.length; i++) {
# 					this.handler_array[i](data);
# 				}
# 				this.call_text_receivers(data);
# 			}
# 			this.poll_message_map = function(key) {
# 				if (key in this.message_map) {
# 					return this.message_map[key];
# 				}
# 				else { return null};
# 			}
# 			this.add_one_time_ready_poller = function(key, func, vis) {
# 				/*
# 					Check if a sonar msg was sent before chart was ready, and run function.
# 					Can happen if a sender has been initialized with a value.
# 				*/
# 				google.visualization.events.addOneTimeListener(vis, "ready", function() {
# 					var result = joogle_globals.sonar.poll_message_map(key);
# 					if (result !== null) {
# 						func({"sonar_key": key, "sonar_value": result});
# 					}
# 				});
# 			}
# 			this.call_text_receivers = function (data) {
# 				var selected_values = data.sonar_value;
# 				if (typeof selected_values === "undefined") {
# 					return;
# 				}
# 				$(".joogle_text_receiver").each(function() {
# 					var receiver = this;
# 					var key = receiver.dataset.key;
# 					var list_style = receiver.dataset.liststyle;
# 					var sub_text = selected_values;
# 					var default_text = receiver.dataset.default;
# 					if (typeof default_text === "undefined") {
# 						default_text = "";
# 					}
# 					var clear_text = receiver.dataset.clear_text;
# 					if (sub_text.constructor !== Array) {
# 						sub_text = $.trim(sub_text);
# 						if (sub_text.length == 0) {
# 							sub_text = default_text;
# 						}
# 						sub_text = [sub_text];
# 					} else if (sub_text.length === 0) {
# 						sub_text = [default_text];
# 					}
# 					sub_text = joogle_globals.format_list_for_text_receiver(sub_text, list_style);
# 					if (key == data.sonar_key) {
# 						var template = receiver.dataset.template;
# 						template = template.replace("{}", sub_text);
# 						receiver.innerHTML = template;
# 					}
# 				})
# 			}
# 		})();
# 	}
#
# 	window.joogle_globals.format_list_for_text_receiver = function(arr, list_style) {
# 		if (list_style === "colloquial") {
# 			if (arr.length === 1) { return arr[0]; }
# 			var front = "";
# 			var back = "";
# 			var back_arr = arr.slice(arr.length - 2, arr.length);
# 			back = back_arr[0] + " and " + back_arr[1];
# 			if (arr.length > 2) {
# 				var front_arr = arr.slice(0, arr.length - 1);
# 				for (var i = 0; i < front_arr.length; i++) {
# 					front += front_arr[i] + ", ";
# 				}
# 			}
# 			return front + back;
# 		}
# 		else if (list_style === "parens") {
# 			return "(" + arr.join(", ") + ")";
# 		}
# 		else if (list_style === "brackets") {
# 			return "[" + arr.join(", ") + "]";
# 		}
# 	}
#
# 	window.joogle_globals.update_category_filter = function(filter, selected_values) {
# 		var filter_state = filter.getState();
# 		filter_state.selectedValues = selected_values;
# 		filter.setState(filter_state);
# 		filter.draw();
# 	}
# 	window.joogle_globals.update_range_filter = function(filter, range) {
# 		var filter_state = filter.getState();
# 		filter_state.lowValue = range[0];
# 		filter_state.highValue = range[1];
# 		filter_state.lowThumbAtMinimum = false; // buggy without this
# 		filter_state.highThumbAtMaximum = false;
# 		filter.setState(filter_state);
# 		filter.draw();
# 	}
# 	window.joogle_globals.update_filter_binding_selection = function(binding_values, data, filter, column, sending_keys) {
# 		// This method is used to update a custom bound filter when its controlling filter gets a selection.
#
#
# 		// Get the list of rows in the table produced by the controlling filter.
# 		var filtered_rows = [];
# 		if (binding_values.length == 0) {
# 			filtered_rows = null;
# 		}
# 		else {
# 			for (var i = 0; i < binding_values.length; i++) {
# 				var rows = data.getFilteredRows([{column: column, value: binding_values[i]}]);
# 				filtered_rows = $.merge(filtered_rows, rows);
# 			}
# 		}
#
# 		// (undocumented setView method on control wrappers)
# 		filter.setView({
# 			rows: filtered_rows
# 		});
# 		filter.draw();
#
# 		// The selected values on the bound filter will stay or get discarded when the
# 		// filter is redrawn with the binding values.  Set the values in the message map
# 		// with the current selected values.
# 		var selected_values = filter.getState().selectedValues;
# 		for (var i = 0; i < sending_keys.length; i++) {
# 			window.joogle_globals.sonar.message_map[sending_keys[i]] = selected_values;
# 		}
#
#
#
# 	}
#
# 	window.joogle_globals.draw_chart_filtered_rows = function(chartwrapper, key_filter_list) {
# 		/*
# 		    This function updates a chart using values from all controlling sonar row filters.
# 			The key_filter_list has the column and filter type for each key.  Get the value
# 			for that filter from the message_map.
# 		*/
#
# 		var datatable = chartwrapper.getDataTable();
# 		var no_filtered_values = true;
# 		var filtered_rows;
#
# 		var total_filtered_rows = [];
# 		for (var i = 0; i < key_filter_list.length; i++) {
# 			// get the list of rows filtered by each filter, and then get their intersection
#
# 			var key = key_filter_list[i].key;
# 			var type = key_filter_list[i].type;
# 			var data = window.joogle_globals.sonar.message_map[key];
# 			var column = key_filter_list[i].column;
#
# 			if (typeof data !== 'undefined' &&
# 			((type === "values" && data.length > 0) || type === "range")) {
# 				// if we enter the loop, then at least one filter has a selection.
# 				no_filtered_values = false;
# 				if (type === "values") {
# 					filtered_rows = joogle_globals.get_rows_for_column_and_values(column, data, datatable);
# 				}
#
# 				else if (type === "range"){
# 					filtered_rows = datatable.getFilteredRows([{column: column, minValue: data[0], maxValue: data[1]}]);
# 				}
#
# 				if (total_filtered_rows.length == 0) { total_filtered_rows = filtered_rows;}
# 				else {
# 					// get the intersection of current rows and the latest list of filtered rows.
# 					total_filtered_rows = total_filtered_rows.filter(function(n) {
# 					  return filtered_rows.indexOf(n) > -1;
# 					});
# 				}
# 			}
# 		}
#
# 		// if the values sent by all the filters were empty, then show the whole chart.
# 		if (no_filtered_values) { total_filtered_rows = null};
#
# 		chartwrapper.setView({
# 			rows: total_filtered_rows,
# 			columns: chartwrapper.getView().columns
# 		});
# 		chartwrapper.draw();
# 	}
#
# 	window.joogle_globals.get_rows_for_column_and_values = function(column

# %% [markdown]
# ## NumberFormat

# %%
# Create a LineChart with numbers
year = ['2001', '2002', '2003']
profits = [46535.542535, 83573.835, 65234.574]
columns = ['year', 'profits']
df = pd.DataFrame({'year':year, 'profits': profits}, columns = columns)

chart = JoogleChart(df)

# add NumberFormat
chart.add_formatter('number', options={'prefix': '$', 'fractionDigits': 2}, cols = 1)

chart.show()
# Out:
# <style>
#
# /*
# 	Setting overflow: scroll prevents buggy behavior in CategoryFilter dropdown
# 	that occurs when the list of menu options is very long.
# */
# .charts-menu {
#     overflow: scroll;
#     max-height: 250px;
# }
#
# .google-visualization-table .google-visualization-table-td-number {
# 	text-align: right;
# }
#
# .jooglechart_container {
# 	margin-bottom: 20px;
# }
#
# h1.jooglechart_global_title {
# 	font-size: 20px;
# 	font-weight: bold;
# 	margin-bottom:8px;
# }
#
#
# .joogle_clearfix:after {
#     content:" ";
#     display:block;
#     clear:both;
# }
#
# </style>
#
# <script>
#
# $(document).ready(function() {
#
# 	/* GLOBALS AREA >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> */
#
# 	window.addEventListener('message', function(message) {
# 		// listener for sonar message from iframe parent
# 		if (typeof message.data.msg !== "undefined" && typeof message.data.msg.sonar_key !== "undefined" &&
# 				typeof message.data.msg.sonar_value !== "undefined" &&
# 				message.data.originId !== message.data.destinationId) {
# 			if (joogle_globals.sonar.handler_array !== undefined) {
# 				joogle_globals.sonar.call_handlers(message.data.msg);
# 			}
# 		}
# 	});
#
#
# 	if (typeof window.joogle_globals === "undefined" || window.joogle_globals === null) {
# 		window.joogle_globals = {};
#
# 		window.joogle_globals.sonar = new (function () {
# 			// object for holding all sonar pieces
# 			this.handler_array = [];
# 			this.message_map = {};
# 			this.add_handler = function(handler) { this.handler_array.push(handler)};
# 			this.send = function(key, value) {
# 				this.message_map[key] = value;
# 				var data = { sonar_key: key, sonar_value: value };
# 				if (window.self !== window.top) {
# 					window.parent.postMessage(data, window.location.origin + window.location.pathname);
# 				}
# 				if (joogle_globals.sonar.handler_array !== undefined) {
# 					joogle_globals.sonar.call_handlers(data);
# 				}
# 			}
# 			this.call_handlers = function(data) {
# 				for (var i = 0; i < this.handler_array.length; i++) {
# 					this.handler_array[i](data);
# 				}
# 				this.call_text_receivers(data);
# 			}
# 			this.poll_message_map = function(key) {
# 				if (key in this.message_map) {
# 					return this.message_map[key];
# 				}
# 				else { return null};
# 			}
# 			this.add_one_time_ready_poller = function(key, func, vis) {
# 				/*
# 					Check if a sonar msg was sent before chart was ready, and run function.
# 					Can happen if a sender has been initialized with a value.
# 				*/
# 				google.visualization.events.addOneTimeListener(vis, "ready", function() {
# 					var result = joogle_globals.sonar.poll_message_map(key);
# 					if (result !== null) {
# 						func({"sonar_key": key, "sonar_value": result});
# 					}
# 				});
# 			}
# 			this.call_text_receivers = function (data) {
# 				var selected_values = data.sonar_value;
# 				if (typeof selected_values === "undefined") {
# 					return;
# 				}
# 				$(".joogle_text_receiver").each(function() {
# 					var receiver = this;
# 					var key = receiver.dataset.key;
# 					var list_style = receiver.dataset.liststyle;
# 					var sub_text = selected_values;
# 					var default_text = receiver.dataset.default;
# 					if (typeof default_text === "undefined") {
# 						default_text = "";
# 					}
# 					var clear_text = receiver.dataset.clear_text;
# 					if (sub_text.constructor !== Array) {
# 						sub_text = $.trim(sub_text);
# 						if (sub_text.length == 0) {
# 							sub_text = default_text;
# 						}
# 						sub_text = [sub_text];
# 					} else if (sub_text.length === 0) {
# 						sub_text = [default_text];
# 					}
# 					sub_text = joogle_globals.format_list_for_text_receiver(sub_text, list_style);
# 					if (key == data.sonar_key) {
# 						var template = receiver.dataset.template;
# 						template = template.replace("{}", sub_text);
# 						receiver.innerHTML = template;
# 					}
# 				})
# 			}
# 		})();
# 	}
#
# 	window.joogle_globals.format_list_for_text_receiver = function(arr, list_style) {
# 		if (list_style === "colloquial") {
# 			if (arr.length === 1) { return arr[0]; }
# 			var front = "";
# 			var back = "";
# 			var back_arr = arr.slice(arr.length - 2, arr.length);
# 			back = back_arr[0] + " and " + back_arr[1];
# 			if (arr.length > 2) {
# 				var front_arr = arr.slice(0, arr.length - 1);
# 				for (var i = 0; i < front_arr.length; i++) {
# 					front += front_arr[i] + ", ";
# 				}
# 			}
# 			return front + back;
# 		}
# 		else if (list_style === "parens") {
# 			return "(" + arr.join(", ") + ")";
# 		}
# 		else if (list_style === "brackets") {
# 			return "[" + arr.join(", ") + "]";
# 		}
# 	}
#
# 	window.joogle_globals.update_category_filter = function(filter, selected_values) {
# 		var filter_state = filter.getState();
# 		filter_state.selectedValues = selected_values;
# 		filter.setState(filter_state);
# 		filter.draw();
# 	}
# 	window.joogle_globals.update_range_filter = function(filter, range) {
# 		var filter_state = filter.getState();
# 		filter_state.lowValue = range[0];
# 		filter_state.highValue = range[1];
# 		filter_state.lowThumbAtMinimum = false; // buggy without this
# 		filter_state.highThumbAtMaximum = false;
# 		filter.setState(filter_state);
# 		filter.draw();
# 	}
# 	window.joogle_globals.update_filter_binding_selection = function(binding_values, data, filter, column, sending_keys) {
# 		// This method is used to update a custom bound filter when its controlling filter gets a selection.
#
#
# 		// Get the list of rows in the table produced by the controlling filter.
# 		var filtered_rows = [];
# 		if (binding_values.length == 0) {
# 			filtered_rows = null;
# 		}
# 		else {
# 			for (var i = 0; i < binding_values.length; i++) {
# 				var rows = data.getFilteredRows([{column: column, value: binding_values[i]}]);
# 				filtered_rows = $.merge(filtered_rows, rows);
# 			}
# 		}
#
# 		// (undocumented setView method on control wrappers)
# 		filter.setView({
# 			rows: filtered_rows
# 		});
# 		filter.draw();
#
# 		// The selected values on the bound filter will stay or get discarded when the
# 		// filter is redrawn with the binding values.  Set the values in the message map
# 		// with the current selected values.
# 		var selected_values = filter.getState().selectedValues;
# 		for (var i = 0; i < sending_keys.length; i++) {
# 			window.joogle_globals.sonar.message_map[sending_keys[i]] = selected_values;
# 		}
#
#
#
# 	}
#
# 	window.joogle_globals.draw_chart_filtered_rows = function(chartwrapper, key_filter_list) {
# 		/*
# 		    This function updates a chart using values from all controlling sonar row filters.
# 			The key_filter_list has the column and filter type for each key.  Get the value
# 			for that filter from the message_map.
# 		*/
#
# 		var datatable = chartwrapper.getDataTable();
# 		var no_filtered_values = true;
# 		var filtered_rows;
#
# 		var total_filtered_rows = [];
# 		for (var i = 0; i < key_filter_list.length; i++) {
# 			// get the list of rows filtered by each filter, and then get their intersection
#
# 			var key = key_filter_list[i].key;
# 			var type = key_filter_list[i].type;
# 			var data = window.joogle_globals.sonar.message_map[key];
# 			var column = key_filter_list[i].column;
#
# 			if (typeof data !== 'undefined' &&
# 			((type === "values" && data.length > 0) || type === "range")) {
# 				// if we enter the loop, then at least one filter has a selection.
# 				no_filtered_values = false;
# 				if (type === "values") {
# 					filtered_rows = joogle_globals.get_rows_for_column_and_values(column, data, datatable);
# 				}
#
# 				else if (type === "range"){
# 					filtered_rows = datatable.getFilteredRows([{column: column, minValue: data[0], maxValue: data[1]}]);
# 				}
#
# 				if (total_filtered_rows.length == 0) { total_filtered_rows = filtered_rows;}
# 				else {
# 					// get the intersection of current rows and the latest list of filtered rows.
# 					total_filtered_rows = total_filtered_rows.filter(function(n) {
# 					  return filtered_rows.indexOf(n) > -1;
# 					});
# 				}
# 			}
# 		}
#
# 		// if the values sent by all the filters were empty, then show the whole chart.
# 		if (no_filtered_values) { total_filtered_rows = null};
#
# 		chartwrapper.setView({
# 			rows: total_filtered_rows,
# 			columns: chartwrapper.getView().columns
# 		});
# 		chartwrapper.draw();
# 	}
#
# 	window.joogle_globals.get_rows_for_column_and_values = function(column

# %%
# In this example, we negate the default behavior to display numbers with thousands separator.

salesperson = ['Ross', 'Monica']
sales = [2535834, 3958320]
columns = ['salesperson', 'employee id', 'employee id (formatted)']
df = pd.DataFrame({'salesperson':salesperson, 'employee id':sales, 'employee id (formatted)': sales}, columns=columns)

chart = JoogleChart(df, chart_type="Table")
chart.add_formatter('number', options = {'pattern': "####"}, cols=2)

chart.show()
# Out:
# <style>
#
# /*
# 	Setting overflow: scroll prevents buggy behavior in CategoryFilter dropdown
# 	that occurs when the list of menu options is very long.
# */
# .charts-menu {
#     overflow: scroll;
#     max-height: 250px;
# }
#
# .google-visualization-table .google-visualization-table-td-number {
# 	text-align: right;
# }
#
# .jooglechart_container {
# 	margin-bottom: 20px;
# }
#
# h1.jooglechart_global_title {
# 	font-size: 20px;
# 	font-weight: bold;
# 	margin-bottom:8px;
# }
#
#
# .joogle_clearfix:after {
#     content:" ";
#     display:block;
#     clear:both;
# }
#
# </style>
#
# <script>
#
# $(document).ready(function() {
#
# 	/* GLOBALS AREA >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> */
#
# 	window.addEventListener('message', function(message) {
# 		// listener for sonar message from iframe parent
# 		if (typeof message.data.msg !== "undefined" && typeof message.data.msg.sonar_key !== "undefined" &&
# 				typeof message.data.msg.sonar_value !== "undefined" &&
# 				message.data.originId !== message.data.destinationId) {
# 			if (joogle_globals.sonar.handler_array !== undefined) {
# 				joogle_globals.sonar.call_handlers(message.data.msg);
# 			}
# 		}
# 	});
#
#
# 	if (typeof window.joogle_globals === "undefined" || window.joogle_globals === null) {
# 		window.joogle_globals = {};
#
# 		window.joogle_globals.sonar = new (function () {
# 			// object for holding all sonar pieces
# 			this.handler_array = [];
# 			this.message_map = {};
# 			this.add_handler = function(handler) { this.handler_array.push(handler)};
# 			this.send = function(key, value) {
# 				this.message_map[key] = value;
# 				var data = { sonar_key: key, sonar_value: value };
# 				if (window.self !== window.top) {
# 					window.parent.postMessage(data, window.location.origin + window.location.pathname);
# 				}
# 				if (joogle_globals.sonar.handler_array !== undefined) {
# 					joogle_globals.sonar.call_handlers(data);
# 				}
# 			}
# 			this.call_handlers = function(data) {
# 				for (var i = 0; i < this.handler_array.length; i++) {
# 					this.handler_array[i](data);
# 				}
# 				this.call_text_receivers(data);
# 			}
# 			this.poll_message_map = function(key) {
# 				if (key in this.message_map) {
# 					return this.message_map[key];
# 				}
# 				else { return null};
# 			}
# 			this.add_one_time_ready_poller = function(key, func, vis) {
# 				/*
# 					Check if a sonar msg was sent before chart was ready, and run function.
# 					Can happen if a sender has been initialized with a value.
# 				*/
# 				google.visualization.events.addOneTimeListener(vis, "ready", function() {
# 					var result = joogle_globals.sonar.poll_message_map(key);
# 					if (result !== null) {
# 						func({"sonar_key": key, "sonar_value": result});
# 					}
# 				});
# 			}
# 			this.call_text_receivers = function (data) {
# 				var selected_values = data.sonar_value;
# 				if (typeof selected_values === "undefined") {
# 					return;
# 				}
# 				$(".joogle_text_receiver").each(function() {
# 					var receiver = this;
# 					var key = receiver.dataset.key;
# 					var list_style = receiver.dataset.liststyle;
# 					var sub_text = selected_values;
# 					var default_text = receiver.dataset.default;
# 					if (typeof default_text === "undefined") {
# 						default_text = "";
# 					}
# 					var clear_text = receiver.dataset.clear_text;
# 					if (sub_text.constructor !== Array) {
# 						sub_text = $.trim(sub_text);
# 						if (sub_text.length == 0) {
# 							sub_text = default_text;
# 						}
# 						sub_text = [sub_text];
# 					} else if (sub_text.length === 0) {
# 						sub_text = [default_text];
# 					}
# 					sub_text = joogle_globals.format_list_for_text_receiver(sub_text, list_style);
# 					if (key == data.sonar_key) {
# 						var template = receiver.dataset.template;
# 						template = template.replace("{}", sub_text);
# 						receiver.innerHTML = template;
# 					}
# 				})
# 			}
# 		})();
# 	}
#
# 	window.joogle_globals.format_list_for_text_receiver = function(arr, list_style) {
# 		if (list_style === "colloquial") {
# 			if (arr.length === 1) { return arr[0]; }
# 			var front = "";
# 			var back = "";
# 			var back_arr = arr.slice(arr.length - 2, arr.length);
# 			back = back_arr[0] + " and " + back_arr[1];
# 			if (arr.length > 2) {
# 				var front_arr = arr.slice(0, arr.length - 1);
# 				for (var i = 0; i < front_arr.length; i++) {
# 					front += front_arr[i] + ", ";
# 				}
# 			}
# 			return front + back;
# 		}
# 		else if (list_style === "parens") {
# 			return "(" + arr.join(", ") + ")";
# 		}
# 		else if (list_style === "brackets") {
# 			return "[" + arr.join(", ") + "]";
# 		}
# 	}
#
# 	window.joogle_globals.update_category_filter = function(filter, selected_values) {
# 		var filter_state = filter.getState();
# 		filter_state.selectedValues = selected_values;
# 		filter.setState(filter_state);
# 		filter.draw();
# 	}
# 	window.joogle_globals.update_range_filter = function(filter, range) {
# 		var filter_state = filter.getState();
# 		filter_state.lowValue = range[0];
# 		filter_state.highValue = range[1];
# 		filter_state.lowThumbAtMinimum = false; // buggy without this
# 		filter_state.highThumbAtMaximum = false;
# 		filter.setState(filter_state);
# 		filter.draw();
# 	}
# 	window.joogle_globals.update_filter_binding_selection = function(binding_values, data, filter, column, sending_keys) {
# 		// This method is used to update a custom bound filter when its controlling filter gets a selection.
#
#
# 		// Get the list of rows in the table produced by the controlling filter.
# 		var filtered_rows = [];
# 		if (binding_values.length == 0) {
# 			filtered_rows = null;
# 		}
# 		else {
# 			for (var i = 0; i < binding_values.length; i++) {
# 				var rows = data.getFilteredRows([{column: column, value: binding_values[i]}]);
# 				filtered_rows = $.merge(filtered_rows, rows);
# 			}
# 		}
#
# 		// (undocumented setView method on control wrappers)
# 		filter.setView({
# 			rows: filtered_rows
# 		});
# 		filter.draw();
#
# 		// The selected values on the bound filter will stay or get discarded when the
# 		// filter is redrawn with the binding values.  Set the values in the message map
# 		// with the current selected values.
# 		var selected_values = filter.getState().selectedValues;
# 		for (var i = 0; i < sending_keys.length; i++) {
# 			window.joogle_globals.sonar.message_map[sending_keys[i]] = selected_values;
# 		}
#
#
#
# 	}
#
# 	window.joogle_globals.draw_chart_filtered_rows = function(chartwrapper, key_filter_list) {
# 		/*
# 		    This function updates a chart using values from all controlling sonar row filters.
# 			The key_filter_list has the column and filter type for each key.  Get the value
# 			for that filter from the message_map.
# 		*/
#
# 		var datatable = chartwrapper.getDataTable();
# 		var no_filtered_values = true;
# 		var filtered_rows;
#
# 		var total_filtered_rows = [];
# 		for (var i = 0; i < key_filter_list.length; i++) {
# 			// get the list of rows filtered by each filter, and then get their intersection
#
# 			var key = key_filter_list[i].key;
# 			var type = key_filter_list[i].type;
# 			var data = window.joogle_globals.sonar.message_map[key];
# 			var column = key_filter_list[i].column;
#
# 			if (typeof data !== 'undefined' &&
# 			((type === "values" && data.length > 0) || type === "range")) {
# 				// if we enter the loop, then at least one filter has a selection.
# 				no_filtered_values = false;
# 				if (type === "values") {
# 					filtered_rows = joogle_globals.get_rows_for_column_and_values(column, data, datatable);
# 				}
#
# 				else if (type === "range"){
# 					filtered_rows = datatable.getFilteredRows([{column: column, minValue: data[0], maxValue: data[1]}]);
# 				}
#
# 				if (total_filtered_rows.length == 0) { total_filtered_rows = filtered_rows;}
# 				else {
# 					// get the intersection of current rows and the latest list of filtered rows.
# 					total_filtered_rows = total_filtered_rows.filter(function(n) {
# 					  return filtered_rows.indexOf(n) > -1;
# 					});
# 				}
# 			}
# 		}
#
# 		// if the values sent by all the filters were empty, then show the whole chart.
# 		if (no_filtered_values) { total_filtered_rows = null};
#
# 		chartwrapper.setView({
# 			rows: total_filtered_rows,
# 			columns: chartwrapper.getView().columns
# 		});
# 		chartwrapper.draw();
# 	}
#
# 	window.joogle_globals.get_rows_for_column_and_values = function(column

# %% [markdown]
# ## PatternFormat
# The PatternFormat creates a display value from the value of one or more other columns.  Pass the pattern and a list of the **source_cols** to **.add_format**.
#
# If a **dest_col** is not specified, the destination column for the completed pattern will be the first column in the source_cols.

# %%
name = ['James', 'Jenny']
pet = ['rabbits', 'turtles']
columns = ['name', 'pet']
df = pd.DataFrame({'name':name, 'pet':pet}, columns=columns)

chart = JoogleChart(df, chart_type="Table")

pattern = "{0} likes {1}!"  # '{x}' indicates the index in the source_cols list

chart.add_formatter('pattern', pattern=pattern, source_cols=[0,1])

# display defaults to the first column in source_cols.

chart.show()
# Out:
# <style>
#
# /*
# 	Setting overflow: scroll prevents buggy behavior in CategoryFilter dropdown
# 	that occurs when the list of menu options is very long.
# */
# .charts-menu {
#     overflow: scroll;
#     max-height: 250px;
# }
#
# .google-visualization-table .google-visualization-table-td-number {
# 	text-align: right;
# }
#
# .jooglechart_container {
# 	margin-bottom: 20px;
# }
#
# h1.jooglechart_global_title {
# 	font-size: 20px;
# 	font-weight: bold;
# 	margin-bottom:8px;
# }
#
#
# .joogle_clearfix:after {
#     content:" ";
#     display:block;
#     clear:both;
# }
#
# </style>
#
# <script>
#
# $(document).ready(function() {
#
# 	/* GLOBALS AREA >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> */
#
# 	window.addEventListener('message', function(message) {
# 		// listener for sonar message from iframe parent
# 		if (typeof message.data.msg !== "undefined" && typeof message.data.msg.sonar_key !== "undefined" &&
# 				typeof message.data.msg.sonar_value !== "undefined" &&
# 				message.data.originId !== message.data.destinationId) {
# 			if (joogle_globals.sonar.handler_array !== undefined) {
# 				joogle_globals.sonar.call_handlers(message.data.msg);
# 			}
# 		}
# 	});
#
#
# 	if (typeof window.joogle_globals === "undefined" || window.joogle_globals === null) {
# 		window.joogle_globals = {};
#
# 		window.joogle_globals.sonar = new (function () {
# 			// object for holding all sonar pieces
# 			this.handler_array = [];
# 			this.message_map = {};
# 			this.add_handler = function(handler) { this.handler_array.push(handler)};
# 			this.send = function(key, value) {
# 				this.message_map[key] = value;
# 				var data = { sonar_key: key, sonar_value: value };
# 				if (window.self !== window.top) {
# 					window.parent.postMessage(data, window.location.origin + window.location.pathname);
# 				}
# 				if (joogle_globals.sonar.handler_array !== undefined) {
# 					joogle_globals.sonar.call_handlers(data);
# 				}
# 			}
# 			this.call_handlers = function(data) {
# 				for (var i = 0; i < this.handler_array.length; i++) {
# 					this.handler_array[i](data);
# 				}
# 				this.call_text_receivers(data);
# 			}
# 			this.poll_message_map = function(key) {
# 				if (key in this.message_map) {
# 					return this.message_map[key];
# 				}
# 				else { return null};
# 			}
# 			this.add_one_time_ready_poller = function(key, func, vis) {
# 				/*
# 					Check if a sonar msg was sent before chart was ready, and run function.
# 					Can happen if a sender has been initialized with a value.
# 				*/
# 				google.visualization.events.addOneTimeListener(vis, "ready", function() {
# 					var result = joogle_globals.sonar.poll_message_map(key);
# 					if (result !== null) {
# 						func({"sonar_key": key, "sonar_value": result});
# 					}
# 				});
# 			}
# 			this.call_text_receivers = function (data) {
# 				var selected_values = data.sonar_value;
# 				if (typeof selected_values === "undefined") {
# 					return;
# 				}
# 				$(".joogle_text_receiver").each(function() {
# 					var receiver = this;
# 					var key = receiver.dataset.key;
# 					var list_style = receiver.dataset.liststyle;
# 					var sub_text = selected_values;
# 					var default_text = receiver.dataset.default;
# 					if (typeof default_text === "undefined") {
# 						default_text = "";
# 					}
# 					var clear_text = receiver.dataset.clear_text;
# 					if (sub_text.constructor !== Array) {
# 						sub_text = $.trim(sub_text);
# 						if (sub_text.length == 0) {
# 							sub_text = default_text;
# 						}
# 						sub_text = [sub_text];
# 					} else if (sub_text.length === 0) {
# 						sub_text = [default_text];
# 					}
# 					sub_text = joogle_globals.format_list_for_text_receiver(sub_text, list_style);
# 					if (key == data.sonar_key) {
# 						var template = receiver.dataset.template;
# 						template = template.replace("{}", sub_text);
# 						receiver.innerHTML = template;
# 					}
# 				})
# 			}
# 		})();
# 	}
#
# 	window.joogle_globals.format_list_for_text_receiver = function(arr, list_style) {
# 		if (list_style === "colloquial") {
# 			if (arr.length === 1) { return arr[0]; }
# 			var front = "";
# 			var back = "";
# 			var back_arr = arr.slice(arr.length - 2, arr.length);
# 			back = back_arr[0] + " and " + back_arr[1];
# 			if (arr.length > 2) {
# 				var front_arr = arr.slice(0, arr.length - 1);
# 				for (var i = 0; i < front_arr.length; i++) {
# 					front += front_arr[i] + ", ";
# 				}
# 			}
# 			return front + back;
# 		}
# 		else if (list_style === "parens") {
# 			return "(" + arr.join(", ") + ")";
# 		}
# 		else if (list_style === "brackets") {
# 			return "[" + arr.join(", ") + "]";
# 		}
# 	}
#
# 	window.joogle_globals.update_category_filter = function(filter, selected_values) {
# 		var filter_state = filter.getState();
# 		filter_state.selectedValues = selected_values;
# 		filter.setState(filter_state);
# 		filter.draw();
# 	}
# 	window.joogle_globals.update_range_filter = function(filter, range) {
# 		var filter_state = filter.getState();
# 		filter_state.lowValue = range[0];
# 		filter_state.highValue = range[1];
# 		filter_state.lowThumbAtMinimum = false; // buggy without this
# 		filter_state.highThumbAtMaximum = false;
# 		filter.setState(filter_state);
# 		filter.draw();
# 	}
# 	window.joogle_globals.update_filter_binding_selection = function(binding_values, data, filter, column, sending_keys) {
# 		// This method is used to update a custom bound filter when its controlling filter gets a selection.
#
#
# 		// Get the list of rows in the table produced by the controlling filter.
# 		var filtered_rows = [];
# 		if (binding_values.length == 0) {
# 			filtered_rows = null;
# 		}
# 		else {
# 			for (var i = 0; i < binding_values.length; i++) {
# 				var rows = data.getFilteredRows([{column: column, value: binding_values[i]}]);
# 				filtered_rows = $.merge(filtered_rows, rows);
# 			}
# 		}
#
# 		// (undocumented setView method on control wrappers)
# 		filter.setView({
# 			rows: filtered_rows
# 		});
# 		filter.draw();
#
# 		// The selected values on the bound filter will stay or get discarded when the
# 		// filter is redrawn with the binding values.  Set the values in the message map
# 		// with the current selected values.
# 		var selected_values = filter.getState().selectedValues;
# 		for (var i = 0; i < sending_keys.length; i++) {
# 			window.joogle_globals.sonar.message_map[sending_keys[i]] = selected_values;
# 		}
#
#
#
# 	}
#
# 	window.joogle_globals.draw_chart_filtered_rows = function(chartwrapper, key_filter_list) {
# 		/*
# 		    This function updates a chart using values from all controlling sonar row filters.
# 			The key_filter_list has the column and filter type for each key.  Get the value
# 			for that filter from the message_map.
# 		*/
#
# 		var datatable = chartwrapper.getDataTable();
# 		var no_filtered_values = true;
# 		var filtered_rows;
#
# 		var total_filtered_rows = [];
# 		for (var i = 0; i < key_filter_list.length; i++) {
# 			// get the list of rows filtered by each filter, and then get their intersection
#
# 			var key = key_filter_list[i].key;
# 			var type = key_filter_list[i].type;
# 			var data = window.joogle_globals.sonar.message_map[key];
# 			var column = key_filter_list[i].column;
#
# 			if (typeof data !== 'undefined' &&
# 			((type === "values" && data.length > 0) || type === "range")) {
# 				// if we enter the loop, then at least one filter has a selection.
# 				no_filtered_values = false;
# 				if (type === "values") {
# 					filtered_rows = joogle_globals.get_rows_for_column_and_values(column, data, datatable);
# 				}
#
# 				else if (type === "range"){
# 					filtered_rows = datatable.getFilteredRows([{column: column, minValue: data[0], maxValue: data[1]}]);
# 				}
#
# 				if (total_filtered_rows.length == 0) { total_filtered_rows = filtered_rows;}
# 				else {
# 					// get the intersection of current rows and the latest list of filtered rows.
# 					total_filtered_rows = total_filtered_rows.filter(function(n) {
# 					  return filtered_rows.indexOf(n) > -1;
# 					});
# 				}
# 			}
# 		}
#
# 		// if the values sent by all the filters were empty, then show the whole chart.
# 		if (no_filtered_values) { total_filtered_rows = null};
#
# 		chartwrapper.setView({
# 			rows: total_filtered_rows,
# 			columns: chartwrapper.getView().columns
# 		});
# 		chartwrapper.draw();
# 	}
#
# 	window.joogle_globals.get_rows_for_column_and_values = function(column

# %% [markdown]
# ## PatternFormat, dest_col, set view cols
# You can specify columns of data to show, which can be useful for PatternFormat, as you can hide columns whose only purpose is to provide input for a PatterFormat.

# %%
list1 = []
list1.append(['First', 'Middle', 'Last'])
list1.append(['Sally', 'A.', 'Smith'])
list1.append(['John', 'J', 'Johnson'])
chart = JoogleChart(list1, chart_type = "Table")
pattern = "{0} {1} {2}"
chart.add_formatter("pattern", pattern=pattern, source_cols=[0, 1, 2], dest_col=1)
chart.set_view_cols(1)
chart.show()
# Out:
# <style>
#
# /*
# 	Setting overflow: scroll prevents buggy behavior in CategoryFilter dropdown
# 	that occurs when the list of menu options is very long.
# */
# .charts-menu {
#     overflow: scroll;
#     max-height: 250px;
# }
#
# .google-visualization-table .google-visualization-table-td-number {
# 	text-align: right;
# }
#
# .jooglechart_container {
# 	margin-bottom: 20px;
# }
#
# h1.jooglechart_global_title {
# 	font-size: 20px;
# 	font-weight: bold;
# 	margin-bottom:8px;
# }
#
#
# .joogle_clearfix:after {
#     content:" ";
#     display:block;
#     clear:both;
# }
#
# </style>
#
# <script>
#
# $(document).ready(function() {
#
# 	/* GLOBALS AREA >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> */
#
# 	window.addEventListener('message', function(message) {
# 		// listener for sonar message from iframe parent
# 		if (typeof message.data.msg !== "undefined" && typeof message.data.msg.sonar_key !== "undefined" &&
# 				typeof message.data.msg.sonar_value !== "undefined" &&
# 				message.data.originId !== message.data.destinationId) {
# 			if (joogle_globals.sonar.handler_array !== undefined) {
# 				joogle_globals.sonar.call_handlers(message.data.msg);
# 			}
# 		}
# 	});
#
#
# 	if (typeof window.joogle_globals === "undefined" || window.joogle_globals === null) {
# 		window.joogle_globals = {};
#
# 		window.joogle_globals.sonar = new (function () {
# 			// object for holding all sonar pieces
# 			this.handler_array = [];
# 			this.message_map = {};
# 			this.add_handler = function(handler) { this.handler_array.push(handler)};
# 			this.send = function(key, value) {
# 				this.message_map[key] = value;
# 				var data = { sonar_key: key, sonar_value: value };
# 				if (window.self !== window.top) {
# 					window.parent.postMessage(data, window.location.origin + window.location.pathname);
# 				}
# 				if (joogle_globals.sonar.handler_array !== undefined) {
# 					joogle_globals.sonar.call_handlers(data);
# 				}
# 			}
# 			this.call_handlers = function(data) {
# 				for (var i = 0; i < this.handler_array.length; i++) {
# 					this.handler_array[i](data);
# 				}
# 				this.call_text_receivers(data);
# 			}
# 			this.poll_message_map = function(key) {
# 				if (key in this.message_map) {
# 					return this.message_map[key];
# 				}
# 				else { return null};
# 			}
# 			this.add_one_time_ready_poller = function(key, func, vis) {
# 				/*
# 					Check if a sonar msg was sent before chart was ready, and run function.
# 					Can happen if a sender has been initialized with a value.
# 				*/
# 				google.visualization.events.addOneTimeListener(vis, "ready", function() {
# 					var result = joogle_globals.sonar.poll_message_map(key);
# 					if (result !== null) {
# 						func({"sonar_key": key, "sonar_value": result});
# 					}
# 				});
# 			}
# 			this.call_text_receivers = function (data) {
# 				var selected_values = data.sonar_value;
# 				if (typeof selected_values === "undefined") {
# 					return;
# 				}
# 				$(".joogle_text_receiver").each(function() {
# 					var receiver = this;
# 					var key = receiver.dataset.key;
# 					var list_style = receiver.dataset.liststyle;
# 					var sub_text = selected_values;
# 					var default_text = receiver.dataset.default;
# 					if (typeof default_text === "undefined") {
# 						default_text = "";
# 					}
# 					var clear_text = receiver.dataset.clear_text;
# 					if (sub_text.constructor !== Array) {
# 						sub_text = $.trim(sub_text);
# 						if (sub_text.length == 0) {
# 							sub_text = default_text;
# 						}
# 						sub_text = [sub_text];
# 					} else if (sub_text.length === 0) {
# 						sub_text = [default_text];
# 					}
# 					sub_text = joogle_globals.format_list_for_text_receiver(sub_text, list_style);
# 					if (key == data.sonar_key) {
# 						var template = receiver.dataset.template;
# 						template = template.replace("{}", sub_text);
# 						receiver.innerHTML = template;
# 					}
# 				})
# 			}
# 		})();
# 	}
#
# 	window.joogle_globals.format_list_for_text_receiver = function(arr, list_style) {
# 		if (list_style === "colloquial") {
# 			if (arr.length === 1) { return arr[0]; }
# 			var front = "";
# 			var back = "";
# 			var back_arr = arr.slice(arr.length - 2, arr.length);
# 			back = back_arr[0] + " and " + back_arr[1];
# 			if (arr.length > 2) {
# 				var front_arr = arr.slice(0, arr.length - 1);
# 				for (var i = 0; i < front_arr.length; i++) {
# 					front += front_arr[i] + ", ";
# 				}
# 			}
# 			return front + back;
# 		}
# 		else if (list_style === "parens") {
# 			return "(" + arr.join(", ") + ")";
# 		}
# 		else if (list_style === "brackets") {
# 			return "[" + arr.join(", ") + "]";
# 		}
# 	}
#
# 	window.joogle_globals.update_category_filter = function(filter, selected_values) {
# 		var filter_state = filter.getState();
# 		filter_state.selectedValues = selected_values;
# 		filter.setState(filter_state);
# 		filter.draw();
# 	}
# 	window.joogle_globals.update_range_filter = function(filter, range) {
# 		var filter_state = filter.getState();
# 		filter_state.lowValue = range[0];
# 		filter_state.highValue = range[1];
# 		filter_state.lowThumbAtMinimum = false; // buggy without this
# 		filter_state.highThumbAtMaximum = false;
# 		filter.setState(filter_state);
# 		filter.draw();
# 	}
# 	window.joogle_globals.update_filter_binding_selection = function(binding_values, data, filter, column, sending_keys) {
# 		// This method is used to update a custom bound filter when its controlling filter gets a selection.
#
#
# 		// Get the list of rows in the table produced by the controlling filter.
# 		var filtered_rows = [];
# 		if (binding_values.length == 0) {
# 			filtered_rows = null;
# 		}
# 		else {
# 			for (var i = 0; i < binding_values.length; i++) {
# 				var rows = data.getFilteredRows([{column: column, value: binding_values[i]}]);
# 				filtered_rows = $.merge(filtered_rows, rows);
# 			}
# 		}
#
# 		// (undocumented setView method on control wrappers)
# 		filter.setView({
# 			rows: filtered_rows
# 		});
# 		filter.draw();
#
# 		// The selected values on the bound filter will stay or get discarded when the
# 		// filter is redrawn with the binding values.  Set the values in the message map
# 		// with the current selected values.
# 		var selected_values = filter.getState().selectedValues;
# 		for (var i = 0; i < sending_keys.length; i++) {
# 			window.joogle_globals.sonar.message_map[sending_keys[i]] = selected_values;
# 		}
#
#
#
# 	}
#
# 	window.joogle_globals.draw_chart_filtered_rows = function(chartwrapper, key_filter_list) {
# 		/*
# 		    This function updates a chart using values from all controlling sonar row filters.
# 			The key_filter_list has the column and filter type for each key.  Get the value
# 			for that filter from the message_map.
# 		*/
#
# 		var datatable = chartwrapper.getDataTable();
# 		var no_filtered_values = true;
# 		var filtered_rows;
#
# 		var total_filtered_rows = [];
# 		for (var i = 0; i < key_filter_list.length; i++) {
# 			// get the list of rows filtered by each filter, and then get their intersection
#
# 			var key = key_filter_list[i].key;
# 			var type = key_filter_list[i].type;
# 			var data = window.joogle_globals.sonar.message_map[key];
# 			var column = key_filter_list[i].column;
#
# 			if (typeof data !== 'undefined' &&
# 			((type === "values" && data.length > 0) || type === "range")) {
# 				// if we enter the loop, then at least one filter has a selection.
# 				no_filtered_values = false;
# 				if (type === "values") {
# 					filtered_rows = joogle_globals.get_rows_for_column_and_values(column, data, datatable);
# 				}
#
# 				else if (type === "range"){
# 					filtered_rows = datatable.getFilteredRows([{column: column, minValue: data[0], maxValue: data[1]}]);
# 				}
#
# 				if (total_filtered_rows.length == 0) { total_filtered_rows = filtered_rows;}
# 				else {
# 					// get the intersection of current rows and the latest list of filtered rows.
# 					total_filtered_rows = total_filtered_rows.filter(function(n) {
# 					  return filtered_rows.indexOf(n) > -1;
# 					});
# 				}
# 			}
# 		}
#
# 		// if the values sent by all the filters were empty, then show the whole chart.
# 		if (no_filtered_values) { total_filtered_rows = null};
#
# 		chartwrapper.setView({
# 			rows: total_filtered_rows,
# 			columns: chartwrapper.getView().columns
# 		});
# 		chartwrapper.draw();
# 	}
#
# 	window.joogle_globals.get_rows_for_column_and_values = function(column
