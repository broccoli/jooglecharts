# %% [markdown]
# # JoogleChart ChartRow
# Two to four JoogleCharts can be rendered in a row using a ChartRow object by the following steps.
#
# 1.  Create 2-4 chart objects.
# 2.  Create a ChartRow object, passing the charts as arguments
# 3.  Call .show() on the ChartRow.  All charts in the row will be rendered.
#
# The charts in the ChartRow can contain filters.

# %%
import pandas as pd
from jooglechart_api import JoogleChart, Filter, ChartRow

# %%
cities = ['New York', 'Chicago', 'Dallas', 'Boston']
pies = [12, 32, 5, 20]
pies_df = pd.DataFrame({'cities': cities, 'pies': pies}, columns=['cities', 'pies'])


# Create 3 charts for the row.
chart1 = JoogleChart(pies_df, chart_type="PieChart")

# For our demonstration, we'll create copies of the chart and change the chart type.
chart2 = chart1.copy()
chart2.set_chart_type("LineChart")

chart3 = chart1.copy()
chart3.set_chart_type("ColumnChart")

# Create the ChartRow object
row = ChartRow(chart1, chart2, chart3)

# Display the ChartRow
row.show()
# Out:
# <script type="text/javascript">
#
#     // Check if google jsapi is already loaded.  If not, load it.
#     if (typeof window.google == 'undefined') {
#         jQuery.getScript('https://www.google.com/jsapi', function( data, textStatus, jqxhr) {
#             google_loader_15();
#         });
#     } else {
#         google_loader_15();
#     }
#
#     // load visualization library
#     function google_loader_15() {
#
#         google.load('visualization', '1.0', {'callback': doStuff_15});
#     }
#     function doStuff_15() {
#
# 	// ==================== CHARTROW CHART 1 ============================= //
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jugle_chart_16_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"New York"},{"v":12}]},{"c":[{"v":"Chicago"},{"v":32}]},{"c":[{"v":"Dallas"},{"v":5}]},{"c":[{"v":"Boston"},{"v":20}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"number","id":"pies","label":"pies"}]});
#
#         // Create ChartWrapper
#         var google_chart_12 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_12_div_id",
#             "dataTable": jugle_chart_16_data,
#             "chartType": "PieChart",
#             "options": {}
#         });
#
#
#
#         			google_chart_12.draw();
#
# 	// ==================================================================== //
#
# 	// ==================== CHARTROW CHART 2 ============================= //
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jugle_chart_17_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"New York"},{"v":12}]},{"c":[{"v":"Chicago"},{"v":32}]},{"c":[{"v":"Dallas"},{"v":5}]},{"c":[{"v":"Boston"},{"v":20}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"number","id":"pies","label":"pies"}]});
#
#         // Create ChartWrapper
#         var google_chart_13 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_13_div_id",
#             "dataTable": jugle_chart_17_data,
#             "chartType": "LineChart",
#             "options": {}
#         });
#
#
#
#         			google_chart_13.draw();
#
# 	// ==================================================================== //
#
# 	// ==================== CHARTROW CHART 3 ============================= //
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jugle_chart_18_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"New York"},{"v":12}]},{"c":[{"v":"Chicago"},{"v":32}]},{"c":[{"v":"Dallas"},{"v":5}]},{"c":[{"v":"Boston"},{"v":20}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"number","id":"pies","label":"pies"}]});
#
#         // Create ChartWrapper
#         var google_chart_14 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_14_div_id",
#             "dataTable": jugle_chart_18_data,
#             "chartType": "ColumnChart",
#             "options": {}
#         });
#
#
#
#         			google_chart_14.draw();
#
# 	// ==================================================================== //
#
#     }
#
# </script>
# <div class="row">
# 	<div class="col-sm-4">
# <div id="google_chart_12_div_id" ></div>
# 	</div>
# 	<div class="col-sm-4">
# <div id="google_chart_13_div_id" ></div>
# 	</div>
# 	<div class="col-sm-4">
# <div id="google_chart_14_div_id" ></div>
# 	</div>
# </div>

# %% [markdown]
# ## Charts with filters

# %%
# For this demo, we'll just add a filter to one of the charts and re-display the row.
filter1 = Filter(type="NumberRangeFilter")
filter1.add_options(filterColumnIndex=1)

chart1.add_filter(filter1)

row.show()
# Out:
# <script type="text/javascript">
#
#     // Check if google jsapi is already loaded.  If not, load it.
#     if (typeof window.google == 'undefined') {
#         jQuery.getScript('https://www.google.com/jsapi', function( data, textStatus, jqxhr) {
#             google_loader_19();
#         });
#     } else {
#         google_loader_19();
#     }
#
#     // load visualization library
#     function google_loader_19() {
# 		google.load('visualization', '1.0', {'packages':['controls'], 'callback': doStuff_19});
#     }
#     function doStuff_19() {
#
# 	// ==================== CHARTROW CHART 1 ============================= //
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jugle_chart_20_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"New York"},{"v":12}]},{"c":[{"v":"Chicago"},{"v":32}]},{"c":[{"v":"Dallas"},{"v":5}]},{"c":[{"v":"Boston"},{"v":20}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"number","id":"pies","label":"pies"}]});
#
#         // Create ChartWrapper
#         var google_chart_15 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_15_div_id",
#             "dataTable": jugle_chart_20_data,
#             "chartType": "PieChart",
#             "options": {}
#         });
#
#         // Create a dashboard.
#         var jugle_chart_20_dashboard = new google.visualization.Dashboard(
#             document.getElementById('jugle_chart_20_dashboard_div_id'));
#
#         // Create controls
#         var google_filter_2 = new google.visualization.ControlWrapper({
#           'controlType': 'NumberRangeFilter',
#           'containerId': 'google_filter_2_div_id',
#           'options': {"filterColumnIndex": 1},
#           'state': {}
#         });
#
#         // Establish dependencies.
# 		jugle_chart_20_dashboard.bind(google_filter_2, google_chart_15);
#
#         // Draw the dashboard.
#         jugle_chart_20_dashboard.draw(jugle_chart_20_data);	// ==================================================================== //
#
# 	// ==================== CHARTROW CHART 2 ============================= //
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jugle_chart_21_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"New York"},{"v":12}]},{"c":[{"v":"Chicago"},{"v":32}]},{"c":[{"v":"Dallas"},{"v":5}]},{"c":[{"v":"Boston"},{"v":20}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"number","id":"pies","label":"pies"}]});
#
#         // Create ChartWrapper
#         var google_chart_16 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_16_div_id",
#             "dataTable": jugle_chart_21_data,
#             "chartType": "LineChart",
#             "options": {}
#         });
#
#
#
#         			google_chart_16.draw();
#
# 	// ==================================================================== //
#
# 	// ==================== CHARTROW CHART 3 ============================= //
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jugle_chart_22_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"New York"},{"v":12}]},{"c":[{"v":"Chicago"},{"v":32}]},{"c":[{"v":"Dallas"},{"v":5}]},{"c":[{"v":"Boston"},{"v":20}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"number","id":"pies","label":"pies"}]});
#
#         // Create ChartWrapper
#         var google_chart_17 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_17_div_id",
#             "dataTable": jugle_chart_22_data,
#             "chartType": "ColumnChart",
#             "options": {}
#         });
#
#
#
#         			google_chart_17.draw();
#
# 	// ==================================================================== //
#
#     }
#
# </script>
# <div class="row">
# 	<div class="col-sm-4">
# <div id="jugle_chart_20_dashboard_div_id">
# 	<div id="google_filter_2_div_id"></div>
# 	<div id="google_chart_15_div_id" ></div>
# </div>	</div>
# 	<div class="col-sm-4">
# <div id="google_chart_16_div_id" ></div>
# 	</div>
# 	<div class="col-sm-4">
# <div id="google_chart_17_div_id" ></div>
# 	</div>
# </div>
