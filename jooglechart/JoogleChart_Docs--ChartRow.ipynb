# %% [markdown]
# # JoogleChart ChartRow
# Two to four JoogleCharts can be rendered in a row using a ChartRow object by the following steps.
#
# 1.  Create 2-4 chart objects.
# 2.  Create a ChartRow object, passing the charts as arguments
# 3.  Call .show() on the ChartRow.  All charts in the row will be rendered.
#
# The charts in the ChartRow can contain filters.

# %%
import pandas as pd
from jooglechart_api import JoogleChart, Filter, ChartRow

# %%
cities = ['New York', 'Chicago', 'Dallas', 'Boston']
pies = [12, 32, 5, 20]
pies_df = pd.DataFrame({'cities': cities, 'pies': pies}, columns=['cities', 'pies'])

# Create 3 charts for the row.
chart1 = JoogleChart(pies_df, chart_type="PieChart")

# For our demonstration, we'll create copies of the chart and change the chart type.
chart2 = chart1.copy()
chart2.chart_type = "LineChart"

chart3 = chart1.copy()
chart3.chart_type = "ColumnChart"

# Create the ChartRow object
row = ChartRow(chart1, chart2, chart3)

# Display the ChartRow
row.show()
# Out:
# <script type="text/javascript">
#
#     // Check if google jsapi is already loaded.  If not, load it.
#     if (typeof window.google == 'undefined') {
#         jQuery.getScript('https://www.google.com/jsapi', function( data, textStatus, jqxhr) {
#             google_loader();
#         });
#     } else {
#         google_loader();
#     }
#
#     // load visualization library
#     function google_loader() {
#
#         google.load('visualization', '1.0', {'callback': doStuff});
#     }
#     function doStuff() {
#
# 	// ==================== CHARTROW CHART 1 ============================= //
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jugle_chart_7_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"New York"},{"v":12}]},{"c":[{"v":"Chicago"},{"v":32}]},{"c":[{"v":"Dallas"},{"v":5}]},{"c":[{"v":"Boston"},{"v":20}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"number","id":"pies","label":"pies"}]});
#
#         // Create ChartWrapper
#         var google_chart_7 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_7_div_id",
#             "dataTable": jugle_chart_7_data,
#             "chartType": "PieChart",
#             "options": {}
#         });
#
#
#
#         			google_chart_7.draw();
#
# 	// ==================================================================== //
#
# 	// ==================== CHARTROW CHART 2 ============================= //
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jugle_chart_8_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"New York"},{"v":12}]},{"c":[{"v":"Chicago"},{"v":32}]},{"c":[{"v":"Dallas"},{"v":5}]},{"c":[{"v":"Boston"},{"v":20}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"number","id":"pies","label":"pies"}]});
#
#         // Create ChartWrapper
#         var google_chart_8 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_8_div_id",
#             "dataTable": jugle_chart_8_data,
#             "chartType": "PieChart",
#             "options": {}
#         });
#
#
#
#         			google_chart_8.draw();
#
# 	// ==================================================================== //
#
# 	// ==================== CHARTROW CHART 3 ============================= //
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jugle_chart_9_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"New York"},{"v":12}]},{"c":[{"v":"Chicago"},{"v":32}]},{"c":[{"v":"Dallas"},{"v":5}]},{"c":[{"v":"Boston"},{"v":20}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"number","id":"pies","label":"pies"}]});
#
#         // Create ChartWrapper
#         var google_chart_9 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_9_div_id",
#             "dataTable": jugle_chart_9_data,
#             "chartType": "PieChart",
#             "options": {}
#         });
#
#
#
#         			google_chart_9.draw();
#
# 	// ==================================================================== //
#
#     }
#
# </script>
# <div class="row">
# 	<div class="col-sm-4">
# <div id="google_chart_7_div_id" ></div>
# 	</div>
# 	<div class="col-sm-4">
# <div id="google_chart_8_div_id" ></div>
# 	</div>
# 	<div class="col-sm-4">
# <div id="google_chart_9_div_id" ></div>
# 	</div>
# </div>

# %% [markdown]
# ## Charts with filters

# %%
# For this demo, we'll just add a filter to one of the charts and re-display the row.
filter1 = Filter(type="NumberRangeFilter")
filter1.add_options(filterColumnIndex=1)

chart1.add_filter(filter1)

row.show()
# Out:
# <script type="text/javascript">
#
#     // Check if google jsapi is already loaded.  If not, load it.
#     if (typeof window.google == 'undefined') {
#         jQuery.getScript('https://www.google.com/jsapi', function( data, textStatus, jqxhr) {
#             google_loader();
#         });
#     } else {
#         google_loader();
#     }
#
#     // load visualization library
#     function google_loader() {
# 		google.load('visualization', '1.0', {'packages':['controls'], 'callback': doStuff});
#     }
#     function doStuff() {
#
# 	// ==================== CHARTROW CHART 1 ============================= //
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jugle_chart_4_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"New York"},{"v":12}]},{"c":[{"v":"Chicago"},{"v":32}]},{"c":[{"v":"Dallas"},{"v":5}]},{"c":[{"v":"Boston"},{"v":20}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"number","id":"pies","label":"pies"}]});
#
#         // Create ChartWrapper
#         var google_chart_4 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_4_div_id",
#             "dataTable": jugle_chart_4_data,
#             "chartType": "PieChart",
#             "options": {}
#         });
#
#         // Create a dashboard.
#         var jugle_chart_4_dashboard = new google.visualization.Dashboard(
#             document.getElementById('jugle_chart_4_dashboard_div_id'));
#
#         // Create controls
#         var google_filter_1 = new google.visualization.ControlWrapper({
#           'controlType': 'NumberRangeFilter',
#           'containerId': 'google_filter_1_div_id',
#           'options': {"filterColumnIndex": 1},
#           'state': {}
#         });
#
#         // Establish dependencies.
# 		jugle_chart_4_dashboard.bind(google_filter_1, google_chart_4);
#
#         // Draw the dashboard.
#         jugle_chart_4_dashboard.draw(jugle_chart_4_data);	// ==================================================================== //
#
# 	// ==================== CHARTROW CHART 2 ============================= //
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jugle_chart_5_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"New York"},{"v":12}]},{"c":[{"v":"Chicago"},{"v":32}]},{"c":[{"v":"Dallas"},{"v":5}]},{"c":[{"v":"Boston"},{"v":20}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"number","id":"pies","label":"pies"}]});
#
#         // Create ChartWrapper
#         var google_chart_5 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_5_div_id",
#             "dataTable": jugle_chart_5_data,
#             "chartType": "PieChart",
#             "options": {}
#         });
#
#
#
#         			google_chart_5.draw();
#
# 	// ==================================================================== //
#
# 	// ==================== CHARTROW CHART 3 ============================= //
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jugle_chart_6_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"New York"},{"v":12}]},{"c":[{"v":"Chicago"},{"v":32}]},{"c":[{"v":"Dallas"},{"v":5}]},{"c":[{"v":"Boston"},{"v":20}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"number","id":"pies","label":"pies"}]});
#
#         // Create ChartWrapper
#         var google_chart_6 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_6_div_id",
#             "dataTable": jugle_chart_6_data,
#             "chartType": "PieChart",
#             "options": {}
#         });
#
#
#
#         			google_chart_6.draw();
#
# 	// ==================================================================== //
#
#     }
#
# </script>
# <div class="row">
# 	<div class="col-sm-4">
# <div id="jugle_chart_4_dashboard_div_id">
# 	<div id="google_filter_1_div_id"></div>
# 	<div id="google_chart_4_div_id" ></div>
# </div>	</div>
# 	<div class="col-sm-4">
# <div id="google_chart_5_div_id" ></div>
# 	</div>
# 	<div class="col-sm-4">
# <div id="google_chart_6_div_id" ></div>
# 	</div>
# </div>
