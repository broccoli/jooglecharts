# %% [markdown]
# # Containers
#
# - [ChartRow](#ChartRow)
# - [add_div_styles](#div_styles)
# - [Box](#Box)
# - [Using Markdown](#Markdown)
# - [Toggler](#Toggler)
#
# Jooglechart provides containers that can be used to arrange multiple objects in a layout and show them all at once.  There are two containers -- ChartRow and Box.  These containers can be used to hold and show the following:
# - any jooglechart chart, filter or widget
# - nested ChartRows and Boxes
# - strings (including html)
#
# ### Dashboarding, containers, and you
# Using ChartRows and Boxes, the possibilities are endless for creating simple or elaborate dashboards.  This can be done with the following techniques.
#
# 1.  Nesting containers.  Complex layouts can be created by nesting boxes in rows, and rows in boxes.
# 2.  **add_div_styles()**.  Containers can be given css styles using their **add_div_styles()** method.  For example, margin and padding can be added to containers for spacing.  Or the container width/height can be specified.
# 3.  Sonar.  Sonar widgets lend themselves nicely to dashboarding, as multiple jooglechart objects within a dashboard can be changed together.  For example, you can create a sidebar of filters that controls multiple charts within the same layout container.
#
# Your only limit is your imagination.

# %% [markdown]
# # ChartRow<a name="ChartRow"></a>
# A ChartRow is used to place two or more objects in columns.  A ChartRow uses one of four modes, which may take their own parameters.
#
# ### Padding
# An integer can be passed to specify **padding** in pixels in a ChartRow.  The padding is applied to the left and right of each column in the row.
#
# ### Creating a ChartRow
#
# A ChartRow is created in the following steps.
#
# 1.  Create two or more chart objects.
# 2.  Create a ChartRow object, passing the chart objects as arguments, along with the mode, any additional mode parameters, and optional padding.
# 3.  Call .show() on the ChartRow.  All objects in the row will be rendered.

# %% [markdown]
# ## ChartRow mode:  bootstrap
# Bootstrap mode creates evenly sized columns across the width of the row.  Also, Bootstrap columns are responsive, switching to stacked display when the size of the view window is shrunk enough.
#
# Bootstrap mode is the default mode.  If no mode is specified, bootstrap mode is used.

# %%
import pandas as pd
from jooglechart import JoogleChart, ChartRow
from jooglechart.utils import get_df  # a utility function for generating a toy dataframe

# %%
df1 = get_df(rows=2)
chart1 = JoogleChart(df1, chart_type="PieChart")
chart1.add_chart_options(legend_position="top")

df2 = get_df()
chart2 = JoogleChart(df2, chart_type="ColumnChart")

df3 = get_df()
chart3 = JoogleChart(df3, chart_type="BarChart")

# pass the joogle objects to display, followed by parameters
row = ChartRow(chart1, chart2, chart3, mode="bootstrap")  # passing the mode parameter is optional for bootstrap

row.show()
# Out:
# <style>
#
# /*
# 	Setting overflow: scroll prevents buggy behavior in CategoryFilter dropdown
# 	that occurs when the list of menu options is very long.
# */
# .charts-menu {
#     overflow: scroll;
#     max-height: 250px;
# }
#
# .google-visualization-table .google-visualization-table-td-number {
# 	text-align: right;
# }
#
# .jooglechart_container {
# 	margin-bottom: 20px;
# }
#
# h1.jooglechart_global_title {
# 	font-size: 20px;
# 	font-weight: bold;
# 	margin-bottom:8px;
# }
#
#
# .joogle_clearfix:after {
#     content:" ";
#     display:block;
#     clear:both;
# }
#
# </style>
#
# <script>
#
# $(document).ready(function() {
#
# 	/* GLOBALS AREA >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> */
#
# 	window.addEventListener('message', function(message) {
# 		// listener for sonar message from iframe parent
# 		if (typeof message.data.msg !== "undefined" && typeof message.data.msg.sonar_key !== "undefined" &&
# 				typeof message.data.msg.sonar_value !== "undefined" &&
# 				message.data.originId !== message.data.destinationId) {
# 			if (joogle_globals.sonar.handler_array !== undefined) {
# 				joogle_globals.sonar.call_handlers(message.data.msg);
# 			}
# 		}
# 	});
#
#
# 	if (typeof window.joogle_globals === "undefined" || window.joogle_globals === null) {
# 		window.joogle_globals = {};
#
# 		window.joogle_globals.sonar = new (function () {
# 			// object for holding all sonar pieces
# 			this.handler_array = [];
# 			this.message_map = {};
# 			this.add_handler = function(handler) { this.handler_array.push(handler)};
# 			this.send = function(key, value) {
# 				this.message_map[key] = value;
# 				var data = { sonar_key: key, sonar_value: value };
# 				if (window.self !== window.top) {
# 					window.parent.postMessage(data, window.location.origin + window.location.pathname);
# 				}
# 				if (joogle_globals.sonar.handler_array !== undefined) {
# 					joogle_globals.sonar.call_handlers(data);
# 				}
# 			}
# 			this.call_handlers = function(data) {
# 				for (var i = 0; i < this.handler_array.length; i++) {
# 					this.handler_array[i](data);
# 				}
# 				this.call_text_receivers(data);
# 			}
# 			this.poll_message_map = function(key) {
# 				if (key in this.message_map) {
# 					return this.message_map[key];
# 				}
# 				else { return null};
# 			}
# 			this.add_one_time_ready_poller = function(key, func, vis) {
# 				/*
# 					Check if a sonar msg was sent before chart was ready, and run function.
# 					Can happen if a sender has been initialized with a value.
# 				*/
# 				google.visualization.events.addOneTimeListener(vis, "ready", function() {
# 					var result = joogle_globals.sonar.poll_message_map(key);
# 					if (result !== null) {
# 						func({"sonar_key": key, "sonar_value": result});
# 					}
# 				});
# 			}
# 			this.call_text_receivers = function (data) {
# 				$(".joogle_text_receiver").each(function() {
# 					var receiver = this;
# 					var key = receiver.dataset.key;
# 					var list_style = receiver.dataset.liststyle;
# 					var sub_text = data.sonar_value;
# 					var default_text = receiver.dataset.default;
# 					if (typeof default_text === "undefined") {
# 						default_text = "";
# 					}
# 					var clear_text = receiver.dataset.clear_text;
# 					if (sub_text.constructor !== Array) {
# 						sub_text = $.trim(sub_text);
# 						if (sub_text.length == 0) {
# 							sub_text = default_text;
# 						}
# 						sub_text = [sub_text];
# 					} else if (sub_text.length === 0) {
# 						sub_text = [default_text];
# 					}
# 					sub_text = joogle_globals.format_list_for_text_receiver(sub_text, list_style);
# 					if (key == data.sonar_key) {
# 						var template = receiver.dataset.template;
# 						template = template.replace("{}", sub_text);
# 						receiver.innerHTML = template;
# 					}
# 				})
# 			}
# 		})();
# 	}
#
# 	window.joogle_globals.format_list_for_text_receiver = function(arr, list_style) {
# 		if (list_style === "colloquial") {
# 			if (arr.length === 1) { return arr[0]; }
# 			var front = "";
# 			var back = "";
# 			var back_arr = arr.slice(arr.length - 2, arr.length);
# 			back = back_arr[0] + " and " + back_arr[1];
# 			if (arr.length > 2) {
# 				var front_arr = arr.slice(0, arr.length - 1);
# 				for (var i = 0; i < front_arr.length; i++) {
# 					front += front_arr[i] + ", ";
# 				}
# 			}
# 			return front + back;
# 		}
# 		else if (list_style === "parens") {
# 			return "(" + arr.join(", ") + ")";
# 		}
# 		else if (list_style === "brackets") {
# 			return "[" + arr.join(", ") + "]";
# 		}
# 	}
#
# 	window.joogle_globals.update_category_filter = function(filter, selected_values) {
# 		// utility function for updating Google Charts filter
# 		var filter_state = filter.getState();
# 		filter_state.selectedValues = selected_values;
# 		filter.setState(filter_state);
# 		filter.draw();
# 	}
# 	window.joogle_globals.update_range_filter = function(filter, range) {
# 		// utility function for updating Google Charts filter
# 		var filter_state = filter.getState();
# 		filter_state.lowValue = range[0];
# 		filter_state.highValue = range[1];
# 		filter_state.lowThumbAtMinimum = false; // buggy without this
# 		filter_state.highThumbAtMaximum = false;
# 		filter.setState(filter_state);
# 		filter.draw();
# 	}
# 	window.joogle_globals.update_filter_binding_selection = function(binding_values, data, filter, column, sending_keys) {
# 		// This method is used to update a custom bound filter when its controlling filter gets a selection.
#
#
# 		// Get the list of rows in the table produced by the controlling filter.
# 		var filtered_rows = [];
# 		if (binding_values.length == 0) {
# 			filtered_rows = null;
# 		}
# 		else {
# 			for (var i = 0; i < binding_values.length; i++) {
# 				var rows = data.getFilteredRows([{column: column, value: binding_values[i]}]);
# 				filtered_rows = $.merge(filtered_rows, rows);
# 			}
# 		}
#
# 		// (undocumented setView method on control wrappers)
# 		filter.setView({
# 			rows: filtered_rows
# 		});
# 		filter.draw();
#
# 		// The selected values on the bound filter will stay or get discarded when the
# 		// filter is redrawn with the binding values.  Set the values in the message map
# 		// with the current selected values.
# 		var selected_values = filter.getState().selectedValues;
# 		for (var i = 0; i < sending_keys.length; i++) {
# 			window.joogle_globals.sonar.message_map[sending_keys[i]] = selected_values;
# 		}
#
#
#
# 	}
# 	window.joogle_globals.update_chart = function(data, chartwrapper, view_cols, key_filter_list) {
# 		/*  This function updates a chart using values from all controlling sonar filters.
# 			The key_filter_list has the column and filter type for each key.  Get the value
# 			for that filter from the message_map.
# 		*/
#
# 		var no_filtered_values = true;
#
# 		var total_filtered_rows = [];
# 		for (var i = 0; i < key_filter_list.length; i++) {
# 			// get the list of rows filtered by each filter, and then get their intersection
#
# 			var key = key_filter_list[i].key;
# 			var type = key_filter_list[i].type;
# 			var values = window.joogle_globals.sonar.message_map[key];
# 			var column = key_filter_list[i].column;
#
# 			if (typeof values !== 'undefined' && values.length > 0) {
# 				// if we enter the loop, then at least one filter has a selection.
# 				no_filtered_values = false;
# 				if (type === "values") {
# 					filtered_rows = joogle_globals.get_rows_for_column_and_values(column, values, data);
# 				}
#
# 				else if (type === "range"){
# 					filtered_rows = data.getFilteredRows([{column: column, minValue: values[0], maxValue: values[1]}]);
# 				}
#
# 				if (total_filtered_rows.length == 0) { total_filtered_rows = filtered_rows;}
# 				else {
# 					// get the intersection of current rows and the latest list of filtered rows.
# 					total_filtered_rows = total_filtered_rows.filter(function(n) {
# 					  return filtered_rows.indexOf(n) > -1;
# 					});
# 				}
# 			}
# 		}
#
# 		// if the values sent be all the filters were empty, then show the whole chart.
# 		if (no_filtered_values) { total_filtered_rows = null};
#
# 		chartwrapper.setView({
# 			rows: total_filtered_rows,
# 			columns: view_cols
# 		});
# 		chartwrapper.draw();
# 	}
#
# 	window.joogle_globals.get_rows_for_column_and_values = function(column, selections, datatable) {
# 		// for a list of values and a column, get the row numbers that have those values.
# 		var rows_total = [];

# %% [markdown]
# ## ChartRow mode:  free
# In free mode, no column width is specified.  The columns widths conform to the object sizes.
#
# It may be desirable to adding padding when using free mode.

# %%
row = ChartRow(chart3, chart2, mode="free")

row.show()
# Out:
# <style>
#
# /*
# 	Setting overflow: scroll prevents buggy behavior in CategoryFilter dropdown
# 	that occurs when the list of menu options is very long.
# */
# .charts-menu {
#     overflow: scroll;
#     max-height: 250px;
# }
#
# .google-visualization-table .google-visualization-table-td-number {
# 	text-align: right;
# }
#
# .jooglechart_container {
# 	margin-bottom: 20px;
# }
#
# h1.jooglechart_global_title {
# 	font-size: 20px;
# 	font-weight: bold;
# 	margin-bottom:8px;
# }
#
#
# .joogle_clearfix:after {
#     content:" ";
#     display:block;
#     clear:both;
# }
#
# </style>
#
# <script>
#
# $(document).ready(function() {
#
# 	/* GLOBALS AREA >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> */
#
# 	window.addEventListener('message', function(message) {
# 		// listener for sonar message from iframe parent
# 		if (typeof message.data.msg !== "undefined" && typeof message.data.msg.sonar_key !== "undefined" &&
# 				typeof message.data.msg.sonar_value !== "undefined" &&
# 				message.data.originId !== message.data.destinationId) {
# 			if (joogle_globals.sonar.handler_array !== undefined) {
# 				joogle_globals.sonar.call_handlers(message.data.msg);
# 			}
# 		}
# 	});
#
#
# 	if (typeof window.joogle_globals === "undefined" || window.joogle_globals === null) {
# 		window.joogle_globals = {};
#
# 		window.joogle_globals.sonar = new (function () {
# 			// object for holding all sonar pieces
# 			this.handler_array = [];
# 			this.message_map = {};
# 			this.add_handler = function(handler) { this.handler_array.push(handler)};
# 			this.send = function(key, value) {
# 				this.message_map[key] = value;
# 				var data = { sonar_key: key, sonar_value: value };
# 				if (window.self !== window.top) {
# 					window.parent.postMessage(data, window.location.origin + window.location.pathname);
# 				}
# 				if (joogle_globals.sonar.handler_array !== undefined) {
# 					joogle_globals.sonar.call_handlers(data);
# 				}
# 			}
# 			this.call_handlers = function(data) {
# 				for (var i = 0; i < this.handler_array.length; i++) {
# 					this.handler_array[i](data);
# 				}
# 				this.call_text_receivers(data);
# 			}
# 			this.poll_message_map = function(key) {
# 				if (key in this.message_map) {
# 					return this.message_map[key];
# 				}
# 				else { return null};
# 			}
# 			this.add_one_time_ready_poller = function(key, func, vis) {
# 				/*
# 					Check if a sonar msg was sent before chart was ready, and run function.
# 					Can happen if a sender has been initialized with a value.
# 				*/
# 				google.visualization.events.addOneTimeListener(vis, "ready", function() {
# 					var result = joogle_globals.sonar.poll_message_map(key);
# 					if (result !== null) {
# 						func({"sonar_key": key, "sonar_value": result});
# 					}
# 				});
# 			}
# 			this.call_text_receivers = function (data) {
# 				$(".joogle_text_receiver").each(function() {
# 					var receiver = this;
# 					var key = receiver.dataset.key;
# 					var list_style = receiver.dataset.liststyle;
# 					var sub_text = data.sonar_value;
# 					var default_text = receiver.dataset.default;
# 					if (typeof default_text === "undefined") {
# 						default_text = "";
# 					}
# 					var clear_text = receiver.dataset.clear_text;
# 					if (sub_text.constructor !== Array) {
# 						sub_text = $.trim(sub_text);
# 						if (sub_text.length == 0) {
# 							sub_text = default_text;
# 						}
# 						sub_text = [sub_text];
# 					} else if (sub_text.length === 0) {
# 						sub_text = [default_text];
# 					}
# 					sub_text = joogle_globals.format_list_for_text_receiver(sub_text, list_style);
# 					if (key == data.sonar_key) {
# 						var template = receiver.dataset.template;
# 						template = template.replace("{}", sub_text);
# 						receiver.innerHTML = template;
# 					}
# 				})
# 			}
# 		})();
# 	}
#
# 	window.joogle_globals.format_list_for_text_receiver = function(arr, list_style) {
# 		if (list_style === "colloquial") {
# 			if (arr.length === 1) { return arr[0]; }
# 			var front = "";
# 			var back = "";
# 			var back_arr = arr.slice(arr.length - 2, arr.length);
# 			back = back_arr[0] + " and " + back_arr[1];
# 			if (arr.length > 2) {
# 				var front_arr = arr.slice(0, arr.length - 1);
# 				for (var i = 0; i < front_arr.length; i++) {
# 					front += front_arr[i] + ", ";
# 				}
# 			}
# 			return front + back;
# 		}
# 		else if (list_style === "parens") {
# 			return "(" + arr.join(", ") + ")";
# 		}
# 		else if (list_style === "brackets") {
# 			return "[" + arr.join(", ") + "]";
# 		}
# 	}
#
# 	window.joogle_globals.update_category_filter = function(filter, selected_values) {
# 		// utility function for updating Google Charts filter
# 		var filter_state = filter.getState();
# 		filter_state.selectedValues = selected_values;
# 		filter.setState(filter_state);
# 		filter.draw();
# 	}
# 	window.joogle_globals.update_range_filter = function(filter, range) {
# 		// utility function for updating Google Charts filter
# 		var filter_state = filter.getState();
# 		filter_state.lowValue = range[0];
# 		filter_state.highValue = range[1];
# 		filter_state.lowThumbAtMinimum = false; // buggy without this
# 		filter_state.highThumbAtMaximum = false;
# 		filter.setState(filter_state);
# 		filter.draw();
# 	}
# 	window.joogle_globals.update_filter_binding_selection = function(binding_values, data, filter, column, sending_keys) {
# 		// This method is used to update a custom bound filter when its controlling filter gets a selection.
#
#
# 		// Get the list of rows in the table produced by the controlling filter.
# 		var filtered_rows = [];
# 		if (binding_values.length == 0) {
# 			filtered_rows = null;
# 		}
# 		else {
# 			for (var i = 0; i < binding_values.length; i++) {
# 				var rows = data.getFilteredRows([{column: column, value: binding_values[i]}]);
# 				filtered_rows = $.merge(filtered_rows, rows);
# 			}
# 		}
#
# 		// (undocumented setView method on control wrappers)
# 		filter.setView({
# 			rows: filtered_rows
# 		});
# 		filter.draw();
#
# 		// The selected values on the bound filter will stay or get discarded when the
# 		// filter is redrawn with the binding values.  Set the values in the message map
# 		// with the current selected values.
# 		var selected_values = filter.getState().selectedValues;
# 		for (var i = 0; i < sending_keys.length; i++) {
# 			window.joogle_globals.sonar.message_map[sending_keys[i]] = selected_values;
# 		}
#
#
#
# 	}
# 	window.joogle_globals.update_chart = function(data, chartwrapper, view_cols, key_filter_list) {
# 		/*  This function updates a chart using values from all controlling sonar filters.
# 			The key_filter_list has the column and filter type for each key.  Get the value
# 			for that filter from the message_map.
# 		*/
#
# 		var no_filtered_values = true;
#
# 		var total_filtered_rows = [];
# 		for (var i = 0; i < key_filter_list.length; i++) {
# 			// get the list of rows filtered by each filter, and then get their intersection
#
# 			var key = key_filter_list[i].key;
# 			var type = key_filter_list[i].type;
# 			var values = window.joogle_globals.sonar.message_map[key];
# 			var column = key_filter_list[i].column;
#
# 			if (typeof values !== 'undefined' && values.length > 0) {
# 				// if we enter the loop, then at least one filter has a selection.
# 				no_filtered_values = false;
# 				if (type === "values") {
# 					filtered_rows = joogle_globals.get_rows_for_column_and_values(column, values, data);
# 				}
#
# 				else if (type === "range"){
# 					filtered_rows = data.getFilteredRows([{column: column, minValue: values[0], maxValue: values[1]}]);
# 				}
#
# 				if (total_filtered_rows.length == 0) { total_filtered_rows = filtered_rows;}
# 				else {
# 					// get the intersection of current rows and the latest list of filtered rows.
# 					total_filtered_rows = total_filtered_rows.filter(function(n) {
# 					  return filtered_rows.indexOf(n) > -1;
# 					});
# 				}
# 			}
# 		}
#
# 		// if the values sent be all the filters were empty, then show the whole chart.
# 		if (no_filtered_values) { total_filtered_rows = null};
#
# 		chartwrapper.setView({
# 			rows: total_filtered_rows,
# 			columns: view_cols
# 		});
# 		chartwrapper.draw();
# 	}
#
# 	window.joogle_globals.get_rows_for_column_and_values = function(column, selections, datatable) {
# 		// for a list of values and a column, get the row numbers that have those values.
# 		var rows_total = [];

# %% [markdown]
# ## ChartRow mode:  weighted
# To use weighted mode, pass a list of integers with the **weights** parameter.  The widths of the columns will be in the same proportion as the weights.

# %%
row = ChartRow(chart1, chart2, chart2, mode="weighted", weights = [3, 7, 15])

row.show()
# Out:
# <style>
#
# /*
# 	Setting overflow: scroll prevents buggy behavior in CategoryFilter dropdown
# 	that occurs when the list of menu options is very long.
# */
# .charts-menu {
#     overflow: scroll;
#     max-height: 250px;
# }
#
# .google-visualization-table .google-visualization-table-td-number {
# 	text-align: right;
# }
#
# .jooglechart_container {
# 	margin-bottom: 20px;
# }
#
# h1.jooglechart_global_title {
# 	font-size: 20px;
# 	font-weight: bold;
# 	margin-bottom:8px;
# }
#
#
# .joogle_clearfix:after {
#     content:" ";
#     display:block;
#     clear:both;
# }
#
# </style>
#
# <script>
#
# $(document).ready(function() {
#
# 	/* GLOBALS AREA >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> */
#
# 	window.addEventListener('message', function(message) {
# 		// listener for sonar message from iframe parent
# 		if (typeof message.data.msg !== "undefined" && typeof message.data.msg.sonar_key !== "undefined" &&
# 				typeof message.data.msg.sonar_value !== "undefined" &&
# 				message.data.originId !== message.data.destinationId) {
# 			if (joogle_globals.sonar.handler_array !== undefined) {
# 				joogle_globals.sonar.call_handlers(message.data.msg);
# 			}
# 		}
# 	});
#
#
# 	if (typeof window.joogle_globals === "undefined" || window.joogle_globals === null) {
# 		window.joogle_globals = {};
#
# 		window.joogle_globals.sonar = new (function () {
# 			// object for holding all sonar pieces
# 			this.handler_array = [];
# 			this.message_map = {};
# 			this.add_handler = function(handler) { this.handler_array.push(handler)};
# 			this.send = function(key, value) {
# 				this.message_map[key] = value;
# 				var data = { sonar_key: key, sonar_value: value };
# 				if (window.self !== window.top) {
# 					window.parent.postMessage(data, window.location.origin + window.location.pathname);
# 				}
# 				if (joogle_globals.sonar.handler_array !== undefined) {
# 					joogle_globals.sonar.call_handlers(data);
# 				}
# 			}
# 			this.call_handlers = function(data) {
# 				for (var i = 0; i < this.handler_array.length; i++) {
# 					this.handler_array[i](data);
# 				}
# 				this.call_text_receivers(data);
# 			}
# 			this.poll_message_map = function(key) {
# 				if (key in this.message_map) {
# 					return this.message_map[key];
# 				}
# 				else { return null};
# 			}
# 			this.add_one_time_ready_poller = function(key, func, vis) {
# 				/*
# 					Check if a sonar msg was sent before chart was ready, and run function.
# 					Can happen if a sender has been initialized with a value.
# 				*/
# 				google.visualization.events.addOneTimeListener(vis, "ready", function() {
# 					var result = joogle_globals.sonar.poll_message_map(key);
# 					if (result !== null) {
# 						func({"sonar_key": key, "sonar_value": result});
# 					}
# 				});
# 			}
# 			this.call_text_receivers = function (data) {
# 				$(".joogle_text_receiver").each(function() {
# 					var receiver = this;
# 					var key = receiver.dataset.key;
# 					var list_style = receiver.dataset.liststyle;
# 					var sub_text = data.sonar_value;
# 					var default_text = receiver.dataset.default;
# 					if (typeof default_text === "undefined") {
# 						default_text = "";
# 					}
# 					var clear_text = receiver.dataset.clear_text;
# 					if (sub_text.constructor !== Array) {
# 						sub_text = $.trim(sub_text);
# 						if (sub_text.length == 0) {
# 							sub_text = default_text;
# 						}
# 						sub_text = [sub_text];
# 					} else if (sub_text.length === 0) {
# 						sub_text = [default_text];
# 					}
# 					sub_text = joogle_globals.format_list_for_text_receiver(sub_text, list_style);
# 					if (key == data.sonar_key) {
# 						var template = receiver.dataset.template;
# 						template = template.replace("{}", sub_text);
# 						receiver.innerHTML = template;
# 					}
# 				})
# 			}
# 		})();
# 	}
#
# 	window.joogle_globals.format_list_for_text_receiver = function(arr, list_style) {
# 		if (list_style === "colloquial") {
# 			if (arr.length === 1) { return arr[0]; }
# 			var front = "";
# 			var back = "";
# 			var back_arr = arr.slice(arr.length - 2, arr.length);
# 			back = back_arr[0] + " and " + back_arr[1];
# 			if (arr.length > 2) {
# 				var front_arr = arr.slice(0, arr.length - 1);
# 				for (var i = 0; i < front_arr.length; i++) {
# 					front += front_arr[i] + ", ";
# 				}
# 			}
# 			return front + back;
# 		}
# 		else if (list_style === "parens") {
# 			return "(" + arr.join(", ") + ")";
# 		}
# 		else if (list_style === "brackets") {
# 			return "[" + arr.join(", ") + "]";
# 		}
# 	}
#
# 	window.joogle_globals.update_category_filter = function(filter, selected_values) {
# 		// utility function for updating Google Charts filter
# 		var filter_state = filter.getState();
# 		filter_state.selectedValues = selected_values;
# 		filter.setState(filter_state);
# 		filter.draw();
# 	}
# 	window.joogle_globals.update_range_filter = function(filter, range) {
# 		// utility function for updating Google Charts filter
# 		var filter_state = filter.getState();
# 		filter_state.lowValue = range[0];
# 		filter_state.highValue = range[1];
# 		filter_state.lowThumbAtMinimum = false; // buggy without this
# 		filter_state.highThumbAtMaximum = false;
# 		filter.setState(filter_state);
# 		filter.draw();
# 	}
# 	window.joogle_globals.update_filter_binding_selection = function(binding_values, data, filter, column, sending_keys) {
# 		// This method is used to update a custom bound filter when its controlling filter gets a selection.
#
#
# 		// Get the list of rows in the table produced by the controlling filter.
# 		var filtered_rows = [];
# 		if (binding_values.length == 0) {
# 			filtered_rows = null;
# 		}
# 		else {
# 			for (var i = 0; i < binding_values.length; i++) {
# 				var rows = data.getFilteredRows([{column: column, value: binding_values[i]}]);
# 				filtered_rows = $.merge(filtered_rows, rows);
# 			}
# 		}
#
# 		// (undocumented setView method on control wrappers)
# 		filter.setView({
# 			rows: filtered_rows
# 		});
# 		filter.draw();
#
# 		// The selected values on the bound filter will stay or get discarded when the
# 		// filter is redrawn with the binding values.  Set the values in the message map
# 		// with the current selected values.
# 		var selected_values = filter.getState().selectedValues;
# 		for (var i = 0; i < sending_keys.length; i++) {
# 			window.joogle_globals.sonar.message_map[sending_keys[i]] = selected_values;
# 		}
#
#
#
# 	}
# 	window.joogle_globals.update_chart = function(data, chartwrapper, view_cols, key_filter_list) {
# 		/*  This function updates a chart using values from all controlling sonar filters.
# 			The key_filter_list has the column and filter type for each key.  Get the value
# 			for that filter from the message_map.
# 		*/
#
# 		var no_filtered_values = true;
#
# 		var total_filtered_rows = [];
# 		for (var i = 0; i < key_filter_list.length; i++) {
# 			// get the list of rows filtered by each filter, and then get their intersection
#
# 			var key = key_filter_list[i].key;
# 			var type = key_filter_list[i].type;
# 			var values = window.joogle_globals.sonar.message_map[key];
# 			var column = key_filter_list[i].column;
#
# 			if (typeof values !== 'undefined' && values.length > 0) {
# 				// if we enter the loop, then at least one filter has a selection.
# 				no_filtered_values = false;
# 				if (type === "values") {
# 					filtered_rows = joogle_globals.get_rows_for_column_and_values(column, values, data);
# 				}
#
# 				else if (type === "range"){
# 					filtered_rows = data.getFilteredRows([{column: column, minValue: values[0], maxValue: values[1]}]);
# 				}
#
# 				if (total_filtered_rows.length == 0) { total_filtered_rows = filtered_rows;}
# 				else {
# 					// get the intersection of current rows and the latest list of filtered rows.
# 					total_filtered_rows = total_filtered_rows.filter(function(n) {
# 					  return filtered_rows.indexOf(n) > -1;
# 					});
# 				}
# 			}
# 		}
#
# 		// if the values sent be all the filters were empty, then show the whole chart.
# 		if (no_filtered_values) { total_filtered_rows = null};
#
# 		chartwrapper.setView({
# 			rows: total_filtered_rows,
# 			columns: view_cols
# 		});
# 		chartwrapper.draw();
# 	}
#
# 	window.joogle_globals.get_rows_for_column_and_values = function(column, selections, datatable) {
# 		// for a list of values and a column, get the row numbers that have those values.
# 		var rows_total = [];

# %% [markdown]
# ## ChartRow mode: fixed
# In fixed mode, you specify the exact widths of the columns, passed with the **widths** parameter.  A width can be specified
# as an integer in pixels.  Or, it can be specified as a string of a valid css width.  For example: **widths = [300, "250px", "10em"]**

# %%
row = ChartRow(chart1, chart2, chart2, mode="weighted", weights = [100, 200, 300])

row.show()
# Out:
# <style>
#
# /*
# 	Setting overflow: scroll prevents buggy behavior in CategoryFilter dropdown
# 	that occurs when the list of menu options is very long.
# */
# .charts-menu {
#     overflow: scroll;
#     max-height: 250px;
# }
#
# .google-visualization-table .google-visualization-table-td-number {
# 	text-align: right;
# }
#
# .jooglechart_container {
# 	margin-bottom: 20px;
# }
#
# h1.jooglechart_global_title {
# 	font-size: 20px;
# 	font-weight: bold;
# 	margin-bottom:8px;
# }
#
#
# .joogle_clearfix:after {
#     content:" ";
#     display:block;
#     clear:both;
# }
#
# </style>
#
# <script>
#
# $(document).ready(function() {
#
# 	/* GLOBALS AREA >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> */
#
# 	window.addEventListener('message', function(message) {
# 		// listener for sonar message from iframe parent
# 		if (typeof message.data.msg !== "undefined" && typeof message.data.msg.sonar_key !== "undefined" &&
# 				typeof message.data.msg.sonar_value !== "undefined" &&
# 				message.data.originId !== message.data.destinationId) {
# 			if (joogle_globals.sonar.handler_array !== undefined) {
# 				joogle_globals.sonar.call_handlers(message.data.msg);
# 			}
# 		}
# 	});
#
#
# 	if (typeof window.joogle_globals === "undefined" || window.joogle_globals === null) {
# 		window.joogle_globals = {};
#
# 		window.joogle_globals.sonar = new (function () {
# 			// object for holding all sonar pieces
# 			this.handler_array = [];
# 			this.message_map = {};
# 			this.add_handler = function(handler) { this.handler_array.push(handler)};
# 			this.send = function(key, value) {
# 				this.message_map[key] = value;
# 				var data = { sonar_key: key, sonar_value: value };
# 				if (window.self !== window.top) {
# 					window.parent.postMessage(data, window.location.origin + window.location.pathname);
# 				}
# 				if (joogle_globals.sonar.handler_array !== undefined) {
# 					joogle_globals.sonar.call_handlers(data);
# 				}
# 			}
# 			this.call_handlers = function(data) {
# 				for (var i = 0; i < this.handler_array.length; i++) {
# 					this.handler_array[i](data);
# 				}
# 				this.call_text_receivers(data);
# 			}
# 			this.poll_message_map = function(key) {
# 				if (key in this.message_map) {
# 					return this.message_map[key];
# 				}
# 				else { return null};
# 			}
# 			this.add_one_time_ready_poller = function(key, func, vis) {
# 				/*
# 					Check if a sonar msg was sent before chart was ready, and run function.
# 					Can happen if a sender has been initialized with a value.
# 				*/
# 				google.visualization.events.addOneTimeListener(vis, "ready", function() {
# 					var result = joogle_globals.sonar.poll_message_map(key);
# 					if (result !== null) {
# 						func({"sonar_key": key, "sonar_value": result});
# 					}
# 				});
# 			}
# 			this.call_text_receivers = function (data) {
# 				$(".joogle_text_receiver").each(function() {
# 					var receiver = this;
# 					var key = receiver.dataset.key;
# 					var list_style = receiver.dataset.liststyle;
# 					var sub_text = data.sonar_value;
# 					var default_text = receiver.dataset.default;
# 					if (typeof default_text === "undefined") {
# 						default_text = "";
# 					}
# 					var clear_text = receiver.dataset.clear_text;
# 					if (sub_text.constructor !== Array) {
# 						sub_text = $.trim(sub_text);
# 						if (sub_text.length == 0) {
# 							sub_text = default_text;
# 						}
# 						sub_text = [sub_text];
# 					} else if (sub_text.length === 0) {
# 						sub_text = [default_text];
# 					}
# 					sub_text = joogle_globals.format_list_for_text_receiver(sub_text, list_style);
# 					if (key == data.sonar_key) {
# 						var template = receiver.dataset.template;
# 						template = template.replace("{}", sub_text);
# 						receiver.innerHTML = template;
# 					}
# 				})
# 			}
# 		})();
# 	}
#
# 	window.joogle_globals.format_list_for_text_receiver = function(arr, list_style) {
# 		if (list_style === "colloquial") {
# 			if (arr.length === 1) { return arr[0]; }
# 			var front = "";
# 			var back = "";
# 			var back_arr = arr.slice(arr.length - 2, arr.length);
# 			back = back_arr[0] + " and " + back_arr[1];
# 			if (arr.length > 2) {
# 				var front_arr = arr.slice(0, arr.length - 1);
# 				for (var i = 0; i < front_arr.length; i++) {
# 					front += front_arr[i] + ", ";
# 				}
# 			}
# 			return front + back;
# 		}
# 		else if (list_style === "parens") {
# 			return "(" + arr.join(", ") + ")";
# 		}
# 		else if (list_style === "brackets") {
# 			return "[" + arr.join(", ") + "]";
# 		}
# 	}
#
# 	window.joogle_globals.update_category_filter = function(filter, selected_values) {
# 		// utility function for updating Google Charts filter
# 		var filter_state = filter.getState();
# 		filter_state.selectedValues = selected_values;
# 		filter.setState(filter_state);
# 		filter.draw();
# 	}
# 	window.joogle_globals.update_range_filter = function(filter, range) {
# 		// utility function for updating Google Charts filter
# 		var filter_state = filter.getState();
# 		filter_state.lowValue = range[0];
# 		filter_state.highValue = range[1];
# 		filter_state.lowThumbAtMinimum = false; // buggy without this
# 		filter_state.highThumbAtMaximum = false;
# 		filter.setState(filter_state);
# 		filter.draw();
# 	}
# 	window.joogle_globals.update_filter_binding_selection = function(binding_values, data, filter, column, sending_keys) {
# 		// This method is used to update a custom bound filter when its controlling filter gets a selection.
#
#
# 		// Get the list of rows in the table produced by the controlling filter.
# 		var filtered_rows = [];
# 		if (binding_values.length == 0) {
# 			filtered_rows = null;
# 		}
# 		else {
# 			for (var i = 0; i < binding_values.length; i++) {
# 				var rows = data.getFilteredRows([{column: column, value: binding_values[i]}]);
# 				filtered_rows = $.merge(filtered_rows, rows);
# 			}
# 		}
#
# 		// (undocumented setView method on control wrappers)
# 		filter.setView({
# 			rows: filtered_rows
# 		});
# 		filter.draw();
#
# 		// The selected values on the bound filter will stay or get discarded when the
# 		// filter is redrawn with the binding values.  Set the values in the message map
# 		// with the current selected values.
# 		var selected_values = filter.getState().selectedValues;
# 		for (var i = 0; i < sending_keys.length; i++) {
# 			window.joogle_globals.sonar.message_map[sending_keys[i]] = selected_values;
# 		}
#
#
#
# 	}
# 	window.joogle_globals.update_chart = function(data, chartwrapper, view_cols, key_filter_list) {
# 		/*  This function updates a chart using values from all controlling sonar filters.
# 			The key_filter_list has the column and filter type for each key.  Get the value
# 			for that filter from the message_map.
# 		*/
#
# 		var no_filtered_values = true;
#
# 		var total_filtered_rows = [];
# 		for (var i = 0; i < key_filter_list.length; i++) {
# 			// get the list of rows filtered by each filter, and then get their intersection
#
# 			var key = key_filter_list[i].key;
# 			var type = key_filter_list[i].type;
# 			var values = window.joogle_globals.sonar.message_map[key];
# 			var column = key_filter_list[i].column;
#
# 			if (typeof values !== 'undefined' && values.length > 0) {
# 				// if we enter the loop, then at least one filter has a selection.
# 				no_filtered_values = false;
# 				if (type === "values") {
# 					filtered_rows = joogle_globals.get_rows_for_column_and_values(column, values, data);
# 				}
#
# 				else if (type === "range"){
# 					filtered_rows = data.getFilteredRows([{column: column, minValue: values[0], maxValue: values[1]}]);
# 				}
#
# 				if (total_filtered_rows.length == 0) { total_filtered_rows = filtered_rows;}
# 				else {
# 					// get the intersection of current rows and the latest list of filtered rows.
# 					total_filtered_rows = total_filtered_rows.filter(function(n) {
# 					  return filtered_rows.indexOf(n) > -1;
# 					});
# 				}
# 			}
# 		}
#
# 		// if the values sent be all the filters were empty, then show the whole chart.
# 		if (no_filtered_values) { total_filtered_rows = null};
#
# 		chartwrapper.setView({
# 			rows: total_filtered_rows,
# 			columns: view_cols
# 		});
# 		chartwrapper.draw();
# 	}
#
# 	window.joogle_globals.get_rows_for_column_and_values = function(column, selections, datatable) {
# 		// for a list of values and a column, get the row numbers that have those values.
# 		var rows_total = [];

# %% [markdown]
# # add_div_styles<a name="div_styles"></a>
# CSS styles can be added to containers with the **add_div_styles** method.  Here's a silly example.

# %%
row = ChartRow(chart1, chart2, chart2, padding=10) # padding allows the background color show between charts
styles = {}
styles['border'] = "10px dashed pink"
styles['background-color'] = "red"
row.add_div_styles(styles)

row.show()
# Out:
# <style>
#
# /*
# 	Setting overflow: scroll prevents buggy behavior in CategoryFilter dropdown
# 	that occurs when the list of menu options is very long.
# */
# .charts-menu {
#     overflow: scroll;
#     max-height: 250px;
# }
#
# .google-visualization-table .google-visualization-table-td-number {
# 	text-align: right;
# }
#
# .jooglechart_container {
# 	margin-bottom: 20px;
# }
#
# h1.jooglechart_global_title {
# 	font-size: 20px;
# 	font-weight: bold;
# 	margin-bottom:8px;
# }
#
#
# .joogle_clearfix:after {
#     content:" ";
#     display:block;
#     clear:both;
# }
#
# </style>
#
# <script>
#
# $(document).ready(function() {
#
# 	/* GLOBALS AREA >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> */
#
# 	window.addEventListener('message', function(message) {
# 		// listener for sonar message from iframe parent
# 		if (typeof message.data.msg !== "undefined" && typeof message.data.msg.sonar_key !== "undefined" &&
# 				typeof message.data.msg.sonar_value !== "undefined" &&
# 				message.data.originId !== message.data.destinationId) {
# 			if (joogle_globals.sonar.handler_array !== undefined) {
# 				joogle_globals.sonar.call_handlers(message.data.msg);
# 			}
# 		}
# 	});
#
#
# 	if (typeof window.joogle_globals === "undefined" || window.joogle_globals === null) {
# 		window.joogle_globals = {};
#
# 		window.joogle_globals.sonar = new (function () {
# 			// object for holding all sonar pieces
# 			this.handler_array = [];
# 			this.message_map = {};
# 			this.add_handler = function(handler) { this.handler_array.push(handler)};
# 			this.send = function(key, value) {
# 				this.message_map[key] = value;
# 				var data = { sonar_key: key, sonar_value: value };
# 				if (window.self !== window.top) {
# 					window.parent.postMessage(data, window.location.origin + window.location.pathname);
# 				}
# 				if (joogle_globals.sonar.handler_array !== undefined) {
# 					joogle_globals.sonar.call_handlers(data);
# 				}
# 			}
# 			this.call_handlers = function(data) {
# 				for (var i = 0; i < this.handler_array.length; i++) {
# 					this.handler_array[i](data);
# 				}
# 				this.call_text_receivers(data);
# 			}
# 			this.poll_message_map = function(key) {
# 				if (key in this.message_map) {
# 					return this.message_map[key];
# 				}
# 				else { return null};
# 			}
# 			this.add_one_time_ready_poller = function(key, func, vis) {
# 				/*
# 					Check if a sonar msg was sent before chart was ready, and run function.
# 					Can happen if a sender has been initialized with a value.
# 				*/
# 				google.visualization.events.addOneTimeListener(vis, "ready", function() {
# 					var result = joogle_globals.sonar.poll_message_map(key);
# 					if (result !== null) {
# 						func({"sonar_key": key, "sonar_value": result});
# 					}
# 				});
# 			}
# 			this.call_text_receivers = function (data) {
# 				$(".joogle_text_receiver").each(function() {
# 					var receiver = this;
# 					var key = receiver.dataset.key;
# 					var list_style = receiver.dataset.liststyle;
# 					var sub_text = data.sonar_value;
# 					var default_text = receiver.dataset.default;
# 					if (typeof default_text === "undefined") {
# 						default_text = "";
# 					}
# 					var clear_text = receiver.dataset.clear_text;
# 					if (sub_text.constructor !== Array) {
# 						sub_text = $.trim(sub_text);
# 						if (sub_text.length == 0) {
# 							sub_text = default_text;
# 						}
# 						sub_text = [sub_text];
# 					} else if (sub_text.length === 0) {
# 						sub_text = [default_text];
# 					}
# 					sub_text = joogle_globals.format_list_for_text_receiver(sub_text, list_style);
# 					if (key == data.sonar_key) {
# 						var template = receiver.dataset.template;
# 						template = template.replace("{}", sub_text);
# 						receiver.innerHTML = template;
# 					}
# 				})
# 			}
# 		})();
# 	}
#
# 	window.joogle_globals.format_list_for_text_receiver = function(arr, list_style) {
# 		if (list_style === "colloquial") {
# 			if (arr.length === 1) { return arr[0]; }
# 			var front = "";
# 			var back = "";
# 			var back_arr = arr.slice(arr.length - 2, arr.length);
# 			back = back_arr[0] + " and " + back_arr[1];
# 			if (arr.length > 2) {
# 				var front_arr = arr.slice(0, arr.length - 1);
# 				for (var i = 0; i < front_arr.length; i++) {
# 					front += front_arr[i] + ", ";
# 				}
# 			}
# 			return front + back;
# 		}
# 		else if (list_style === "parens") {
# 			return "(" + arr.join(", ") + ")";
# 		}
# 		else if (list_style === "brackets") {
# 			return "[" + arr.join(", ") + "]";
# 		}
# 	}
#
# 	window.joogle_globals.update_category_filter = function(filter, selected_values) {
# 		// utility function for updating Google Charts filter
# 		var filter_state = filter.getState();
# 		filter_state.selectedValues = selected_values;
# 		filter.setState(filter_state);
# 		filter.draw();
# 	}
# 	window.joogle_globals.update_range_filter = function(filter, range) {
# 		// utility function for updating Google Charts filter
# 		var filter_state = filter.getState();
# 		filter_state.lowValue = range[0];
# 		filter_state.highValue = range[1];
# 		filter_state.lowThumbAtMinimum = false; // buggy without this
# 		filter_state.highThumbAtMaximum = false;
# 		filter.setState(filter_state);
# 		filter.draw();
# 	}
# 	window.joogle_globals.update_filter_binding_selection = function(binding_values, data, filter, column, sending_keys) {
# 		// This method is used to update a custom bound filter when its controlling filter gets a selection.
#
#
# 		// Get the list of rows in the table produced by the controlling filter.
# 		var filtered_rows = [];
# 		if (binding_values.length == 0) {
# 			filtered_rows = null;
# 		}
# 		else {
# 			for (var i = 0; i < binding_values.length; i++) {
# 				var rows = data.getFilteredRows([{column: column, value: binding_values[i]}]);
# 				filtered_rows = $.merge(filtered_rows, rows);
# 			}
# 		}
#
# 		// (undocumented setView method on control wrappers)
# 		filter.setView({
# 			rows: filtered_rows
# 		});
# 		filter.draw();
#
# 		// The selected values on the bound filter will stay or get discarded when the
# 		// filter is redrawn with the binding values.  Set the values in the message map
# 		// with the current selected values.
# 		var selected_values = filter.getState().selectedValues;
# 		for (var i = 0; i < sending_keys.length; i++) {
# 			window.joogle_globals.sonar.message_map[sending_keys[i]] = selected_values;
# 		}
#
#
#
# 	}
# 	window.joogle_globals.update_chart = function(data, chartwrapper, view_cols, key_filter_list) {
# 		/*  This function updates a chart using values from all controlling sonar filters.
# 			The key_filter_list has the column and filter type for each key.  Get the value
# 			for that filter from the message_map.
# 		*/
#
# 		var no_filtered_values = true;
#
# 		var total_filtered_rows = [];
# 		for (var i = 0; i < key_filter_list.length; i++) {
# 			// get the list of rows filtered by each filter, and then get their intersection
#
# 			var key = key_filter_list[i].key;
# 			var type = key_filter_list[i].type;
# 			var values = window.joogle_globals.sonar.message_map[key];
# 			var column = key_filter_list[i].column;
#
# 			if (typeof values !== 'undefined' && values.length > 0) {
# 				// if we enter the loop, then at least one filter has a selection.
# 				no_filtered_values = false;
# 				if (type === "values") {
# 					filtered_rows = joogle_globals.get_rows_for_column_and_values(column, values, data);
# 				}
#
# 				else if (type === "range"){
# 					filtered_rows = data.getFilteredRows([{column: column, minValue: values[0], maxValue: values[1]}]);
# 				}
#
# 				if (total_filtered_rows.length == 0) { total_filtered_rows = filtered_rows;}
# 				else {
# 					// get the intersection of current rows and the latest list of filtered rows.
# 					total_filtered_rows = total_filtered_rows.filter(function(n) {
# 					  return filtered_rows.indexOf(n) > -1;
# 					});
# 				}
# 			}
# 		}
#
# 		// if the values sent be all the filters were empty, then show the whole chart.
# 		if (no_filtered_values) { total_filtered_rows = null};
#
# 		chartwrapper.setView({
# 			rows: total_filtered_rows,
# 			columns: view_cols
# 		});
# 		chartwrapper.draw();
# 	}
#
# 	window.joogle_globals.get_rows_for_column_and_values = function(column, selections, datatable) {
# 		// for a list of values and a column, get the row numbers that have those values.
# 		var rows_total = [];

# %% [markdown]
# # Box<a name="Box"></a>
# The Box is a vertical stacking container.  Just pass in the objects to be displayed and call the **.show()** method.
#
# For this example, we'll put two charts in a box, and put the box in a row with another chart.  (Box with two charts by itself just looks like two charts displayed on their own.)

# %%
from jooglechart.widgets import Box

# %%
chart2.add_chart_options(height=500, chartArea_height=400, title="Look at me!")

box = Box(chart1, chart3)
row = ChartRow(box, chart2, mode="fixed", widths=[400, 400])
row.show()
# Out:
# <style>
#
# /*
# 	Setting overflow: scroll prevents buggy behavior in CategoryFilter dropdown
# 	that occurs when the list of menu options is very long.
# */
# .charts-menu {
#     overflow: scroll;
#     max-height: 250px;
# }
#
# .google-visualization-table .google-visualization-table-td-number {
# 	text-align: right;
# }
#
# .jooglechart_container {
# 	margin-bottom: 20px;
# }
#
# h1.jooglechart_global_title {
# 	font-size: 20px;
# 	font-weight: bold;
# 	margin-bottom:8px;
# }
#
#
# .joogle_clearfix:after {
#     content:" ";
#     display:block;
#     clear:both;
# }
#
# </style>
#
# <script>
#
# $(document).ready(function() {
#
# 	/* GLOBALS AREA >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> */
#
# 	window.addEventListener('message', function(message) {
# 		// listener for sonar message from iframe parent
# 		if (typeof message.data.msg !== "undefined" && typeof message.data.msg.sonar_key !== "undefined" &&
# 				typeof message.data.msg.sonar_value !== "undefined" &&
# 				message.data.originId !== message.data.destinationId) {
# 			if (joogle_globals.sonar.handler_array !== undefined) {
# 				joogle_globals.sonar.call_handlers(message.data.msg);
# 			}
# 		}
# 	});
#
#
# 	if (typeof window.joogle_globals === "undefined" || window.joogle_globals === null) {
# 		window.joogle_globals = {};
#
# 		window.joogle_globals.sonar = new (function () {
# 			// object for holding all sonar pieces
# 			this.handler_array = [];
# 			this.message_map = {};
# 			this.add_handler = function(handler) { this.handler_array.push(handler)};
# 			this.send = function(key, value) {
# 				this.message_map[key] = value;
# 				var data = { sonar_key: key, sonar_value: value };
# 				if (window.self !== window.top) {
# 					window.parent.postMessage(data, window.location.origin + window.location.pathname);
# 				}
# 				if (joogle_globals.sonar.handler_array !== undefined) {
# 					joogle_globals.sonar.call_handlers(data);
# 				}
# 			}
# 			this.call_handlers = function(data) {
# 				for (var i = 0; i < this.handler_array.length; i++) {
# 					this.handler_array[i](data);
# 				}
# 				this.call_text_receivers(data);
# 			}
# 			this.poll_message_map = function(key) {
# 				if (key in this.message_map) {
# 					return this.message_map[key];
# 				}
# 				else { return null};
# 			}
# 			this.add_one_time_ready_poller = function(key, func, vis) {
# 				/*
# 					Check if a sonar msg was sent before chart was ready, and run function.
# 					Can happen if a sender has been initialized with a value.
# 				*/
# 				google.visualization.events.addOneTimeListener(vis, "ready", function() {
# 					var result = joogle_globals.sonar.poll_message_map(key);
# 					if (result !== null) {
# 						func({"sonar_key": key, "sonar_value": result});
# 					}
# 				});
# 			}
# 			this.call_text_receivers = function (data) {
# 				$(".joogle_text_receiver").each(function() {
# 					var receiver = this;
# 					var key = receiver.dataset.key;
# 					var list_style = receiver.dataset.liststyle;
# 					var sub_text = data.sonar_value;
# 					var default_text = receiver.dataset.default;
# 					if (typeof default_text === "undefined") {
# 						default_text = "";
# 					}
# 					var clear_text = receiver.dataset.clear_text;
# 					if (sub_text.constructor !== Array) {
# 						sub_text = $.trim(sub_text);
# 						if (sub_text.length == 0) {
# 							sub_text = default_text;
# 						}
# 						sub_text = [sub_text];
# 					} else if (sub_text.length === 0) {
# 						sub_text = [default_text];
# 					}
# 					sub_text = joogle_globals.format_list_for_text_receiver(sub_text, list_style);
# 					if (key == data.sonar_key) {
# 						var template = receiver.dataset.template;
# 						template = template.replace("{}", sub_text);
# 						receiver.innerHTML = template;
# 					}
# 				})
# 			}
# 		})();
# 	}
#
# 	window.joogle_globals.format_list_for_text_receiver = function(arr, list_style) {
# 		if (list_style === "colloquial") {
# 			if (arr.length === 1) { return arr[0]; }
# 			var front = "";
# 			var back = "";
# 			var back_arr = arr.slice(arr.length - 2, arr.length);
# 			back = back_arr[0] + " and " + back_arr[1];
# 			if (arr.length > 2) {
# 				var front_arr = arr.slice(0, arr.length - 1);
# 				for (var i = 0; i < front_arr.length; i++) {
# 					front += front_arr[i] + ", ";
# 				}
# 			}
# 			return front + back;
# 		}
# 		else if (list_style === "parens") {
# 			return "(" + arr.join(", ") + ")";
# 		}
# 		else if (list_style === "brackets") {
# 			return "[" + arr.join(", ") + "]";
# 		}
# 	}
#
# 	window.joogle_globals.update_category_filter = function(filter, selected_values) {
# 		// utility function for updating Google Charts filter
# 		var filter_state = filter.getState();
# 		filter_state.selectedValues = selected_values;
# 		filter.setState(filter_state);
# 		filter.draw();
# 	}
# 	window.joogle_globals.update_range_filter = function(filter, range) {
# 		// utility function for updating Google Charts filter
# 		var filter_state = filter.getState();
# 		filter_state.lowValue = range[0];
# 		filter_state.highValue = range[1];
# 		filter_state.lowThumbAtMinimum = false; // buggy without this
# 		filter_state.highThumbAtMaximum = false;
# 		filter.setState(filter_state);
# 		filter.draw();
# 	}
# 	window.joogle_globals.update_filter_binding_selection = function(binding_values, data, filter, column, sending_keys) {
# 		// This method is used to update a custom bound filter when its controlling filter gets a selection.
#
#
# 		// Get the list of rows in the table produced by the controlling filter.
# 		var filtered_rows = [];
# 		if (binding_values.length == 0) {
# 			filtered_rows = null;
# 		}
# 		else {
# 			for (var i = 0; i < binding_values.length; i++) {
# 				var rows = data.getFilteredRows([{column: column, value: binding_values[i]}]);
# 				filtered_rows = $.merge(filtered_rows, rows);
# 			}
# 		}
#
# 		// (undocumented setView method on control wrappers)
# 		filter.setView({
# 			rows: filtered_rows
# 		});
# 		filter.draw();
#
# 		// The selected values on the bound filter will stay or get discarded when the
# 		// filter is redrawn with the binding values.  Set the values in the message map
# 		// with the current selected values.
# 		var selected_values = filter.getState().selectedValues;
# 		for (var i = 0; i < sending_keys.length; i++) {
# 			window.joogle_globals.sonar.message_map[sending_keys[i]] = selected_values;
# 		}
#
#
#
# 	}
# 	window.joogle_globals.update_chart = function(data, chartwrapper, view_cols, key_filter_list) {
# 		/*  This function updates a chart using values from all controlling sonar filters.
# 			The key_filter_list has the column and filter type for each key.  Get the value
# 			for that filter from the message_map.
# 		*/
#
# 		var no_filtered_values = true;
#
# 		var total_filtered_rows = [];
# 		for (var i = 0; i < key_filter_list.length; i++) {
# 			// get the list of rows filtered by each filter, and then get their intersection
#
# 			var key = key_filter_list[i].key;
# 			var type = key_filter_list[i].type;
# 			var values = window.joogle_globals.sonar.message_map[key];
# 			var column = key_filter_list[i].column;
#
# 			if (typeof values !== 'undefined' && values.length > 0) {
# 				// if we enter the loop, then at least one filter has a selection.
# 				no_filtered_values = false;
# 				if (type === "values") {
# 					filtered_rows = joogle_globals.get_rows_for_column_and_values(column, values, data);
# 				}
#
# 				else if (type === "range"){
# 					filtered_rows = data.getFilteredRows([{column: column, minValue: values[0], maxValue: values[1]}]);
# 				}
#
# 				if (total_filtered_rows.length == 0) { total_filtered_rows = filtered_rows;}
# 				else {
# 					// get the intersection of current rows and the latest list of filtered rows.
# 					total_filtered_rows = total_filtered_rows.filter(function(n) {
# 					  return filtered_rows.indexOf(n) > -1;
# 					});
# 				}
# 			}
# 		}
#
# 		// if the values sent be all the filters were empty, then show the whole chart.
# 		if (no_filtered_values) { total_filtered_rows = null};
#
# 		chartwrapper.setView({
# 			rows: total_filtered_rows,
# 			columns: view_cols
# 		});
# 		chartwrapper.draw();
# 	}
#
# 	window.joogle_globals.get_rows_for_column_and_values = function(column, selections, datatable) {
# 		// for a list of values and a column, get the row numbers that have those values.
# 		var rows_total = [];

# %% [markdown]
# # Using Markdown with Jooglecharts<a name="Markdown"></a>
# Dashboard design possibilities can be expanded with markdown.  Since Jooglechart containers take strings, markdown can be used when combined with the Python library **markdown**, which is part of the standard library.  No additional package needs to be installed.
#
# The Python library implements John Gruber’s [Markdown](http://daringfireball.net/projects/markdown/).

# %%
from markdown import markdown as md

# %%
df = get_df()

chart = JoogleChart(df)
chart.add_chart_options(legend_position="top")

side_bar = """
## Morbi Convallis

Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nulla consectetur ante vel condimentum porttitor.
Vivamus luctus augue in erat lobortis, sed interdum nunc hendrerit. Nunc consectetur, dui eu fringilla 
consectetur, nunc lorem accumsan lacus, ac varius erat velit ac massa. Donec fringilla metus in vestibulum feugiat. 
Sed vitae efficitur risus.

#### Praesent pellentesque
- Eget volutpat mauris
- Duis sapien nulla
- Purus vitae elementum hendrerit
"""

caption = """
*Nulla dapibus elementum massa, ut iaculis neque pellentesque ac. 
Curabitur in erat ut nunc tempor fermentum a non dui. Nam sit amet 
tortor facilisis, elementum enim pharetra, tincidunt nibh.*
"""

# pass the strings to the markdown function before putting them in a container
box = Box(chart, md(caption))
row = ChartRow(md(side_bar), box)
row.add_div_styles(width="800px")
row.show()
# Out:
# <style>
#
# /*
# 	Setting overflow: scroll prevents buggy behavior in CategoryFilter dropdown
# 	that occurs when the list of menu options is very long.
# */
# .charts-menu {
#     overflow: scroll;
#     max-height: 250px;
# }
#
# .google-visualization-table .google-visualization-table-td-number {
# 	text-align: right;
# }
#
# .jooglechart_container {
# 	margin-bottom: 20px;
# }
#
# h1.jooglechart_global_title {
# 	font-size: 20px;
# 	font-weight: bold;
# 	margin-bottom:8px;
# }
#
#
# .joogle_clearfix:after {
#     content:" ";
#     display:block;
#     clear:both;
# }
#
# </style>
#
# <script>
#
# $(document).ready(function() {
#
# 	/* GLOBALS AREA >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> */
#
# 	window.addEventListener('message', function(message) {
# 		// listener for sonar message from iframe parent
# 		if (typeof message.data.msg !== "undefined" && typeof message.data.msg.sonar_key !== "undefined" &&
# 				typeof message.data.msg.sonar_value !== "undefined" &&
# 				message.data.originId !== message.data.destinationId) {
# 			if (joogle_globals.sonar.handler_array !== undefined) {
# 				joogle_globals.sonar.call_handlers(message.data.msg);
# 			}
# 		}
# 	});
#
#
# 	if (typeof window.joogle_globals === "undefined" || window.joogle_globals === null) {
# 		window.joogle_globals = {};
#
# 		window.joogle_globals.sonar = new (function () {
# 			// object for holding all sonar pieces
# 			this.handler_array = [];
# 			this.message_map = {};
# 			this.add_handler = function(handler) { this.handler_array.push(handler)};
# 			this.send = function(key, value) {
# 				this.message_map[key] = value;
# 				var data = { sonar_key: key, sonar_value: value };
# 				if (window.self !== window.top) {
# 					window.parent.postMessage(data, window.location.origin + window.location.pathname);
# 				}
# 				if (joogle_globals.sonar.handler_array !== undefined) {
# 					joogle_globals.sonar.call_handlers(data);
# 				}
# 			}
# 			this.call_handlers = function(data) {
# 				for (var i = 0; i < this.handler_array.length; i++) {
# 					this.handler_array[i](data);
# 				}
# 				this.call_text_receivers(data);
# 			}
# 			this.poll_message_map = function(key) {
# 				if (key in this.message_map) {
# 					return this.message_map[key];
# 				}
# 				else { return null};
# 			}
# 			this.add_one_time_ready_poller = function(key, func, vis) {
# 				/*
# 					Check if a sonar msg was sent before chart was ready, and run function.
# 					Can happen if a sender has been initialized with a value.
# 				*/
# 				google.visualization.events.addOneTimeListener(vis, "ready", function() {
# 					var result = joogle_globals.sonar.poll_message_map(key);
# 					if (result !== null) {
# 						func({"sonar_key": key, "sonar_value": result});
# 					}
# 				});
# 			}
# 			this.call_text_receivers = function (data) {
# 				$(".joogle_text_receiver").each(function() {
# 					var receiver = this;
# 					var key = receiver.dataset.key;
# 					var list_style = receiver.dataset.liststyle;
# 					var sub_text = data.sonar_value;
# 					var default_text = receiver.dataset.default;
# 					if (typeof default_text === "undefined") {
# 						default_text = "";
# 					}
# 					var clear_text = receiver.dataset.clear_text;
# 					if (sub_text.constructor !== Array) {
# 						sub_text = $.trim(sub_text);
# 						if (sub_text.length == 0) {
# 							sub_text = default_text;
# 						}
# 						sub_text = [sub_text];
# 					} else if (sub_text.length === 0) {
# 						sub_text = [default_text];
# 					}
# 					sub_text = joogle_globals.format_list_for_text_receiver(sub_text, list_style);
# 					if (key == data.sonar_key) {
# 						var template = receiver.dataset.template;
# 						template = template.replace("{}", sub_text);
# 						receiver.innerHTML = template;
# 					}
# 				})
# 			}
# 		})();
# 	}
#
# 	window.joogle_globals.format_list_for_text_receiver = function(arr, list_style) {
# 		if (list_style === "colloquial") {
# 			if (arr.length === 1) { return arr[0]; }
# 			var front = "";
# 			var back = "";
# 			var back_arr = arr.slice(arr.length - 2, arr.length);
# 			back = back_arr[0] + " and " + back_arr[1];
# 			if (arr.length > 2) {
# 				var front_arr = arr.slice(0, arr.length - 1);
# 				for (var i = 0; i < front_arr.length; i++) {
# 					front += front_arr[i] + ", ";
# 				}
# 			}
# 			return front + back;
# 		}
# 		else if (list_style === "parens") {
# 			return "(" + arr.join(", ") + ")";
# 		}
# 		else if (list_style === "brackets") {
# 			return "[" + arr.join(", ") + "]";
# 		}
# 	}
#
# 	window.joogle_globals.update_category_filter = function(filter, selected_values) {
# 		// utility function for updating Google Charts filter
# 		var filter_state = filter.getState();
# 		filter_state.selectedValues = selected_values;
# 		filter.setState(filter_state);
# 		filter.draw();
# 	}
# 	window.joogle_globals.update_range_filter = function(filter, range) {
# 		// utility function for updating Google Charts filter
# 		var filter_state = filter.getState();
# 		filter_state.lowValue = range[0];
# 		filter_state.highValue = range[1];
# 		filter_state.lowThumbAtMinimum = false; // buggy without this
# 		filter_state.highThumbAtMaximum = false;
# 		filter.setState(filter_state);
# 		filter.draw();
# 	}
# 	window.joogle_globals.update_filter_binding_selection = function(binding_values, data, filter, column, sending_keys) {
# 		// This method is used to update a custom bound filter when its controlling filter gets a selection.
#
#
# 		// Get the list of rows in the table produced by the controlling filter.
# 		var filtered_rows = [];
# 		if (binding_values.length == 0) {
# 			filtered_rows = null;
# 		}
# 		else {
# 			for (var i = 0; i < binding_values.length; i++) {
# 				var rows = data.getFilteredRows([{column: column, value: binding_values[i]}]);
# 				filtered_rows = $.merge(filtered_rows, rows);
# 			}
# 		}
#
# 		// (undocumented setView method on control wrappers)
# 		filter.setView({
# 			rows: filtered_rows
# 		});
# 		filter.draw();
#
# 		// The selected values on the bound filter will stay or get discarded when the
# 		// filter is redrawn with the binding values.  Set the values in the message map
# 		// with the current selected values.
# 		var selected_values = filter.getState().selectedValues;
# 		for (var i = 0; i < sending_keys.length; i++) {
# 			window.joogle_globals.sonar.message_map[sending_keys[i]] = selected_values;
# 		}
#
#
#
# 	}
# 	window.joogle_globals.update_chart = function(data, chartwrapper, view_cols, key_filter_list) {
# 		/*  This function updates a chart using values from all controlling sonar filters.
# 			The key_filter_list has the column and filter type for each key.  Get the value
# 			for that filter from the message_map.
# 		*/
#
# 		var no_filtered_values = true;
#
# 		var total_filtered_rows = [];
# 		for (var i = 0; i < key_filter_list.length; i++) {
# 			// get the list of rows filtered by each filter, and then get their intersection
#
# 			var key = key_filter_list[i].key;
# 			var type = key_filter_list[i].type;
# 			var values = window.joogle_globals.sonar.message_map[key];
# 			var column = key_filter_list[i].column;
#
# 			if (typeof values !== 'undefined' && values.length > 0) {
# 				// if we enter the loop, then at least one filter has a selection.
# 				no_filtered_values = false;
# 				if (type === "values") {
# 					filtered_rows = joogle_globals.get_rows_for_column_and_values(column, values, data);
# 				}
#
# 				else if (type === "range"){
# 					filtered_rows = data.getFilteredRows([{column: column, minValue: values[0], maxValue: values[1]}]);
# 				}
#
# 				if (total_filtered_rows.length == 0) { total_filtered_rows = filtered_rows;}
# 				else {
# 					// get the intersection of current rows and the latest list of filtered rows.
# 					total_filtered_rows = total_filtered_rows.filter(function(n) {
# 					  return filtered_rows.indexOf(n) > -1;
# 					});
# 				}
# 			}
# 		}
#
# 		// if the values sent be all the filters were empty, then show the whole chart.
# 		if (no_filtered_values) { total_filtered_rows = null};
#
# 		chartwrapper.setView({
# 			rows: total_filtered_rows,
# 			columns: view_cols
# 		});
# 		chartwrapper.draw();
# 	}
#
# 	window.joogle_globals.get_rows_for_column_and_values = function(column, selections, datatable) {
# 		// for a list of values and a column, get the row numbers that have those values.
# 		var rows_total = [];

# %% [markdown]
# # Toggler<a name="Markdown"></a>
# The toggler is a container that the user can slide open and close by clicking on a prompt.  It can only hold one object or one string, but the object can be another container with nested objects or containers.
#
# There are a number of parameters that can be set on the Toggler.
# - **open_prompt**.  Text to prompt user to open the toggler.  Default is "View".
# - **close_prompt**.  Text to prompt user to close the toggler.  Default is "Close".
# - **icon**.  An icon that will appear to the right of the prompt.  Options:
#   - "arrow"  (Default)  A toggling up and down arrow.
#   - "plus".   A toggling plus/minus sign.
#   - None
# - **state**.  The initial state of the Toggler.
#   - "open" (Default)
#   - "closed"
# - **duration**.  How long it takes the Toggler to open and close.
#   - integer milliseconds.  (Default is 400)
#   - "fast".  Same as 200 ms.
#   - "slow".  Same as 600 ms.
#
# ### .add_prompt_div_styles(), .add_content_div_styles()
# In addition to adding css styles to the Toggler container, styles can be added to the prompt and to the content div.

# %%
from jooglechart.widgets import Toggler

# %%
s = """
Lorem ipsum dolor sit amet, consectetur adipiscing elit. Sed et condimentum arcu. Curabitur tellus diam, 
pharetra nec eleifend ac, blandit sit amet est. Sed a lectus ante. Nam at sapien nunc. Donec non aliquet 
metus, vel tempus arcu. Fusce at nisl sed lacus tincidunt efficitur faucibus non est. Phasellus quis laoreet
urna. Mauris in convallis lacus. Phasellus vitae enim ante. Maecenas congue ullamcorper risus at pharetra.
"""

# %%
t1 = Toggler(s)

t2 = Toggler(s, open_prompt="View Instructions", close_prompt="Close Instructions", state="closed", icon=None)

t3 = Toggler(s, icon="plus", duration=100)

# You can use the same text for open and close prompts along with an icon
t4 = Toggler(s, open_prompt="Glossary", close_prompt="Glossary", duration=800)

row = ChartRow(t1, t2, t3, t4)
row.show()
# Out:
# <style>
#
# /*
# 	Setting overflow: scroll prevents buggy behavior in CategoryFilter dropdown
# 	that occurs when the list of menu options is very long.
# */
# .charts-menu {
#     overflow: scroll;
#     max-height: 250px;
# }
#
# .google-visualization-table .google-visualization-table-td-number {
# 	text-align: right;
# }
#
# .jooglechart_container {
# 	margin-bottom: 20px;
# }
#
# h1.jooglechart_global_title {
# 	font-size: 20px;
# 	font-weight: bold;
# 	margin-bottom:8px;
# }
#
#
# .joogle_clearfix:after {
#     content:" ";
#     display:block;
#     clear:both;
# }
#
# </style>
#
# <script>
#
# $(document).ready(function() {
#
# 	/* GLOBALS AREA >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> */
#
# 	window.addEventListener('message', function(message) {
# 		// listener for sonar message from iframe parent
# 		if (typeof message.data.msg !== "undefined" && typeof message.data.msg.sonar_key !== "undefined" &&
# 				typeof message.data.msg.sonar_value !== "undefined" &&
# 				message.data.originId !== message.data.destinationId) {
# 			if (joogle_globals.sonar.handler_array !== undefined) {
# 				joogle_globals.sonar.call_handlers(message.data.msg);
# 			}
# 		}
# 	});
#
#
# 	if (typeof window.joogle_globals === "undefined" || window.joogle_globals === null) {
# 		window.joogle_globals = {};
#
# 		window.joogle_globals.sonar = new (function () {
# 			// object for holding all sonar pieces
# 			this.handler_array = [];
# 			this.message_map = {};
# 			this.add_handler = function(handler) { this.handler_array.push(handler)};
# 			this.send = function(key, value) {
# 				this.message_map[key] = value;
# 				var data = { sonar_key: key, sonar_value: value };
# 				if (window.self !== window.top) {
# 					window.parent.postMessage(data, window.location.origin + window.location.pathname);
# 				}
# 				if (joogle_globals.sonar.handler_array !== undefined) {
# 					joogle_globals.sonar.call_handlers(data);
# 				}
# 			}
# 			this.call_handlers = function(data) {
# 				for (var i = 0; i < this.handler_array.length; i++) {
# 					this.handler_array[i](data);
# 				}
# 				this.call_text_receivers(data);
# 			}
# 			this.poll_message_map = function(key) {
# 				if (key in this.message_map) {
# 					return this.message_map[key];
# 				}
# 				else { return null};
# 			}
# 			this.add_one_time_ready_poller = function(key, func, vis) {
# 				/*
# 					Check if a sonar msg was sent before chart was ready, and run function.
# 					Can happen if a sender has been initialized with a value.
# 				*/
# 				google.visualization.events.addOneTimeListener(vis, "ready", function() {
# 					var result = joogle_globals.sonar.poll_message_map(key);
# 					if (result !== null) {
# 						func({"sonar_key": key, "sonar_value": result});
# 					}
# 				});
# 			}
# 			this.call_text_receivers = function (data) {
# 				$(".joogle_text_receiver").each(function() {
# 					var receiver = this;
# 					var key = receiver.dataset.key;
# 					var list_style = receiver.dataset.liststyle;
# 					var sub_text = data.sonar_value;
# 					var default_text = receiver.dataset.default;
# 					if (typeof default_text === "undefined") {
# 						default_text = "";
# 					}
# 					var clear_text = receiver.dataset.clear_text;
# 					if (sub_text.constructor !== Array) {
# 						sub_text = $.trim(sub_text);
# 						if (sub_text.length == 0) {
# 							sub_text = default_text;
# 						}
# 						sub_text = [sub_text];
# 					} else if (sub_text.length === 0) {
# 						sub_text = [default_text];
# 					}
# 					sub_text = joogle_globals.format_list_for_text_receiver(sub_text, list_style);
# 					if (key == data.sonar_key) {
# 						var template = receiver.dataset.template;
# 						template = template.replace("{}", sub_text);
# 						receiver.innerHTML = template;
# 					}
# 				})
# 			}
# 		})();
# 	}
#
# 	window.joogle_globals.format_list_for_text_receiver = function(arr, list_style) {
# 		if (list_style === "colloquial") {
# 			if (arr.length === 1) { return arr[0]; }
# 			var front = "";
# 			var back = "";
# 			var back_arr = arr.slice(arr.length - 2, arr.length);
# 			back = back_arr[0] + " and " + back_arr[1];
# 			if (arr.length > 2) {
# 				var front_arr = arr.slice(0, arr.length - 1);
# 				for (var i = 0; i < front_arr.length; i++) {
# 					front += front_arr[i] + ", ";
# 				}
# 			}
# 			return front + back;
# 		}
# 		else if (list_style === "parens") {
# 			return "(" + arr.join(", ") + ")";
# 		}
# 		else if (list_style === "brackets") {
# 			return "[" + arr.join(", ") + "]";
# 		}
# 	}
#
# 	window.joogle_globals.update_category_filter = function(filter, selected_values) {
# 		// utility function for updating Google Charts filter
# 		var filter_state = filter.getState();
# 		filter_state.selectedValues = selected_values;
# 		filter.setState(filter_state);
# 		filter.draw();
# 	}
# 	window.joogle_globals.update_range_filter = function(filter, range) {
# 		// utility function for updating Google Charts filter
# 		var filter_state = filter.getState();
# 		filter_state.lowValue = range[0];
# 		filter_state.highValue = range[1];
# 		filter_state.lowThumbAtMinimum = false; // buggy without this
# 		filter_state.highThumbAtMaximum = false;
# 		filter.setState(filter_state);
# 		filter.draw();
# 	}
# 	window.joogle_globals.update_filter_binding_selection = function(binding_values, data, filter, column, sending_keys) {
# 		// This method is used to update a custom bound filter when its controlling filter gets a selection.
#
#
# 		// Get the list of rows in the table produced by the controlling filter.
# 		var filtered_rows = [];
# 		if (binding_values.length == 0) {
# 			filtered_rows = null;
# 		}
# 		else {
# 			for (var i = 0; i < binding_values.length; i++) {
# 				var rows = data.getFilteredRows([{column: column, value: binding_values[i]}]);
# 				filtered_rows = $.merge(filtered_rows, rows);
# 			}
# 		}
#
# 		// (undocumented setView method on control wrappers)
# 		filter.setView({
# 			rows: filtered_rows
# 		});
# 		filter.draw();
#
# 		// The selected values on the bound filter will stay or get discarded when the
# 		// filter is redrawn with the binding values.  Set the values in the message map
# 		// with the current selected values.
# 		var selected_values = filter.getState().selectedValues;
# 		for (var i = 0; i < sending_keys.length; i++) {
# 			window.joogle_globals.sonar.message_map[sending_keys[i]] = selected_values;
# 		}
#
#
#
# 	}
# 	window.joogle_globals.update_chart = function(data, chartwrapper, view_cols, key_filter_list) {
# 		/*  This function updates a chart using values from all controlling sonar filters.
# 			The key_filter_list has the column and filter type for each key.  Get the value
# 			for that filter from the message_map.
# 		*/
#
# 		var no_filtered_values = true;
#
# 		var total_filtered_rows = [];
# 		for (var i = 0; i < key_filter_list.length; i++) {
# 			// get the list of rows filtered by each filter, and then get their intersection
#
# 			var key = key_filter_list[i].key;
# 			var type = key_filter_list[i].type;
# 			var values = window.joogle_globals.sonar.message_map[key];
# 			var column = key_filter_list[i].column;
#
# 			if (typeof values !== 'undefined' && values.length > 0) {
# 				// if we enter the loop, then at least one filter has a selection.
# 				no_filtered_values = false;
# 				if (type === "values") {
# 					filtered_rows = joogle_globals.get_rows_for_column_and_values(column, values, data);
# 				}
#
# 				else if (type === "range"){
# 					filtered_rows = data.getFilteredRows([{column: column, minValue: values[0], maxValue: values[1]}]);
# 				}
#
# 				if (total_filtered_rows.length == 0) { total_filtered_rows = filtered_rows;}
# 				else {
# 					// get the intersection of current rows and the latest list of filtered rows.
# 					total_filtered_rows = total_filtered_rows.filter(function(n) {
# 					  return filtered_rows.indexOf(n) > -1;
# 					});
# 				}
# 			}
# 		}
#
# 		// if the values sent be all the filters were empty, then show the whole chart.
# 		if (no_filtered_values) { total_filtered_rows = null};
#
# 		chartwrapper.setView({
# 			rows: total_filtered_rows,
# 			columns: view_cols
# 		});
# 		chartwrapper.draw();
# 	}
#
# 	window.joogle_globals.get_rows_for_column_and_values = function(column, selections, datatable) {
# 		// for a list of values and a column, get the row numbers that have those values.
# 		var rows_total = [];

# %%
t1 = Toggler(s)
t1.add_prompt_div_styles(background_color="#eee")

t2 = Toggler(s)
t2.add_prompt_div_styles(float="right", color="forestgreen")
t2.add_content_div_styles(background_color="#eee")


t3 = Toggler(s)
t3.add_prompt_div_styles(background_color="#dee", display="block")


t4 = Toggler(s)
t4.add_prompt_div_styles(background_color="#efe", display="block", text_align="right")

box = Box(t1, t2, t3, t4)
box.show()
# Out:
# <style>
#
# /*
# 	Setting overflow: scroll prevents buggy behavior in CategoryFilter dropdown
# 	that occurs when the list of menu options is very long.
# */
# .charts-menu {
#     overflow: scroll;
#     max-height: 250px;
# }
#
# .google-visualization-table .google-visualization-table-td-number {
# 	text-align: right;
# }
#
# .jooglechart_container {
# 	margin-bottom: 20px;
# }
#
# h1.jooglechart_global_title {
# 	font-size: 20px;
# 	font-weight: bold;
# 	margin-bottom:8px;
# }
#
#
# .joogle_clearfix:after {
#     content:" ";
#     display:block;
#     clear:both;
# }
#
# </style>
#
# <script>
#
# $(document).ready(function() {
#
# 	/* GLOBALS AREA >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> */
#
# 	window.addEventListener('message', function(message) {
# 		// listener for sonar message from iframe parent
# 		if (typeof message.data.msg !== "undefined" && typeof message.data.msg.sonar_key !== "undefined" &&
# 				typeof message.data.msg.sonar_value !== "undefined" &&
# 				message.data.originId !== message.data.destinationId) {
# 			if (joogle_globals.sonar.handler_array !== undefined) {
# 				joogle_globals.sonar.call_handlers(message.data.msg);
# 			}
# 		}
# 	});
#
#
# 	if (typeof window.joogle_globals === "undefined" || window.joogle_globals === null) {
# 		window.joogle_globals = {};
#
# 		window.joogle_globals.sonar = new (function () {
# 			// object for holding all sonar pieces
# 			this.handler_array = [];
# 			this.message_map = {};
# 			this.add_handler = function(handler) { this.handler_array.push(handler)};
# 			this.send = function(key, value) {
# 				this.message_map[key] = value;
# 				var data = { sonar_key: key, sonar_value: value };
# 				if (window.self !== window.top) {
# 					window.parent.postMessage(data, window.location.origin + window.location.pathname);
# 				}
# 				if (joogle_globals.sonar.handler_array !== undefined) {
# 					joogle_globals.sonar.call_handlers(data);
# 				}
# 			}
# 			this.call_handlers = function(data) {
# 				for (var i = 0; i < this.handler_array.length; i++) {
# 					this.handler_array[i](data);
# 				}
# 				this.call_text_receivers(data);
# 			}
# 			this.poll_message_map = function(key) {
# 				if (key in this.message_map) {
# 					return this.message_map[key];
# 				}
# 				else { return null};
# 			}
# 			this.add_one_time_ready_poller = function(key, func, vis) {
# 				/*
# 					Check if a sonar msg was sent before chart was ready, and run function.
# 					Can happen if a sender has been initialized with a value.
# 				*/
# 				google.visualization.events.addOneTimeListener(vis, "ready", function() {
# 					var result = joogle_globals.sonar.poll_message_map(key);
# 					if (result !== null) {
# 						func({"sonar_key": key, "sonar_value": result});
# 					}
# 				});
# 			}
# 			this.call_text_receivers = function (data) {
# 				$(".joogle_text_receiver").each(function() {
# 					var receiver = this;
# 					var key = receiver.dataset.key;
# 					var list_style = receiver.dataset.liststyle;
# 					var sub_text = data.sonar_value;
# 					var default_text = receiver.dataset.default;
# 					if (typeof default_text === "undefined") {
# 						default_text = "";
# 					}
# 					var clear_text = receiver.dataset.clear_text;
# 					if (sub_text.constructor !== Array) {
# 						sub_text = $.trim(sub_text);
# 						if (sub_text.length == 0) {
# 							sub_text = default_text;
# 						}
# 						sub_text = [sub_text];
# 					} else if (sub_text.length === 0) {
# 						sub_text = [default_text];
# 					}
# 					sub_text = joogle_globals.format_list_for_text_receiver(sub_text, list_style);
# 					if (key == data.sonar_key) {
# 						var template = receiver.dataset.template;
# 						template = template.replace("{}", sub_text);
# 						receiver.innerHTML = template;
# 					}
# 				})
# 			}
# 		})();
# 	}
#
# 	window.joogle_globals.format_list_for_text_receiver = function(arr, list_style) {
# 		if (list_style === "colloquial") {
# 			if (arr.length === 1) { return arr[0]; }
# 			var front = "";
# 			var back = "";
# 			var back_arr = arr.slice(arr.length - 2, arr.length);
# 			back = back_arr[0] + " and " + back_arr[1];
# 			if (arr.length > 2) {
# 				var front_arr = arr.slice(0, arr.length - 1);
# 				for (var i = 0; i < front_arr.length; i++) {
# 					front += front_arr[i] + ", ";
# 				}
# 			}
# 			return front + back;
# 		}
# 		else if (list_style === "parens") {
# 			return "(" + arr.join(", ") + ")";
# 		}
# 		else if (list_style === "brackets") {
# 			return "[" + arr.join(", ") + "]";
# 		}
# 	}
#
# 	window.joogle_globals.update_category_filter = function(filter, selected_values) {
# 		// utility function for updating Google Charts filter
# 		var filter_state = filter.getState();
# 		filter_state.selectedValues = selected_values;
# 		filter.setState(filter_state);
# 		filter.draw();
# 	}
# 	window.joogle_globals.update_range_filter = function(filter, range) {
# 		// utility function for updating Google Charts filter
# 		var filter_state = filter.getState();
# 		filter_state.lowValue = range[0];
# 		filter_state.highValue = range[1];
# 		filter_state.lowThumbAtMinimum = false; // buggy without this
# 		filter_state.highThumbAtMaximum = false;
# 		filter.setState(filter_state);
# 		filter.draw();
# 	}
# 	window.joogle_globals.update_filter_binding_selection = function(binding_values, data, filter, column, sending_keys) {
# 		// This method is used to update a custom bound filter when its controlling filter gets a selection.
#
#
# 		// Get the list of rows in the table produced by the controlling filter.
# 		var filtered_rows = [];
# 		if (binding_values.length == 0) {
# 			filtered_rows = null;
# 		}
# 		else {
# 			for (var i = 0; i < binding_values.length; i++) {
# 				var rows = data.getFilteredRows([{column: column, value: binding_values[i]}]);
# 				filtered_rows = $.merge(filtered_rows, rows);
# 			}
# 		}
#
# 		// (undocumented setView method on control wrappers)
# 		filter.setView({
# 			rows: filtered_rows
# 		});
# 		filter.draw();
#
# 		// The selected values on the bound filter will stay or get discarded when the
# 		// filter is redrawn with the binding values.  Set the values in the message map
# 		// with the current selected values.
# 		var selected_values = filter.getState().selectedValues;
# 		for (var i = 0; i < sending_keys.length; i++) {
# 			window.joogle_globals.sonar.message_map[sending_keys[i]] = selected_values;
# 		}
#
#
#
# 	}
# 	window.joogle_globals.update_chart = function(data, chartwrapper, view_cols, key_filter_list) {
# 		/*  This function updates a chart using values from all controlling sonar filters.
# 			The key_filter_list has the column and filter type for each key.  Get the value
# 			for that filter from the message_map.
# 		*/
#
# 		var no_filtered_values = true;
#
# 		var total_filtered_rows = [];
# 		for (var i = 0; i < key_filter_list.length; i++) {
# 			// get the list of rows filtered by each filter, and then get their intersection
#
# 			var key = key_filter_list[i].key;
# 			var type = key_filter_list[i].type;
# 			var values = window.joogle_globals.sonar.message_map[key];
# 			var column = key_filter_list[i].column;
#
# 			if (typeof values !== 'undefined' && values.length > 0) {
# 				// if we enter the loop, then at least one filter has a selection.
# 				no_filtered_values = false;
# 				if (type === "values") {
# 					filtered_rows = joogle_globals.get_rows_for_column_and_values(column, values, data);
# 				}
#
# 				else if (type === "range"){
# 					filtered_rows = data.getFilteredRows([{column: column, minValue: values[0], maxValue: values[1]}]);
# 				}
#
# 				if (total_filtered_rows.length == 0) { total_filtered_rows = filtered_rows;}
# 				else {
# 					// get the intersection of current rows and the latest list of filtered rows.
# 					total_filtered_rows = total_filtered_rows.filter(function(n) {
# 					  return filtered_rows.indexOf(n) > -1;
# 					});
# 				}
# 			}
# 		}
#
# 		// if the values sent be all the filters were empty, then show the whole chart.
# 		if (no_filtered_values) { total_filtered_rows = null};
#
# 		chartwrapper.setView({
# 			rows: total_filtered_rows,
# 			columns: view_cols
# 		});
# 		chartwrapper.draw();
# 	}
#
# 	window.joogle_globals.get_rows_for_column_and_values = function(column, selections, datatable) {
# 		// for a list of values and a column, get the row numbers that have those values.
# 		var rows_total = [];
