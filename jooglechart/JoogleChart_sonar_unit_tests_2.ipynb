# %%
import pandas as pd
from jooglechart_api import JoogleChart, Filter, ChartRow, sonar_keys
from utils import get_df, get_date_df
from widgets import ButtonGroup, CheckboxGroup
from contrib.display.bi_styles import get_styler
from IPython.display import display, HTML

# %% [markdown]
# # Category Filter send to chart filter

# %%
df = get_df()
chart1 = JoogleChart(df)
filter1 = Filter("CategoryFilter")
filter1.add_options(filterColumnIndex=0)
filter1.add_sender(key=sonar_keys.ONE)
chart1.add_filter(filter1)
chart1.add_styler(get_styler())

# print chart1.render()
# chart1.show()

chart2 = JoogleChart(df, chart_type="Table")
filter2 = Filter("CategoryFilter")
filter2.add_options(filterColumnIndex=0)
# filter2.add_receiver(key=sonar_keys.ONE)
filter2.add_options(ui_cssClass="hidden")
chart2.add_filter(filter2)

row = ChartRow(chart1, chart2)
row.show()
# Out:
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
#
# 	globals.call_jooglechart_callback(doStuff_28);
#
# });
#
#     function doStuff_28() {
#
#     // ==================== CHARTROW CHART 1 ============================= //
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jooglechart_29_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"Sacramento"},{"v":97}]},{"c":[{"v":"Montpelier"},{"v":96}]},{"c":[{"v":"Juneau"},{"v":24}]},{"c":[{"v":"Montgomery"},{"v":26}]},{"c":[{"v":"Little Rock"},{"v":87}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"number","id":"Aaaaaaaaa","label":"Aaaaaaaaa"}]});
#
#         // Add formatters, if any
#
#         // Create ChartWrapper
#         var google_chart_30 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_30_div_id",
#             "dataTable": jooglechart_29_data,
#             "chartType": "ColumnChart",
#             "options": {"fontName": "Helvetica Neue", "bar": {"groupWidth": 55}, "hAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "chartArea": {"width": 440, "top": 20, "height": 295, "left": 60}, "height": 375, "width": 500, "fontSize": 12, "vAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "titleTextStyle": {"fontSize": 16}, "legend": {"position": "top"}}
#         });
#
#         // Create a dashboard.
#         var jooglechart_29_dashboard = new google.visualization.Dashboard(
#             document.getElementById('jooglechart_29_dashboard_div_id'));
#
#         // Create controls
#
#         var google_filter_31 = new google.visualization.ControlWrapper({
#           'controlType': 'CategoryFilter',
#           'containerId': 'google_filter_31_div_id',
#           'options': {"filterColumnIndex": 0},
#           'state': {}
#         });
#
#         // Establish dependencies.
# 		jooglechart_29_dashboard.bind(google_filter_31, google_chart_30);
#
# 		// Add sonar senders, if any
#         google.visualization.events.addListener(google_filter_31, "statechange", function () {
# 			var selected_values = google_filter_31.getState().selectedValues;
# 			globals.sonar.send("SONAR_KEY_ONE", selected_values);
# 		});
#         // Draw the dashboard.
#         jooglechart_29_dashboard.draw(jooglechart_29_data);
#
#         // Add sonar receivers, if any
#
#
# 		// -------------- Add senders, if any -------------
#
# 		// ------------------------------------------------
#
# 		// -------------- Add receivers, if any -------------
#
# 		// --------------------------------------------------
#
#     // ==================================================================== //
#
#     // ==================== CHARTROW CHART 2 ============================= //
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jooglechart_32_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"Sacramento"},{"v":97}]},{"c":[{"v":"Montpelier"},{"v":96}]},{"c":[{"v":"Juneau"},{"v":24}]},{"c":[{"v":"Montgomery"},{"v":26}]},{"c":[{"v":"Little Rock"},{"v":87}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"number","id":"Aaaaaaaaa","label":"Aaaaaaaaa"}]});
#
#         // Add formatters, if any
#
#         // Create ChartWrapper
#         var google_chart_33 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_33_div_id",
#             "dataTable": jooglechart_32_data,
#             "chartType": "Table",
#             "options": {}
#         });
#
#         // Create a dashboard.
#         var jooglechart_32_dashboard = new google.visualization.Dashboard(
#             document.getElementById('jooglechart_32_dashboard_div_id'));
#
#         // Create controls
#
#         var google_filter_34 = new google.visualization.ControlWrapper({
#           'controlType': 'CategoryFilter',
#           'containerId': 'google_filter_34_div_id',
#           'options': {"ui": {"cssClass": "hidden"}, "filterColumnIndex": 0},
#           'state': {}
#         });
#
#         // Establish dependencies.
# 		jooglechart_32_dashboard.bind(google_filter_34, google_chart_33);
#
# 		// Add sonar senders, if any
#
#         // Draw the dashboard.
#         jooglechart_32_dashboard.draw(jooglechart_32_data);
#
#         // Add sonar receivers, if any
#
#
# 		// -------------- Add senders, if any -------------
#
# 		// ------------------------------------------------
#
# 		// -------------- Add receivers, if any -------------
#
# 		// --------------------------------------------------
#
#     // ==================================================================== //
#
#     }
#
# </script>
#
#
# <div class="row">
#     <div class="col-sm-6">
#
#
#
# <div id="jooglechart_29_dashboard_div_id">
# 	<div id="google_filter_31_div_id"></div>
#
# <div id="google_chart_30_div_id" class="jooglechart_container jooglechart_type_ColumnChart" ></div>
#
# </div>
#     </div>
#     <div class="col-sm-6">
#
#
#
# <div id="jooglechart_32_dashboard_div_id">
# 	<div id="google_filter_34_div_id"></div>
#
# <div id="google_chart_33_div_id" class="jooglechart_container jooglechart_type_Table" ></div>
#
# </div>
#     </div>
# </div>

# %% [markdown]
# # DateRange filter send to chart filter

# %%
df1 = get_date_df(days=10, num_series=2)
chart1 = JoogleChart(df1, chart_type="LineChart")
filter1 = Filter("DateRangeFilter")
filter1.add_options(filterColumnIndex=0)
filter1.add_sender(key="KEY2")
chart1.add_filter(filter1)
chart1.add_styler(get_styler())

df2 = get_date_df(days=10, num_series=2)
chart2 = JoogleChart(df2, chart_type="LineChart")
filter2 = Filter("DateRangeFilter")
filter2.add_receiver(key="KEY2")
filter2.add_options(filterColumnIndex=0)
chart2.add_filter(filter2)
chart2.add_styler(get_styler())

# print chart1.render()
# print chart2.render(force_common=False)
row = ChartRow(chart1, chart2)
row.show()
# Out:
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
#
# 	globals.call_jooglechart_callback(doStuff_35);
#
# });
#
#     function doStuff_35() {
#
#     // ==================== CHARTROW CHART 1 ============================= //
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jooglechart_36_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"Date(2015,0,1)"},{"v":37.26119698117952},{"v":37.65152349976111}]},{"c":[{"v":"Date(2015,0,2)"},{"v":36.374732184322774},{"v":34.49060446183322}]},{"c":[{"v":"Date(2015,0,3)"},{"v":36.420892351778605},{"v":36.27461558257771}]},{"c":[{"v":"Date(2015,0,4)"},{"v":35.9385087750296},{"v":33.30932586851561}]},{"c":[{"v":"Date(2015,0,5)"},{"v":32.955527737360065},{"v":35.01765679221871}]},{"c":[{"v":"Date(2015,0,6)"},{"v":33.725168105734326},{"v":36.382135824432766}]},{"c":[{"v":"Date(2015,0,7)"},{"v":34.38238542459892},{"v":29.29060784638988}]},{"c":[{"v":"Date(2015,0,8)"},{"v":37.40187938864989},{"v":34.707370399766}]},{"c":[{"v":"Date(2015,0,9)"},{"v":34.1131784935412},{"v":35.529267101737624}]},{"c":[{"v":"Date(2015,0,10)"},{"v":37.23435460285569},{"v":34.400557794143275}]}],"cols":[{"type":"date","id":"dates","label":"dates"},{"type":"number","id":"A","label":"A"},{"type":"number","id":"B","label":"B"}]});
#
#         // Add formatters, if any
#
#         // Create ChartWrapper
#         var google_chart_37 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_37_div_id",
#             "dataTable": jooglechart_36_data,
#             "chartType": "LineChart",
#             "options": {"fontName": "Helvetica Neue", "hAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "chartArea": {"width": 440, "top": 20, "height": 295, "left": 60}, "height": 375, "width": 500, "fontSize": 12, "vAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "titleTextStyle": {"fontSize": 16}, "legend": {"position": "top"}}
#         });
#
#         // Create a dashboard.
#         var jooglechart_36_dashboard = new google.visualization.Dashboard(
#             document.getElementById('jooglechart_36_dashboard_div_id'));
#
#         // Create controls
#
#         var google_filter_38 = new google.visualization.ControlWrapper({
#           'controlType': 'DateRangeFilter',
#           'containerId': 'google_filter_38_div_id',
#           'options': {"filterColumnIndex": 0},
#           'state': {}
#         });
#
#         // Establish dependencies.
# 		jooglechart_36_dashboard.bind(google_filter_38, google_chart_37);
#
# 		// Add sonar senders, if any
#         google.visualization.events.addListener(google_filter_38, "statechange", function () {
# 			var low_value = google_filter_38.getState().lowValue;
# 			var high_value = google_filter_38.getState().highValue;
# 			globals.sonar.send("KEY2", [low_value, high_value]);
# 		});
#         // Draw the dashboard.
#         jooglechart_36_dashboard.draw(jooglechart_36_data);
#
#         // Add sonar receivers, if any
#
#
# 		// -------------- Add senders, if any -------------
#
# 		// ------------------------------------------------
#
# 		// -------------- Add receivers, if any -------------
#
# 		// --------------------------------------------------
#
#     // ==================================================================== //
#
#     // ==================== CHARTROW CHART 2 ============================= //
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jooglechart_39_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"Date(2015,0,1)"},{"v":27.477179908545313},{"v":32.500234224987054}]},{"c":[{"v":"Date(2015,0,2)"},{"v":25.53266396077861},{"v":36.0636973340511}]},{"c":[{"v":"Date(2015,0,3)"},{"v":26.893176499033313},{"v":32.74217039213046}]},{"c":[{"v":"Date(2015,0,4)"},{"v":28.191638533707597},{"v":31.563369283036025}]},{"c":[{"v":"Date(2015,0,5)"},{"v":23.485124349516894},{"v":30.17624248498956}]},{"c":[{"v":"Date(2015,0,6)"},{"v":26.39046848167065},{"v":33.10261187717447}]},{"c":[{"v":"Date(2015,0,7)"},{"v":25.00346852065044},{"v":30.353979260220985}]},{"c":[{"v":"Date(2015,0,8)"},{"v":28.075666728821886},{"v":30.75098451903343}]},{"c":[{"v":"Date(2015,0,9)"},{"v":24.94322904838723},{"v":33.869822453751894}]},{"c":[{"v":"Date(2015,0,10)"},{"v":27.565518870641267},{"v":32.578820807227146}]}],"cols":[{"type":"date","id":"dates","label":"dates"},{"type":"number","id":"A","label":"A"},{"type":"number","id":"B","label":"B"}]});
#
#         // Add formatters, if any
#
#         // Create ChartWrapper
#         var google_chart_40 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_40_div_id",
#             "dataTable": jooglechart_39_data,
#             "chartType": "LineChart",
#             "options": {"fontName": "Helvetica Neue", "hAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "chartArea": {"width": 440, "top": 20, "height": 295, "left": 60}, "height": 375, "width": 500, "fontSize": 12, "vAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "titleTextStyle": {"fontSize": 16}, "legend": {"position": "top"}}
#         });
#
#         // Create a dashboard.
#         var jooglechart_39_dashboard = new google.visualization.Dashboard(
#             document.getElementById('jooglechart_39_dashboard_div_id'));
#
#         // Create controls
#
#         var google_filter_41 = new google.visualization.ControlWrapper({
#           'controlType': 'DateRangeFilter',
#           'containerId': 'google_filter_41_div_id',
#           'options': {"filterColumnIndex": 0},
#           'state': {}
#         });
#
#         // Establish dependencies.
# 		jooglechart_39_dashboard.bind(google_filter_41, google_chart_40);
#
# 		// Add sonar senders, if any
#
#         // Draw the dashboard.
#         jooglechart_39_dashboard.draw(jooglechart_39_data);
#
#         // Add sonar receivers, if any
# 		globals.sonar.add_handler(function (data) {
# 			if (data.sonar_key == "KEY2") {
# 				globals.update_daterange_filter(google_filter_41, data.sonar_value);
# 			}
# 		});
#
# 		// -------------- Add senders, if any -------------
#
# 		// ------------------------------------------------
#
# 		// -------------- Add receivers, if any -------------
#
# 		// --------------------------------------------------
#
#     // ==================================================================== //
#
#     }
#
# </script>
#
#
# <div class="row">
#     <div class="col-sm-6">
#
#
#
# <div id="jooglechart_36_dashboard_div_id">
# 	<div id="google_filter_38_div_id"></div>
#
# <div id="google_chart_37_div_id" class="jooglechart_container jooglechart_type_LineChart" ></div>
#
# </div>
#     </div>
#     <div class="col-sm-6">
#
#
#
# <div id="jooglechart_39_dashboard_div_id">
# 	<div id="google_filter_41_div_id"></div>
#
# <div id="google_chart_40_div_id" class="jooglechart_container jooglechart_type_LineChart" ></div>
#
# </div>
#     </div>
# </div>
