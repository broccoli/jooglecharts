# %% [raw]
# <link rel="stylesheet" href="reveal.js/css/theme/custom_theme.css" id="theme">
# <style>
#     div.prompt {
#         display:none;
#     }
#     .slides {
#         overflow-y: auto !important;
#         overflow-x: hidden !important;
#         height: 700px;
#     }
#     .rendered_html h1:first-child {
#         margin-top:0;
#     }
#     .reveal .slides > section {
#         padding:0;
#     }
#     .reveal pre {
#         font-size:100%;
#     }
#     .hidden {
#         display:none;
#     }
# </style>

# %%
import pandas as pd
from jooglechart_api import JoogleChart, Filter, ChartRow, sonar_keys, joogle_include, SeriesFilter
from jooglechart.utils import get_df, get_date_df
from widgets import ButtonGroup, CheckboxGroup, Button, Box, TextReceiver, Legend
from contrib.display.bi_styles import get_styler

# %% [markdown]
# # Jooglechart sonar

# %% [markdown]
# # What is jooglechart sonar?
# ## - Event handling framework
# ## - Send messages from a chart object
# ## - Messages trigger events on other objects

# %% [markdown]
# # For example:  select and filter and change and unconnected chart

# %% [markdown]
# # Works within an ishbook and across Aquarium tanks
# ## - Uses Aaron's message handler in Aquarium

# %% [markdown]
# # Usage
#
# ## - Add a “sender” and a key to one object.
#
# ## - Add a “receiver” with the same key to another object.
#
# ## - Add as many senders and receivers as you need, using the same or different keys.

# %% [markdown]
# # Syntax
#
# ## object_1.add_sender(key=”ABC” [,type , **kwargs])
# ## object_2.add_receiver(key=”ABC” [, action, **kwargs])

# %% [markdown]
# # The good news!
# ## - Can control multiple charts with a filter in Ishbook and Aquarium
# ## - Lots of new widgets and layout tools
# ## - Can make super cool dashboards

# %% [markdown]
# # The bad news :(
#
# ## - Massive backlog of code to merge into production
# ## - Only partially available to use
# ## - We’ll be in beta for a while watching for bugs

# %% [markdown]
# # Example time

# %% [markdown]
# # First, some preliminaries

# %% [markdown]
# # joogle_include() at top of notebook
# ## - Inserts the jooglechart boilerplate code.
# ## - It's optional:  the first joogle object will insert the boilerplate.
# ## - joogle_include() will flush the handler list, which you might want to do occasionally.

# %%
joogle_include()
# Out:
# <script type="text/javascript">
# window.joogle_globals = null;
# </script>
#
#
#
# <style>
#
# /*
# 	Setting overflow: scroll prevents buggy behavior in CategoryFilter dropdown
# 	that occurs when the list of menu options is very long.
# */
# .charts-menu {
#     overflow: scroll;
#     max-height: 250px;
# }
#
# .google-visualization-table .google-visualization-table-td-number {
# 	text-align: right;
# }
#
# .jooglechart_container {
# 	margin-bottom: 20px;
# }
#
# h1.jooglechart_global_title {
# 	font-size: 20px;
# 	font-weight: bold;
# 	margin-bottom:8px;
# }
#
# </style>
#
# <script>
#
# $(document).ready(function() {
#
# 	/* GLOBALS AREA >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> */
#
# 	window.addEventListener('message', function(message) {
# 		// listener for sonar message from iframe parent
# 		if (message.data.msg.sonar_key !== undefined && message.data.msg.sonar_value !== undefined &&
# 				message.data.originId !== message.data.destinationId) {
# 			if (joogle_globals.sonar.handler_array !== undefined) {
# 				joogle_globals.sonar.call_handlers(message.data.msg);
# 			}
# 		}
# 	});
#
# 		window.joogle_globals = null;
#
# 	if (typeof window.joogle_globals === "undefined" || window.joogle_globals === null) {
# 		window.joogle_globals = {};
#
# 		window.joogle_globals.sonar = new (function () {
# 			// object for holding all sonar pieces
# 			this.handler_array = [];
# 			this.message_map = {};
# 			this.add_handler = function(handler) { this.handler_array.push(handler)};
# 			this.send = function(key, value) {
# 				this.message_map[key] = value;
# 				var data = { sonar_key: key, sonar_value: value };
# 				if (window.self !== window.top) {
# 					window.parent.postMessage(data, window.location.origin + window.location.pathname);
# 				}
# 				if (joogle_globals.sonar.handler_array !== undefined) {
# 					joogle_globals.sonar.call_handlers(data);
# 				}
# 			}
# 			this.call_handlers = function(data) {
# 				for (var i = 0; i < this.handler_array.length; i++) {
# 					this.handler_array[i](data);
# 				}
# 				this.call_text_receivers(data);
# 			}
# 			this.poll_message_map = function(key) {
# 				if (key in this.message_map) {
# 					return this.message_map[key];
# 				}
# 				else { return null};
# 			}
# 			this.add_one_time_ready_poller = function(key, func, vis) {
# 				/*
# 					Check if a sonar msg was sent before chart was ready, and run function.
# 					Can happen if a sender has been initialized with a value.
# 				*/
# 				google.visualization.events.addOneTimeListener(vis, "ready", function() {
# 					var result = joogle_globals.sonar.poll_message_map(key);
# 					if (result !== null) {
# 						func({"sonar_key": key, "sonar_value": result});
# 					}
# 				});
# 			}
# 			this.call_text_receivers = function (data) {
# 				$(".joogle_text_receiver").each(function() {
# 					var receiver = this;
# 					var key = receiver.dataset.key;
# 					var list_style = receiver.dataset.liststyle;
# 					var sub_text = data.sonar_value;
# 					var default_text = receiver.dataset.default;
# 					if (typeof default_text === "undefined") {
# 						default_text = "";
# 					}
# 					var clear_text = receiver.dataset.clear_text;
# 					if (sub_text.constructor !== Array) {
# 						sub_text = $.trim(sub_text);
# 						if (sub_text.length == 0) {
# 							sub_text = default_text;
# 						}
# 						sub_text = [sub_text];
# 					} else if (sub_text.length === 0) {
# 						sub_text = [default_text];
# 					}
# 					sub_text = joogle_globals.format_list_for_text_receiver(sub_text, list_style);
# 					if (key == data.sonar_key) {
# 						var template = receiver.dataset.template;
# 						template = template.replace("{}", sub_text);
# 						receiver.innerHTML = template;
# 					}
# 				})
# 			}
# 		})();
# 	}
#
# 	window.joogle_globals.format_list_for_text_receiver = function(arr, list_style) {
# 		if (list_style === "colloquial") {
# 			if (arr.length === 1) { return arr[0]; }
# 			var front = "";
# 			var back = "";
# 			var back_arr = arr.slice(arr.length - 2, arr.length);
# 			back = back_arr[0] + " and " + back_arr[1];
# 			if (arr.length > 2) {
# 				var front_arr = arr.slice(0, arr.length - 1);
# 				for (var i = 0; i < front_arr.length; i++) {
# 					front += front_arr[i] + ", ";
# 				}
# 			}
# 			return front + back;
# 		}
# 		else if (list_style === "parens") {
# 			return "(" + arr.join(", ") + ")";
# 		}
# 		else if (list_style === "brackets") {
# 			return "[" + arr.join(", ") + "]";
# 		}
# 	}
#
# 	window.joogle_globals.update_category_filter = function(filter, selected_values) {
# 		// utility function for updating Google Charts filter
# 		var filter_state = filter.getState();
# 		filter_state.selectedValues = selected_values;
# 		filter.setState(filter_state);
# 		filter.draw();
# 	}
# 	window.joogle_globals.update_range_filter = function(filter, range) {
# 		// utility function for updating Google Charts filter
# 		var filter_state = filter.getState();
# 		filter_state.lowValue = range[0];
# 		filter_state.highValue = range[1];
# 		filter_state.lowThumbAtMinimum = false; // buggy without this
# 		filter_state.highThumbAtMaximum = false;
# 		filter.setState(filter_state);
# 		filter.draw();
# 	}
# 	window.joogle_globals.update_filter_binding_selection = function(selected_values, data, filter, column) {
# 		// Method for filtering controlWrapper's dataTable and redrawing.  Used for filter sonar receiver.
#
# 		var filtered_rows = [];
# 		if (selected_values.length == 0) {
# 			filtered_rows = null;
# 		}
# 		else {
# 			for (var i = 0; i < selected_values.length; i++) {
# 				var rows = data.getFilteredRows([{column: column, value: selected_values[i]}]);
# 				filtered_rows = $.merge(filtered_rows, rows);
# 			}
# 		}
# 		// undocumented setView method on control wrappers
# 		filter.setView({
# 			rows: filtered_rows
# 		});
#
# 		filter.draw();
# 	}
# 	window.joogle_globals.update_chart = function(values_arr, data, chartwrapper, column, view_cols) {
# 		var filtered_rows = joogle_globals.get_rows_for_column_selections(column, values_arr, data);
# 		chartwrapper.setView({
# 			rows: filtered_rows,
# 			columns: view_cols
# 		});
# 		chartwrapper.draw();
# 	}
#
# 	window.joogle_globals.update_chart_range = function(minValue, maxValue, data, chartwrapper, column, view_cols) {
# 		var filtered_rows = data.getFilteredRows([{column: column, minValue: minValue, maxValue: maxValue}]);
# 		chartwrapper.setView({
# 			rows: filtered_rows,
# 			columns: view_cols
# 		});
# 		chartwrapper.draw();
# 	}
#
# 	window.joogle_globals.get_rows_for_column_selections = function(column, selections, datatable) {
# 		var rows_total = [];
# 		if (selections.length == 0) {
# 			rows_total = null;
# 		}
# 		else {
# 			for (var i = 0; i < selections.length; i++) {
# 				var rows = datatable.getFilteredRows([{column: parseInt(column), value: selections[i]}]);
# 				rows_total = $.merge(rows_total, rows);
# 			}
# 		}
# 		return rows_total;
# 	}
#
# 	window.joogle_globals.get_binding_selections = function(binding_selections, datatable) {
# 		// A filter's column can be bound by another sender (a filter, typically).
# 		// Need to get the filtering values for the bound column if it had received a filtering messsage.
# 		var binding_rows = [];
# 		var binding_values = [];
# 		for (var column in binding_selections) {
# 			if (binding_selections[column].length > 0) {
# 				var rows = joogle_globals.get_rows_for_column_selections(column, binding_selections[column], datatable);
# 				$.merge(binding_rows, rows);
# 			}
# 		}
# 		// now we've got the binding rows, get the values in the right column
# 		for (var ix in binding_rows) {
# 			binding_values.push(datatable.getValue(binding_rows[ix], 0));
# 		}
# 		return binding_values;
# 	}
#
# 	window.joogle_globals.draw_chart_filtered_columns = function(datatable, viewable_columns, selected_columns, callback) {
# 		// an object of series properties will be passed to the chart wrapper for setting color
# 	    var series = {};
#
# 		// initialize the array of dataTable column indices, e.g, [0, 1, 2, etc.]
# 	    var columns = [];
# 	    for (var i = 0; i < datatable.getNumberOfColumns(); i++) {
# 	        columns.push(i);
# 	    }
#
# 		// Loop through series cols
# 		for (var i = 0; i < viewable_columns.length; i++) {
# 			series[i] = {}	// initialize series object
# 			var ix = viewable_columns[i]	// get series column index in the original data table
#
# 			// c

# %% [markdown]
# # Jooglechart Containers:  Rows and Boxes

# %% [markdown]
# # What's in the Box!

# %% [markdown]
# # Box (not yet in production)
# ## - A vertical stacking container
# ## - Accepts all joogle objects, including Rows and Boxes
# ## - Accepts strings

# %%
df = get_df()
chart1 = JoogleChart(df)
chart1.add_styler(get_styler(width="small", legend_position="none"))
chart1.add_chart_options(height=800)

chart2 = JoogleChart(df, chart_type="PieChart")
chart2.add_styler(get_styler(legend_position="none"))

chart3 = JoogleChart(df, chart_type="BarChart")
chart3.add_styler(get_styler(width="small", legend_position="none"))
chart3.add_chart_options(colors=['green'])

box = Box(chart2, chart3)
row = ChartRow(chart1, box)

row.show()
# Out:
# <div class="row" id="joogle_chartrow_1" >
#     <div class="col-sm-6">
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_2);
# });
#
#     function doStuff_2() {
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jooglechart_2_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"Sacramento"},{"v":97}]},{"c":[{"v":"Montpelier"},{"v":96}]},{"c":[{"v":"Juneau"},{"v":24}]},{"c":[{"v":"Montgomery"},{"v":26}]},{"c":[{"v":"Little Rock"},{"v":87}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"number","id":"Aaaaaaaaa","label":"Aaaaaaaaa"}]});
#
#         // Add formatters, if any
#
#         // Create ChartWrapper
#         var google_chart_3 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_3_div_id",
#             "dataTable": jooglechart_2_data,
#             "view": {columns: null},
#             "chartType": "ColumnChart",
#             "options": {"fontName": "Helvetica Neue", "bar": {"groupWidth": 36}, "hAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "chartArea": {"width": 290, "top": 10, "height": 730, "left": 60}, "height": 800, "width": 350, "fontSize": 12, "vAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "titleTextStyle": {"fontSize": 16}, "legend": {"position": "none"}}
#         });
#
#         google_chart_3.draw();
#
# 		// -------------- Add chartwrapper senders, if any -------------
#
# 		// -------------------------------------------------------------
#
# 		// -------------- Add chartwrapper receivers, if any -------------
#
# 		// ---------------------------------------------------------------
#
#
#     }
#
# </script>
#
#
#
#
# <div id="google_chart_3_div_id" class="jooglechart_container jooglechart_type_ColumnChart" ></div>
#
#
#     </div>
#     <div class="col-sm-6">
#
# <div id="joogle_box_4" >
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_5);
# });
#
#     function doStuff_5() {
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jooglechart_5_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"Sacramento"},{"v":97}]},{"c":[{"v":"Montpelier"},{"v":96}]},{"c":[{"v":"Juneau"},{"v":24}]},{"c":[{"v":"Montgomery"},{"v":26}]},{"c":[{"v":"Little Rock"},{"v":87}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"number","id":"Aaaaaaaaa","label":"Aaaaaaaaa"}]});
#
#         // Add formatters, if any
#
#         // Create ChartWrapper
#         var google_chart_6 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_6_div_id",
#             "dataTable": jooglechart_5_data,
#             "view": {columns: null},
#             "chartType": "PieChart",
#             "options": {"fontName": "Helvetica Neue", "hAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "chartArea": {"width": 500, "top": 10, "height": 325, "left": 0}, "height": 375, "width": 500, "fontSize": 12, "vAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "titleTextStyle": {"fontSize": 16}, "legend": {"position": "none"}}
#         });
#
#         google_chart_6.draw();
#
# 		// -------------- Add chartwrapper senders, if any -------------
#
# 		// -------------------------------------------------------------
#
# 		// -------------- Add chartwrapper receivers, if any -------------
#
# 		// ---------------------------------------------------------------
#
#
#     }
#
# </script>
#
#
#
#
# <div id="google_chart_6_div_id" class="jooglechart_container jooglechart_type_PieChart" ></div>
#
#
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_7);
# });
#
#     function doStuff_7() {
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jooglechart_7_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"Sacramento"},{"v":97}]},{"c":[{"v":"Montpelier"},{"v":96}]},{"c":[{"v":"Juneau"},{"v":24}]},{"c":[{"v":"Montgomery"},{"v":26}]},{"c":[{"v":"Little Rock"},{"v":87}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"number","id":"Aaaaaaaaa","label":"Aaaaaaaaa"}]});
#
#         // Add formatters, if any
#
#         // Create ChartWrapper
#         var google_chart_8 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_8_div_id",
#             "dataTable": jooglechart_7_data,
#             "view": {columns: null},
#             "chartType": "BarChart",
#             "options": {"fontName": "Helvetica Neue", "bar": {"groupWidth": 41}, "hAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "chartArea": {"width": 250, "top": 10, "height": 325, "left": 100}, "height": 375, "width": 350, "colors": ["green"], "fontSize": 12, "vAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "titleTextStyle": {"fontSize": 16}, "legend": {"position": "none"}}
#         });
#
#         google_chart_8.draw();
#
# 		// -------------- Add chartwrapper senders, if any -------------
#
# 		// -------------------------------------------------------------
#
# 		// -------------- Add chartwrapper receivers, if any -------------
#
# 		// ---------------------------------------------------------------
#
#
#     }
#
# </script>
#
#
#
#
# <div id="google_chart_8_div_id" class="jooglechart_container jooglechart_type_BarChart" ></div>
#
#
# </div>
#
# <style>
# #joogle_box_4 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
# </div>
#
#
# <style>
# .joogle_clearfix:after {
#     content:" ";
#     display:block;
#     clear:both;
# }
#
# #joogle_chartrow_1 > .joogle_chartrow_column {
# 	box-sizing: border-box;
# 	float: left;
# }
#
# </style>

# %%
df = get_df()
chart1 = JoogleChart(df)
chart1.add_styler(get_styler(width="small", legend_position="none"))
chart1.add_div_styles(border="10px solid orange")
chart1.add_chart_options(height=800)

chart2 = JoogleChart(df, chart_type="PieChart")
chart2.add_styler(get_styler(legend_position="none"))
chart2.add_div_styles(border="10px solid gray")

chart3 = JoogleChart(df, chart_type="BarChart")
chart3.add_styler(get_styler(width="small", legend_position="none"))
chart3.add_div_styles(border="10px solid orange")
chart3.add_chart_options(colors=['green'])

box = Box(chart2, chart3)
box.add_div_styles(border="10px solid darkcyan")
row = ChartRow(chart1, box)
row.add_div_styles(border="10px solid blue")

row.show()
# Out:
# <div class="row" id="joogle_chartrow_9" style="border: 10px solid blue">
#     <div class="col-sm-6">
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_10);
# });
#
#     function doStuff_10() {
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jooglechart_10_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"Sacramento"},{"v":97}]},{"c":[{"v":"Montpelier"},{"v":96}]},{"c":[{"v":"Juneau"},{"v":24}]},{"c":[{"v":"Montgomery"},{"v":26}]},{"c":[{"v":"Little Rock"},{"v":87}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"number","id":"Aaaaaaaaa","label":"Aaaaaaaaa"}]});
#
#         // Add formatters, if any
#
#         // Create ChartWrapper
#         var google_chart_11 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_11_div_id",
#             "dataTable": jooglechart_10_data,
#             "view": {columns: null},
#             "chartType": "ColumnChart",
#             "options": {"fontName": "Helvetica Neue", "bar": {"groupWidth": 36}, "hAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "chartArea": {"width": 290, "top": 10, "height": 730, "left": 60}, "height": 800, "width": 350, "fontSize": 12, "vAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "titleTextStyle": {"fontSize": 16}, "legend": {"position": "none"}}
#         });
#
#         google_chart_11.draw();
#
# 		// -------------- Add chartwrapper senders, if any -------------
#
# 		// -------------------------------------------------------------
#
# 		// -------------- Add chartwrapper receivers, if any -------------
#
# 		// ---------------------------------------------------------------
#
#
#     }
#
# </script>
#
#
#
#
# <div id="google_chart_11_div_id" class="jooglechart_container jooglechart_type_ColumnChart" style="border: 10px solid orange"></div>
#
#
#     </div>
#     <div class="col-sm-6">
#
# <div id="joogle_box_12" style="border: 10px solid darkcyan">
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_13);
# });
#
#     function doStuff_13() {
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jooglechart_13_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"Sacramento"},{"v":97}]},{"c":[{"v":"Montpelier"},{"v":96}]},{"c":[{"v":"Juneau"},{"v":24}]},{"c":[{"v":"Montgomery"},{"v":26}]},{"c":[{"v":"Little Rock"},{"v":87}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"number","id":"Aaaaaaaaa","label":"Aaaaaaaaa"}]});
#
#         // Add formatters, if any
#
#         // Create ChartWrapper
#         var google_chart_14 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_14_div_id",
#             "dataTable": jooglechart_13_data,
#             "view": {columns: null},
#             "chartType": "PieChart",
#             "options": {"fontName": "Helvetica Neue", "hAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "chartArea": {"width": 500, "top": 10, "height": 325, "left": 0}, "height": 375, "width": 500, "fontSize": 12, "vAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "titleTextStyle": {"fontSize": 16}, "legend": {"position": "none"}}
#         });
#
#         google_chart_14.draw();
#
# 		// -------------- Add chartwrapper senders, if any -------------
#
# 		// -------------------------------------------------------------
#
# 		// -------------- Add chartwrapper receivers, if any -------------
#
# 		// ---------------------------------------------------------------
#
#
#     }
#
# </script>
#
#
#
#
# <div id="google_chart_14_div_id" class="jooglechart_container jooglechart_type_PieChart" style="border: 10px solid gray"></div>
#
#
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_15);
# });
#
#     function doStuff_15() {
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jooglechart_15_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"Sacramento"},{"v":97}]},{"c":[{"v":"Montpelier"},{"v":96}]},{"c":[{"v":"Juneau"},{"v":24}]},{"c":[{"v":"Montgomery"},{"v":26}]},{"c":[{"v":"Little Rock"},{"v":87}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"number","id":"Aaaaaaaaa","label":"Aaaaaaaaa"}]});
#
#         // Add formatters, if any
#
#         // Create ChartWrapper
#         var google_chart_16 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_16_div_id",
#             "dataTable": jooglechart_15_data,
#             "view": {columns: null},
#             "chartType": "BarChart",
#             "options": {"fontName": "Helvetica Neue", "bar": {"groupWidth": 41}, "hAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "chartArea": {"width": 250, "top": 10, "height": 325, "left": 100}, "height": 375, "width": 350, "colors": ["green"], "fontSize": 12, "vAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "titleTextStyle": {"fontSize": 16}, "legend": {"position": "none"}}
#         });
#
#         google_chart_16.draw();
#
# 		// -------------- Add chartwrapper senders, if any -------------
#
# 		// -------------------------------------------------------------
#
# 		// -------------- Add chartwrapper receivers, if any -------------
#
# 		// ---------------------------------------------------------------
#
#
#     }
#
# </script>
#
#
#
#
# <div id="google_chart_16_div_id" class="jooglechart_container jooglechart_type_BarChart" style="border: 10px solid orange"></div>
#
#
# </div>
#
# <style>
# #joogle_box_12 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
# </div>
#
#
# <style>
# .joogle_clearfix:after {
#     content:" ";
#     display:block;
#     clear:both;
# }
#
# #joogle_chartrow_9 > .joogle_chartrow_column {
# 	box-sizing: border-box;
# 	float: left;
# }
#
# </style>

# %% [markdown]
# # Row, Row, Row your chart!

# %% [markdown]
# # ChartRow now has four modes (not in production)

# %%
# 1.  bootstrap (default)
row1 = ChartRow(chart1, chart1.copy(), mode="bootstrap")

# 2.  free
row2 = ChartRow(chart1, chart1.copy(), mode="free")

# 3.  weighted
row3 = ChartRow(chart1, chart1.copy(), mode="weighted", weights = [24, 53])

# 4.  fixed
row4 = ChartRow(chart1, chart1.copy(), mode="fixed", widths = ["300px", "200px"])

# %% [markdown]
# # Bootstrap mode (default)
# ### Evenly spaced columns, responsive

# %%
box1 = Box("")
box1.add_div_styles(background_color="chartreuse", height="300px", width="100px")

box2 = Box("")
box2.add_div_styles(background_color="blueviolet", height="300px", width="100px")

row = ChartRow(box1, box2)

row.show()
# Out:
# <div class="row" id="joogle_chartrow_17" >
#     <div class="col-sm-6">
#
# <div id="joogle_box_18" style="width: 100px; background-color: chartreuse; height: 300px">
#
# </div>
#
# <style>
# #joogle_box_18 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
#     <div class="col-sm-6">
#
# <div id="joogle_box_19" style="width: 100px; background-color: blueviolet; height: 300px">
#
# </div>
#
# <style>
# #joogle_box_19 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
# </div>
#
#
# <style>
# .joogle_clearfix:after {
#     content:" ";
#     display:block;
#     clear:both;
# }
#
# #joogle_chartrow_17 > .joogle_chartrow_column {
# 	box-sizing: border-box;
# 	float: left;
# }
#
# </style>

# %% [markdown]
# # free mode
# ### No specified spacing

# %%
row = ChartRow(box1, box2, mode="free")
row.show()
# Out:
# <div class="joogle_clearfix" id="joogle_chartrow_20" >
#     <div class="joogle_chartrow_column" >
#
# <div id="joogle_box_21" style="width: 100px; background-color: chartreuse; height: 300px">
#
#
# </div>
#
# <style>
# #joogle_box_21 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <div id="joogle_box_22" style="width: 100px; background-color: blueviolet; height: 300px">
#
#
# </div>
#
# <style>
# #joogle_box_22 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
# </div>
#
#
# <style>
# .joogle_clearfix:after {
#     content:" ";
#     display:block;
#     clear:both;
# }
#
# #joogle_chartrow_20 > .joogle_chartrow_column {
# 	box-sizing: border-box;
# 	float: left;
# }
#
# </style>

# %% [markdown]
# # Weighted mode
# ### Pass a list of weights.  These are translated proportionally into percentage widths.

# %%
row = ChartRow(box1, box2, mode="weighted", weights=[3, 8])
row.show()
# Out:
# <div class="joogle_clearfix" id="joogle_chartrow_23" >
#     <div class="joogle_chartrow_column" style="width:27.0%">
#
# <div id="joogle_box_24" style="width: 100px; background-color: chartreuse; height: 300px">
#
#
#
# </div>
#
# <style>
# #joogle_box_24 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
#     <div class="joogle_chartrow_column" style="width:72.0%">
#
# <div id="joogle_box_25" style="width: 100px; background-color: blueviolet; height: 300px">
#
#
#
# </div>
#
# <style>
# #joogle_box_25 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
# </div>
#
#
# <style>
# .joogle_clearfix:after {
#     content:" ";
#     display:block;
#     clear:both;
# }
#
# #joogle_chartrow_23 > .joogle_chartrow_column {
# 	box-sizing: border-box;
# 	float: left;
# }
#
# </style>

# %% [markdown]
# # Fixed mode
# ### Pass a list of widths:  integers (as pixels), or strings ("150px", "20em")

# %%
row = ChartRow(box1, box2, mode="fixed", widths = [800, "200px"])
row.show()
# Out:
# <div class="joogle_clearfix" id="joogle_chartrow_26" >
#     <div class="joogle_chartrow_column" style="width:800px">
#
# <div id="joogle_box_27" style="width: 100px; background-color: chartreuse; height: 300px">
#
#
#
#
# </div>
#
# <style>
# #joogle_box_27 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
#     <div class="joogle_chartrow_column" style="width:200px">
#
# <div id="joogle_box_28" style="width: 100px; background-color: blueviolet; height: 300px">
#
#
#
#
# </div>
#
# <style>
# #joogle_box_28 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
# </div>
#
#
# <style>
# .joogle_clearfix:after {
#     content:" ";
#     display:block;
#     clear:both;
# }
#
# #joogle_chartrow_26 > .joogle_chartrow_column {
# 	box-sizing: border-box;
# 	float: left;
# }
#
# </style>

# %% [markdown]
# # Free mode with padding

# %%
row = ChartRow(box1, box2, mode="free", padding=10)
row.show()
# Out:
# <div class="joogle_clearfix" id="joogle_chartrow_29" >
#     <div class="joogle_chartrow_column" >
#
# <div id="joogle_box_30" style="width: 100px; background-color: chartreuse; height: 300px">
#
#
#
#
#
# </div>
#
# <style>
# #joogle_box_30 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <div id="joogle_box_31" style="width: 100px; background-color: blueviolet; height: 300px">
#
#
#
#
#
# </div>
#
# <style>
# #joogle_box_31 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
# </div>
#
#
# <style>
# .joogle_clearfix:after {
#     content:" ";
#     display:block;
#     clear:both;
# }
#
# #joogle_chartrow_29 > .joogle_chartrow_column {
# 	box-sizing: border-box;
# 	float: left;
# 	padding-left: 10px;
# 	padding-right: 10px;
# }
#
# </style>

# %% [markdown]
# # Just because

# %%
boxes = []
width = 1
ctr = 0
total = 5
while total < 1000:
    if ctr % 2 == 0:
        color = 'orange'
    else:
        color = 'green'

    box = Box("")
    width_str = str(width) + "px"
    box.add_div_styles(background_color=color, width=width_str, height="300px")
    boxes.append(box)
    width = width * 1.1
    total += width
    ctr += 1

row = ChartRow(*boxes, mode="free")

row.show()
# Out:
# <div class="joogle_clearfix" id="joogle_chartrow_32" >
#     <div class="joogle_chartrow_column" >
#
# <div id="joogle_box_33" style="width: 1px; background-color: orange; height: 300px">
#
# </div>
#
# <style>
# #joogle_box_33 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <div id="joogle_box_34" style="width: 1.1px; background-color: green; height: 300px">
#
# </div>
#
# <style>
# #joogle_box_34 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <div id="joogle_box_35" style="width: 1.21px; background-color: orange; height: 300px">
#
# </div>
#
# <style>
# #joogle_box_35 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <div id="joogle_box_36" style="width: 1.331px; background-color: green; height: 300px">
#
# </div>
#
# <style>
# #joogle_box_36 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <div id="joogle_box_37" style="width: 1.4641px; background-color: orange; height: 300px">
#
# </div>
#
# <style>
# #joogle_box_37 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <div id="joogle_box_38" style="width: 1.61051px; background-color: green; height: 300px">
#
# </div>
#
# <style>
# #joogle_box_38 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <div id="joogle_box_39" style="width: 1.771561px; background-color: orange; height: 300px">
#
# </div>
#
# <style>
# #joogle_box_39 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <div id="joogle_box_40" style="width: 1.9487171px; background-color: green; height: 300px">
#
# </div>
#
# <style>
# #joogle_box_40 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <div id="joogle_box_41" style="width: 2.14358881px; background-color: orange; height: 300px">
#
# </div>
#
# <style>
# #joogle_box_41 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <div id="joogle_box_42" style="width: 2.357947691px; background-color: green; height: 300px">
#
# </div>
#
# <style>
# #joogle_box_42 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <div id="joogle_box_43" style="width: 2.5937424601px; background-color: orange; height: 300px">
#
# </div>
#
# <style>
# #joogle_box_43 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <div id="joogle_box_44" style="width: 2.85311670611px; background-color: green; height: 300px">
#
# </div>
#
# <style>
# #joogle_box_44 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <div id="joogle_box_45" style="width: 3.13842837672px; background-color: orange; height: 300px">
#
# </div>
#
# <style>
# #joogle_box_45 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <div id="joogle_box_46" style="width: 3.45227121439px; background-color: green; height: 300px">
#
# </div>
#
# <style>
# #joogle_box_46 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <div id="joogle_box_47" style="width: 3.79749833583px; background-color: orange; height: 300px">
#
# </div>
#
# <style>
# #joogle_box_47 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <div id="joogle_box_48" style="width: 4.17724816942px; background-color: green; height: 300px">
#
# </div>
#
# <style>
# #joogle_box_48 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <div id="joogle_box_49" style="width: 4.59497298636px; background-color: orange; height: 300px">
#
# </div>
#
# <style>
# #joogle_box_49 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <div id="joogle_box_50" style="width: 5.05447028499px; background-color: green; height: 300px">
#
# </div>
#
# <style>
# #joogle_box_50 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <div id="joogle_box_51" style="width: 5.55991731349px; background-color: orange; height: 300px">
#
# </div>
#
# <style>
# #joogle_box_51 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <div id="joogle_box_52" style="width: 6.11590904484px; background-color: green; height: 300px">
#
# </div>
#
# <style>
# #joogle_box_52 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <div id="joogle_box_53" style="width: 6.72749994933px; background-color: orange; height: 300px">
#
# </div>
#
# <style>
# #joogle_box_53 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <div id="joogle_box_54" style="width: 7.40024994426px; background-color: green; height: 300px">
#
# </div>
#
# <style>
# #joogle_box_54 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <div id="joogle_box_55" style="width: 8.14027493868px; background-color: orange; height: 300px">
#
# </div>
#
# <style>
# #joogle_box_55 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <div id="joogle_box_56" style="width: 8.95430243255px; background-color: green; height: 300px">
#
# </div>
#
# <style>
# #joogle_box_56 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <div id="joogle_box_57" style="width: 9.84973267581px; background-color: orange; height: 300px">
#
# </div>
#
# <style>
# #joogle_box_57 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <div id="joogle_box_58" style="width: 10.8347059434px; background-color: green; height: 300px">
#
# </div>
#
# <style>
# #joogle_box_58 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <div id="joogle_box_59" style="width: 11.9181765377px; background-color: orange; height: 300px">
#
# </div>
#
# <style>
# #joogle_box_59 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <div id="joogle_box_60" style="width: 13.1099941915px; background-color: green; height: 300px">
#
# </div>
#
# <style>
# #joogle_box_60 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <div id="joogle_box_61" style="width: 14.4209936106px; background-color: orange; height: 300px">
#
# </div>
#
# <style>
# #joogle_box_61 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <div id="joogle_box_62" style="width: 15.8630929717px; background-color: green; height: 300px">
#
# </div>
#
# <style>
# #joogle_box_62 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <div id="joogle_box_63" style="width: 17.4494022689px; background-color: orange; height: 300px">
#
# </div>
#
# <style>
# #joogle_box_63 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <div id="joogle_box_64" style="width: 19.1943424958px; background-color: green; height: 300px">
#
# </div>
#
# <

# %% [markdown]
# # Moving on to sonar...

# %% [markdown]
# # 1. Filters can update other filters

# %% [markdown]
# # Filter senders and filter receivers

# %%
df1 = get_df()

f1 = Filter("CategoryFilter")
f1.add_options(filterColumnIndex=0)
f1.add_sender(key="AAA")

chart1 = JoogleChart(df1)
chart1.add_styler(get_styler())
chart1.add_filter(f1)

chart2 = JoogleChart(df1, chart_type="BarChart")
chart2.add_styler(get_styler())
f2 = Filter("CategoryFilter")
f2.add_options(filterColumnIndex=0)
f2.add_receiver(key="AAA")
chart2.add_filter(f2)

row = ChartRow(chart1, chart2)
row.show()
# Out:
# <div class="row" id="joogle_chartrow_81" >
#     <div class="col-sm-6">
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_82);
# });
#
#     function doStuff_82() {
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jooglechart_82_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"Sacramento"},{"v":97}]},{"c":[{"v":"Montpelier"},{"v":96}]},{"c":[{"v":"Juneau"},{"v":24}]},{"c":[{"v":"Montgomery"},{"v":26}]},{"c":[{"v":"Little Rock"},{"v":87}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"number","id":"Aaaaaaaaa","label":"Aaaaaaaaa"}]});
#
#         // Add formatters, if any
#
#         // Create ChartWrapper
#         var google_chart_83 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_83_div_id",
#             "dataTable": jooglechart_82_data,
#             "view": {columns: null},
#             "chartType": "ColumnChart",
#             "options": {"fontName": "Helvetica Neue", "bar": {"groupWidth": 55}, "hAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "chartArea": {"width": 440, "top": 20, "height": 295, "left": 60}, "height": 375, "width": 500, "fontSize": 12, "vAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "titleTextStyle": {"fontSize": 16}, "legend": {"position": "top"}}
#         });
#
#         // Create a dashboard.
#         var jooglechart_82_dashboard = new google.visualization.Dashboard(
#             document.getElementById('jooglechart_82_dashboard_div_id'));
#
#         // Create controls
#
#         var google_filter_84 = new google.visualization.ControlWrapper({
#           'controlType': 'CategoryFilter',
#           'containerId': 'google_filter_84_div_id',
#           'options': {"filterColumnIndex": 0},
#           'state': {}
#         });
#
#         // Establish dependencies.
# 		jooglechart_82_dashboard.bind(google_filter_84, google_chart_83);
#
# 		var binding_selections_google_filter_84 = {};
# 		// ------------- Add filter sonar senders, if any ----------
#
# 		// we have to delete any persisten values in the map when rerunning jupyter notebook cells
# 		delete joogle_globals.sonar.message_map["AAA"];        google.visualization.events.addListener(google_filter_84, "statechange", function () {
# 			var selected_values = google_filter_84.getState().selectedValues;
# 			// if the selectedValues is empty, then defer to the binding selections.
# 			// So the chart downstream will still have selections if the binding filter has
# 			// a selection.
# 			if (selected_values.length == 0) {
# 				selected_values = joogle_globals.get_binding_selections(binding_selections_google_filter_84, jooglechart_82_data);
# 			}
# 			joogle_globals.sonar.send("AAA", selected_values);
#
# 		});
#
# 				// ---------------------------------------------------------
#
# 		// ----------- Add filter sonar receivers, if any ----------
# 				// ---------------------------------------------------------
#
#         // Draw the dashboard.
#         jooglechart_82_dashboard.draw(jooglechart_82_data);
#
#
#
# 		// -------------- Add chartwrapper senders, if any -------------
#
# 		// -------------------------------------------------------------
#
# 		// -------------- Add chartwrapper receivers, if any -------------
#
# 		// ---------------------------------------------------------------
#
#
#     }
#
# </script>
#
#
#
#
# <div id="jooglechart_82_dashboard_div_id">
# 	<div id="google_filter_84_div_id" ></div>
#
# <div id="google_chart_83_div_id" class="jooglechart_container jooglechart_type_ColumnChart" ></div>
#
# </div>
#
#     </div>
#     <div class="col-sm-6">
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_85);
# });
#
#     function doStuff_85() {
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jooglechart_85_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"Sacramento"},{"v":97}]},{"c":[{"v":"Montpelier"},{"v":96}]},{"c":[{"v":"Juneau"},{"v":24}]},{"c":[{"v":"Montgomery"},{"v":26}]},{"c":[{"v":"Little Rock"},{"v":87}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"number","id":"Aaaaaaaaa","label":"Aaaaaaaaa"}]});
#
#         // Add formatters, if any
#
#         // Create ChartWrapper
#         var google_chart_86 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_86_div_id",
#             "dataTable": jooglechart_85_data,
#             "view": {columns: null},
#             "chartType": "BarChart",
#             "options": {"fontName": "Helvetica Neue", "bar": {"groupWidth": 39}, "hAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "chartArea": {"width": 400, "top": 20, "height": 315, "left": 100}, "height": 375, "width": 500, "fontSize": 12, "vAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "titleTextStyle": {"fontSize": 16}, "legend": {"position": "top"}}
#         });
#
#         // Create a dashboard.
#         var jooglechart_85_dashboard = new google.visualization.Dashboard(
#             document.getElementById('jooglechart_85_dashboard_div_id'));
#
#         // Create controls
#
#         var google_filter_87 = new google.visualization.ControlWrapper({
#           'controlType': 'CategoryFilter',
#           'containerId': 'google_filter_87_div_id',
#           'options': {"filterColumnIndex": 0},
#           'state': {}
#         });
#
#         // Establish dependencies.
# 		jooglechart_85_dashboard.bind(google_filter_87, google_chart_86);
#
# 		var binding_selections_google_filter_87 = {};
# 		// ------------- Add filter sonar senders, if any ----------
#
# 				// ---------------------------------------------------------
#
# 		// ----------- Add filter sonar receivers, if any ----------
#
# 		(function(key, filter, div_id) {
# 			var func = function(data) {
# 				if (data.sonar_key === key && document.getElementById(div_id) !== null) {
# 					joogle_globals.update_category_filter(filter, data.sonar_value);
# 				}
# 			}
# 			joogle_globals.sonar.add_handler(func);
# 			joogle_globals.sonar.add_one_time_ready_poller(key, func, filter);
# 		})("AAA", google_filter_87, "google_filter_87_div_id");
# 				// ---------------------------------------------------------
#
#         // Draw the dashboard.
#         jooglechart_85_dashboard.draw(jooglechart_85_data);
#
#
#
# 		// -------------- Add chartwrapper senders, if any -------------
#
# 		// -------------------------------------------------------------
#
# 		// -------------- Add chartwrapper receivers, if any -------------
#
# 		// ---------------------------------------------------------------
#
#
#     }
#
# </script>
#
#
#
#
# <div id="jooglechart_85_dashboard_div_id">
# 	<div id="google_filter_87_div_id" ></div>
#
# <div id="google_chart_86_div_id" class="jooglechart_container jooglechart_type_BarChart" ></div>
#
# </div>
#
#     </div>
# </div>
#
#
# <style>
# .joogle_clearfix:after {
#     content:" ";
#     display:block;
#     clear:both;
# }
#
# #joogle_chartrow_81 > .joogle_chartrow_column {
# 	box-sizing: border-box;
# 	float: left;
# }
#
# </style>

# %% [markdown]
# # Filter sender to filter receiver (while hiding a filter)

# %%
f1 = Filter("CategoryFilter")
f1.add_options(filterColumnIndex=0)
f1.add_sender(key="CIA")

chart1 = JoogleChart(df1)
chart1.add_styler(get_styler())
chart1.add_filter(f1)

chart2 = JoogleChart(df1, chart_type="BarChart")
chart2.add_styler(get_styler())
chart2.add_filter(f2)
chart2.add_chart_options(colors=['green'])

f2 = Filter("CategoryFilter")
f2.add_options(filterColumnIndex=0)
f2.add_receiver(key="CIA")
f2.add_options(ui_cssClass="hidden")

row = ChartRow(chart1, chart2)
row.show()
# print row.render(include_common=True)
# Out:
# <div class="row" id="joogle_chartrow_88" >
#     <div class="col-sm-6">
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_89);
# });
#
#     function doStuff_89() {
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jooglechart_89_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"Sacramento"},{"v":97}]},{"c":[{"v":"Montpelier"},{"v":96}]},{"c":[{"v":"Juneau"},{"v":24}]},{"c":[{"v":"Montgomery"},{"v":26}]},{"c":[{"v":"Little Rock"},{"v":87}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"number","id":"Aaaaaaaaa","label":"Aaaaaaaaa"}]});
#
#         // Add formatters, if any
#
#         // Create ChartWrapper
#         var google_chart_90 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_90_div_id",
#             "dataTable": jooglechart_89_data,
#             "view": {columns: null},
#             "chartType": "ColumnChart",
#             "options": {"fontName": "Helvetica Neue", "bar": {"groupWidth": 55}, "hAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "chartArea": {"width": 440, "top": 20, "height": 295, "left": 60}, "height": 375, "width": 500, "fontSize": 12, "vAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "titleTextStyle": {"fontSize": 16}, "legend": {"position": "top"}}
#         });
#
#         // Create a dashboard.
#         var jooglechart_89_dashboard = new google.visualization.Dashboard(
#             document.getElementById('jooglechart_89_dashboard_div_id'));
#
#         // Create controls
#
#         var google_filter_91 = new google.visualization.ControlWrapper({
#           'controlType': 'CategoryFilter',
#           'containerId': 'google_filter_91_div_id',
#           'options': {"filterColumnIndex": 0},
#           'state': {}
#         });
#
#         // Establish dependencies.
# 		jooglechart_89_dashboard.bind(google_filter_91, google_chart_90);
#
# 		var binding_selections_google_filter_91 = {};
# 		// ------------- Add filter sonar senders, if any ----------
#
# 		// we have to delete any persisten values in the map when rerunning jupyter notebook cells
# 		delete joogle_globals.sonar.message_map["CIA"];        google.visualization.events.addListener(google_filter_91, "statechange", function () {
# 			var selected_values = google_filter_91.getState().selectedValues;
# 			// if the selectedValues is empty, then defer to the binding selections.
# 			// So the chart downstream will still have selections if the binding filter has
# 			// a selection.
# 			if (selected_values.length == 0) {
# 				selected_values = joogle_globals.get_binding_selections(binding_selections_google_filter_91, jooglechart_89_data);
# 			}
# 			joogle_globals.sonar.send("CIA", selected_values);
#
# 		});
#
# 				// ---------------------------------------------------------
#
# 		// ----------- Add filter sonar receivers, if any ----------
# 				// ---------------------------------------------------------
#
#         // Draw the dashboard.
#         jooglechart_89_dashboard.draw(jooglechart_89_data);
#
#
#
# 		// -------------- Add chartwrapper senders, if any -------------
#
# 		// -------------------------------------------------------------
#
# 		// -------------- Add chartwrapper receivers, if any -------------
#
# 		// ---------------------------------------------------------------
#
#
#     }
#
# </script>
#
#
#
#
# <div id="jooglechart_89_dashboard_div_id">
# 	<div id="google_filter_91_div_id" ></div>
#
# <div id="google_chart_90_div_id" class="jooglechart_container jooglechart_type_ColumnChart" ></div>
#
# </div>
#
#     </div>
#     <div class="col-sm-6">
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_92);
# });
#
#     function doStuff_92() {
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jooglechart_92_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"Sacramento"},{"v":97}]},{"c":[{"v":"Montpelier"},{"v":96}]},{"c":[{"v":"Juneau"},{"v":24}]},{"c":[{"v":"Montgomery"},{"v":26}]},{"c":[{"v":"Little Rock"},{"v":87}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"number","id":"Aaaaaaaaa","label":"Aaaaaaaaa"}]});
#
#         // Add formatters, if any
#
#         // Create ChartWrapper
#         var google_chart_93 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_93_div_id",
#             "dataTable": jooglechart_92_data,
#             "view": {columns: null},
#             "chartType": "BarChart",
#             "options": {"fontName": "Helvetica Neue", "bar": {"groupWidth": 39}, "hAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "chartArea": {"width": 400, "top": 20, "height": 315, "left": 100}, "height": 375, "width": 500, "colors": ["green"], "fontSize": 12, "vAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "titleTextStyle": {"fontSize": 16}, "legend": {"position": "top"}}
#         });
#
#         // Create a dashboard.
#         var jooglechart_92_dashboard = new google.visualization.Dashboard(
#             document.getElementById('jooglechart_92_dashboard_div_id'));
#
#         // Create controls
#
#         var google_filter_94 = new google.visualization.ControlWrapper({
#           'controlType': 'CategoryFilter',
#           'containerId': 'google_filter_94_div_id',
#           'options': {"filterColumnIndex": 0},
#           'state': {}
#         });
#
#         // Establish dependencies.
# 		jooglechart_92_dashboard.bind(google_filter_94, google_chart_93);
#
# 		var binding_selections_google_filter_94 = {};
# 		// ------------- Add filter sonar senders, if any ----------
#
# 				// ---------------------------------------------------------
#
# 		// ----------- Add filter sonar receivers, if any ----------
#
# 		(function(key, filter, div_id) {
# 			var func = function(data) {
# 				if (data.sonar_key === key && document.getElementById(div_id) !== null) {
# 					joogle_globals.update_category_filter(filter, data.sonar_value);
# 				}
# 			}
# 			joogle_globals.sonar.add_handler(func);
# 			joogle_globals.sonar.add_one_time_ready_poller(key, func, filter);
# 		})("AAA", google_filter_94, "google_filter_94_div_id");
# 				// ---------------------------------------------------------
#
#         // Draw the dashboard.
#         jooglechart_92_dashboard.draw(jooglechart_92_data);
#
#
#
# 		// -------------- Add chartwrapper senders, if any -------------
#
# 		// -------------------------------------------------------------
#
# 		// -------------- Add chartwrapper receivers, if any -------------
#
# 		// ---------------------------------------------------------------
#
#
#     }
#
# </script>
#
#
#
#
# <div id="jooglechart_92_dashboard_div_id">
# 	<div id="google_filter_94_div_id" ></div>
#
# <div id="google_chart_93_div_id" class="jooglechart_container jooglechart_type_BarChart" ></div>
#
# </div>
#
#     </div>
# </div>
#
#
# <style>
# .joogle_clearfix:after {
#     content:" ";
#     display:block;
#     clear:both;
# }
#
# #joogle_chartrow_88 > .joogle_chartrow_column {
# 	box-sizing: border-box;
# 	float: left;
# }
#
# </style>

# %% [markdown]
# # 2. Charts can now be updated directly!  No filter!

# %% [markdown]
# # Filter to chart

# %%
# Specify the column on the chart to be filtered

f1 = Filter("CategoryFilter")
f1.add_options(filterColumnIndex=0)
f1.add_sender(key="DMV")

chart1 = JoogleChart(df1)
chart1.add_styler(get_styler())
chart1.add_filter(f1)

chart2 = JoogleChart(df1, chart_type="BarChart")
chart2.add_styler(get_styler())
chart2.add_chart_options(colors=['orange'])
chart2.add_receiver(key="DMV", column=0)

row = ChartRow(chart1, chart2)
row.show()
# Out:
# <div class="row" id="joogle_chartrow_95" >
#     <div class="col-sm-6">
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_96);
# });
#
#     function doStuff_96() {
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jooglechart_96_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"Sacramento"},{"v":97}]},{"c":[{"v":"Montpelier"},{"v":96}]},{"c":[{"v":"Juneau"},{"v":24}]},{"c":[{"v":"Montgomery"},{"v":26}]},{"c":[{"v":"Little Rock"},{"v":87}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"number","id":"Aaaaaaaaa","label":"Aaaaaaaaa"}]});
#
#         // Add formatters, if any
#
#         // Create ChartWrapper
#         var google_chart_97 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_97_div_id",
#             "dataTable": jooglechart_96_data,
#             "view": {columns: null},
#             "chartType": "ColumnChart",
#             "options": {"fontName": "Helvetica Neue", "bar": {"groupWidth": 55}, "hAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "chartArea": {"width": 440, "top": 20, "height": 295, "left": 60}, "height": 375, "width": 500, "fontSize": 12, "vAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "titleTextStyle": {"fontSize": 16}, "legend": {"position": "top"}}
#         });
#
#         // Create a dashboard.
#         var jooglechart_96_dashboard = new google.visualization.Dashboard(
#             document.getElementById('jooglechart_96_dashboard_div_id'));
#
#         // Create controls
#
#         var google_filter_98 = new google.visualization.ControlWrapper({
#           'controlType': 'CategoryFilter',
#           'containerId': 'google_filter_98_div_id',
#           'options': {"filterColumnIndex": 0},
#           'state': {}
#         });
#
#         // Establish dependencies.
# 		jooglechart_96_dashboard.bind(google_filter_98, google_chart_97);
#
# 		var binding_selections_google_filter_98 = {};
# 		// ------------- Add filter sonar senders, if any ----------
#
# 		// we have to delete any persisten values in the map when rerunning jupyter notebook cells
# 		delete joogle_globals.sonar.message_map["DMV"];        google.visualization.events.addListener(google_filter_98, "statechange", function () {
# 			var selected_values = google_filter_98.getState().selectedValues;
# 			// if the selectedValues is empty, then defer to the binding selections.
# 			// So the chart downstream will still have selections if the binding filter has
# 			// a selection.
# 			if (selected_values.length == 0) {
# 				selected_values = joogle_globals.get_binding_selections(binding_selections_google_filter_98, jooglechart_96_data);
# 			}
# 			joogle_globals.sonar.send("DMV", selected_values);
#
# 		});
#
# 				// ---------------------------------------------------------
#
# 		// ----------- Add filter sonar receivers, if any ----------
# 				// ---------------------------------------------------------
#
#         // Draw the dashboard.
#         jooglechart_96_dashboard.draw(jooglechart_96_data);
#
#
#
# 		// -------------- Add chartwrapper senders, if any -------------
#
# 		// -------------------------------------------------------------
#
# 		// -------------- Add chartwrapper receivers, if any -------------
#
# 		// ---------------------------------------------------------------
#
#
#     }
#
# </script>
#
#
#
#
# <div id="jooglechart_96_dashboard_div_id">
# 	<div id="google_filter_98_div_id" ></div>
#
# <div id="google_chart_97_div_id" class="jooglechart_container jooglechart_type_ColumnChart" ></div>
#
# </div>
#
#     </div>
#     <div class="col-sm-6">
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_99);
# });
#
#     function doStuff_99() {
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jooglechart_99_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"Sacramento"},{"v":97}]},{"c":[{"v":"Montpelier"},{"v":96}]},{"c":[{"v":"Juneau"},{"v":24}]},{"c":[{"v":"Montgomery"},{"v":26}]},{"c":[{"v":"Little Rock"},{"v":87}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"number","id":"Aaaaaaaaa","label":"Aaaaaaaaa"}]});
#
#         // Add formatters, if any
#
#         // Create ChartWrapper
#         var google_chart_100 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_100_div_id",
#             "dataTable": jooglechart_99_data,
#             "view": {columns: null},
#             "chartType": "BarChart",
#             "options": {"fontName": "Helvetica Neue", "bar": {"groupWidth": 39}, "hAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "chartArea": {"width": 400, "top": 20, "height": 315, "left": 100}, "height": 375, "width": 500, "colors": ["orange"], "fontSize": 12, "vAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "titleTextStyle": {"fontSize": 16}, "legend": {"position": "top"}}
#         });
#
#         google_chart_100.draw();
#
# 		// -------------- Add chartwrapper senders, if any -------------
#
# 		// -------------------------------------------------------------
#
# 		// -------------- Add chartwrapper receivers, if any -------------
# 		(function(key, chart, datatable, chart_div_id, col, view_cols) {
# 			var func = function(data) {
# 				if (data.sonar_key === key && document.getElementById(chart_div_id) !== null) {
# 					joogle_globals.update_chart(data.sonar_value, datatable, chart, col, view_cols);
# 				}
# 			}
# 			joogle_globals.sonar.add_handler(func);
# 			joogle_globals.sonar.add_one_time_ready_poller(key, func, chart);
# 		})("DMV", google_chart_100, jooglechart_99_data, "google_chart_100_div_id", 0, null);
#
# 		// ---------------------------------------------------------------
#
#
#     }
#
# </script>
#
#
#
#
# <div id="google_chart_100_div_id" class="jooglechart_container jooglechart_type_BarChart" ></div>
#
#
#     </div>
# </div>
#
#
# <style>
# .joogle_clearfix:after {
#     content:" ";
#     display:block;
#     clear:both;
# }
#
# #joogle_chartrow_95 > .joogle_chartrow_column {
# 	box-sizing: border-box;
# 	float: left;
# }
#
# </style>

# %% [markdown]
# # 3. Click a chart, send a message!

# %% [markdown]
# ## Chart sender to chart

# %%
# Specify the columns for sending data and for receiving data

chart1 = JoogleChart(df1)
chart1.add_styler(get_styler())
chart1.add_sender(key="FBI", column=0)

chart2 = JoogleChart(df1, chart_type="Table")
chart2.add_receiver(key="FBI", column=0)

row = ChartRow(chart1, chart2)
row.show()
# Out:
# <div class="row" id="joogle_chartrow_101" >
#     <div class="col-sm-6">
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_102);
# });
#
#     function doStuff_102() {
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jooglechart_102_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"Sacramento"},{"v":97}]},{"c":[{"v":"Montpelier"},{"v":96}]},{"c":[{"v":"Juneau"},{"v":24}]},{"c":[{"v":"Montgomery"},{"v":26}]},{"c":[{"v":"Little Rock"},{"v":87}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"number","id":"Aaaaaaaaa","label":"Aaaaaaaaa"}]});
#
#         // Add formatters, if any
#
#         // Create ChartWrapper
#         var google_chart_103 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_103_div_id",
#             "dataTable": jooglechart_102_data,
#             "view": {columns: null},
#             "chartType": "ColumnChart",
#             "options": {"fontName": "Helvetica Neue", "bar": {"groupWidth": 55}, "hAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "chartArea": {"width": 440, "top": 20, "height": 295, "left": 60}, "height": 375, "width": 500, "fontSize": 12, "vAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "titleTextStyle": {"fontSize": 16}, "legend": {"position": "top"}}
#         });
#
#         google_chart_103.draw();
#
# 		// -------------- Add chartwrapper senders, if any -------------
# 		// we have to delete any persisten values in the map when rerunning jupyter notebook cells
# 		delete joogle_globals.sonar.message_map["FBI"];        google.visualization.events.addListener(google_chart_103, 'select', function() {
#   			var selection = google_chart_103.getChart().getSelection()[0];
# 			//var true_selection_row =  google_chart_103.getDataTable().getTableRowIndex(selection.row);
#
# 			if (typeof selection !== "undefined" && selection.row !== null) {
# 				var dt = google_chart_103.getDataTable();
# 				var selected_category = dt.getValue(selection.row, 0);
# 				//var selected_category = jooglechart_102_data.getValue(true_selection_row, 0);
# 				joogle_globals.sonar.send('FBI', [selected_category]);
# 			}
# 		});
#
# 		// -------------------------------------------------------------
#
# 		// -------------- Add chartwrapper receivers, if any -------------
#
# 		// ---------------------------------------------------------------
#
#
#     }
#
# </script>
#
#
#
#
# <div id="google_chart_103_div_id" class="jooglechart_container jooglechart_type_ColumnChart" ></div>
#
#
#     </div>
#     <div class="col-sm-6">
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_104);
# });
#
#     function doStuff_104() {
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jooglechart_104_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"Sacramento"},{"v":97}]},{"c":[{"v":"Montpelier"},{"v":96}]},{"c":[{"v":"Juneau"},{"v":24}]},{"c":[{"v":"Montgomery"},{"v":26}]},{"c":[{"v":"Little Rock"},{"v":87}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"number","id":"Aaaaaaaaa","label":"Aaaaaaaaa"}]});
#
#         // Add formatters, if any
#
#         // Create ChartWrapper
#         var google_chart_105 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_105_div_id",
#             "dataTable": jooglechart_104_data,
#             "view": {columns: null},
#             "chartType": "Table",
#             "options": {}
#         });
#
#         google_chart_105.draw();
#
# 		// -------------- Add chartwrapper senders, if any -------------
#
# 		// -------------------------------------------------------------
#
# 		// -------------- Add chartwrapper receivers, if any -------------
# 		(function(key, chart, datatable, chart_div_id, col, view_cols) {
# 			var func = function(data) {
# 				if (data.sonar_key === key && document.getElementById(chart_div_id) !== null) {
# 					joogle_globals.update_chart(data.sonar_value, datatable, chart, col, view_cols);
# 				}
# 			}
# 			joogle_globals.sonar.add_handler(func);
# 			joogle_globals.sonar.add_one_time_ready_poller(key, func, chart);
# 		})("FBI", google_chart_105, jooglechart_104_data, "google_chart_105_div_id", 0, null);
#
# 		// ---------------------------------------------------------------
#
#
#     }
#
# </script>
#
#
#
#
# <div id="google_chart_105_div_id" class="jooglechart_container jooglechart_type_Table" ></div>
#
#
#     </div>
# </div>
#
#
# <style>
# .joogle_clearfix:after {
#     content:" ";
#     display:block;
#     clear:both;
# }
#
# #joogle_chartrow_101 > .joogle_chartrow_column {
# 	box-sizing: border-box;
# 	float: left;
# }
#
# </style>

# %% [markdown]
# # 4.  Filters can be created without a chart at all!

# %% [markdown]
# # Standalone filter:  CategoryFilter

# %%
# Pass a dataframe to the filter and specify the column
f1 = Filter("CategoryFilter", data=df1)
f1.add_options(filterColumnIndex=0)
f1.add_sender(key="NFL")

chart1 = JoogleChart(df1)
chart1.add_styler(get_styler())
chart1.add_receiver(key="NFL", column=0)

row = ChartRow(f1, chart1, mode="fixed", widths=[270, 400])
row.show()
# Out:
# <div class="joogle_clearfix" id="joogle_chartrow_106" >
#     <div class="joogle_chartrow_column" style="width:270px">
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_107);
# });
#
#     function doStuff_107() {
#
# 		var binding_selections = {}; // map of column indexes to selected values
# 		var filter_column_index = 0;
#
# 		var datatable = new google.visualization.DataTable({"rows":[{"c":[{"v":"Sacramento"},{"v":97}]},{"c":[{"v":"Montpelier"},{"v":96}]},{"c":[{"v":"Juneau"},{"v":24}]},{"c":[{"v":"Montgomery"},{"v":26}]},{"c":[{"v":"Little Rock"},{"v":87}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"number","id":"Aaaaaaaaa","label":"Aaaaaaaaa"}]});
#
# 		var google_filter_107 = new google.visualization.ControlWrapper({
# 			'controlType': 'CategoryFilter',
# 			'containerId': 'google_filter_107_div_id',
# 			'dataTable': datatable,
# 			'options': {"filterColumnIndex": 0},
# 			'state': {}
# 		});
#
# 		// ------------ Add filter senders, if any ---------------
#
# 		// we have to delete any persisten values in the map when rerunning jupyter notebook cells
# 		delete joogle_globals.sonar.message_map["NFL"];        google.visualization.events.addListener(google_filter_107, "statechange", function () {
# 			var selected_values = google_filter_107.getState().selectedValues;
# 			// if the selectedValues is empty, then defer to the binding selections.
# 			// So the chart downstream will still have selections if the binding filter has
# 			// a selection.
# 			if (selected_values.length == 0) {
# 				selected_values = joogle_globals.get_binding_selections(binding_selections, datatable);
# 			}
# 			joogle_globals.sonar.send("NFL", selected_values);
#
# 		});
#
# 				// ------------------------------------------------------
#
# 		// ------------ Add filter receiver, if any ---------------
# 				// ------------------------------------------------------
#
# 		google_filter_107.draw();
#
# 		// fix overflow setting on IPython output area that constrains dropdown.
# 		$("#google_filter_107_div_id").closest("div.output_subarea").css("overflow-x", "inherit");
#
#     }
# </script>
#
# <div id="google_filter_107_div_id"  ></div>
#     </div>
#     <div class="joogle_chartrow_column" style="width:400px">
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_108);
# });
#
#     function doStuff_108() {
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jooglechart_108_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"Sacramento"},{"v":97}]},{"c":[{"v":"Montpelier"},{"v":96}]},{"c":[{"v":"Juneau"},{"v":24}]},{"c":[{"v":"Montgomery"},{"v":26}]},{"c":[{"v":"Little Rock"},{"v":87}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"number","id":"Aaaaaaaaa","label":"Aaaaaaaaa"}]});
#
#         // Add formatters, if any
#
#         // Create ChartWrapper
#         var google_chart_109 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_109_div_id",
#             "dataTable": jooglechart_108_data,
#             "view": {columns: null},
#             "chartType": "ColumnChart",
#             "options": {"fontName": "Helvetica Neue", "bar": {"groupWidth": 55}, "hAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "chartArea": {"width": 440, "top": 20, "height": 295, "left": 60}, "height": 375, "width": 500, "fontSize": 12, "vAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "titleTextStyle": {"fontSize": 16}, "legend": {"position": "top"}}
#         });
#
#         google_chart_109.draw();
#
# 		// -------------- Add chartwrapper senders, if any -------------
#
# 		// -------------------------------------------------------------
#
# 		// -------------- Add chartwrapper receivers, if any -------------
# 		(function(key, chart, datatable, chart_div_id, col, view_cols) {
# 			var func = function(data) {
# 				if (data.sonar_key === key && document.getElementById(chart_div_id) !== null) {
# 					joogle_globals.update_chart(data.sonar_value, datatable, chart, col, view_cols);
# 				}
# 			}
# 			joogle_globals.sonar.add_handler(func);
# 			joogle_globals.sonar.add_one_time_ready_poller(key, func, chart);
# 		})("NFL", google_chart_109, jooglechart_108_data, "google_chart_109_div_id", 0, null);
#
# 		// ---------------------------------------------------------------
#
#
#     }
#
# </script>
#
#
#
#
# <div id="google_chart_109_div_id" class="jooglechart_container jooglechart_type_ColumnChart" ></div>
#
#
#     </div>
# </div>
#
#
# <style>
# .joogle_clearfix:after {
#     content:" ";
#     display:block;
#     clear:both;
# }
#
# #joogle_chartrow_106 > .joogle_chartrow_column {
# 	box-sizing: border-box;
# 	float: left;
# }
#
# </style>

# %% [markdown]
# # Standalone filter:  CategoryFilter initialized with selectedValues

# %%
# Pass a dataframe to the filter and specify the column
f1 = Filter("CategoryFilter", data=df1)
f1.add_options(filterColumnIndex=0)
f1.add_sender(key="STM")
f1.add_state(selectedValues=['Sacramento', 'Juneau'])

chart1 = JoogleChart(df1)
chart1.add_styler(get_styler())
chart1.add_receiver(key="STM", column=0)

row = ChartRow(f1, chart1, mode="fixed", widths=[270, 400])
row.show()
# Out:
# <div class="joogle_clearfix" id="joogle_chartrow_110" >
#     <div class="joogle_chartrow_column" style="width:270px">
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_111);
# });
#
#     function doStuff_111() {
#
# 		var binding_selections = {}; // map of column indexes to selected values
# 		var filter_column_index = 0;
#
# 		var datatable = new google.visualization.DataTable({"rows":[{"c":[{"v":"Sacramento"},{"v":97}]},{"c":[{"v":"Montpelier"},{"v":96}]},{"c":[{"v":"Juneau"},{"v":24}]},{"c":[{"v":"Montgomery"},{"v":26}]},{"c":[{"v":"Little Rock"},{"v":87}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"number","id":"Aaaaaaaaa","label":"Aaaaaaaaa"}]});
#
# 		var google_filter_111 = new google.visualization.ControlWrapper({
# 			'controlType': 'CategoryFilter',
# 			'containerId': 'google_filter_111_div_id',
# 			'dataTable': datatable,
# 			'options': {"filterColumnIndex": 0},
# 			'state': {"selectedValues": ["Sacramento", "Juneau"]}
# 		});
#
# 		// ------------ Add filter senders, if any ---------------
#
# 		// we have to delete any persisten values in the map when rerunning jupyter notebook cells
# 		delete joogle_globals.sonar.message_map["STM"];        google.visualization.events.addListener(google_filter_111, "statechange", function () {
# 			var selected_values = google_filter_111.getState().selectedValues;
# 			// if the selectedValues is empty, then defer to the binding selections.
# 			// So the chart downstream will still have selections if the binding filter has
# 			// a selection.
# 			if (selected_values.length == 0) {
# 				selected_values = joogle_globals.get_binding_selections(binding_selections, datatable);
# 			}
# 			joogle_globals.sonar.send("STM", selected_values);
#
# 		});
#
# 		// Add a one time listener to broadcast the initialized values.
#         google.visualization.events.addOneTimeListener(google_filter_111, "ready", function () {
# 			var selected_values = google_filter_111.getState().selectedValues;
# 			// if the selectedValues is empty, then defer to the binding selections.
# 			// So the chart downstream will still have selections if the binding filter has
# 			// a selection.
# 			if (selected_values.length == 0) {
# 				selected_values = joogle_globals.get_binding_selections(binding_selections, datatable);
# 			}
# 			joogle_globals.sonar.send("STM", selected_values);
#
# 		});
# 				// ------------------------------------------------------
#
# 		// ------------ Add filter receiver, if any ---------------
# 				// ------------------------------------------------------
#
# 		google_filter_111.draw();
#
# 		// fix overflow setting on IPython output area that constrains dropdown.
# 		$("#google_filter_111_div_id").closest("div.output_subarea").css("overflow-x", "inherit");
#
#     }
# </script>
#
# <div id="google_filter_111_div_id"  ></div>
#     </div>
#     <div class="joogle_chartrow_column" style="width:400px">
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_112);
# });
#
#     function doStuff_112() {
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jooglechart_112_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"Sacramento"},{"v":97}]},{"c":[{"v":"Montpelier"},{"v":96}]},{"c":[{"v":"Juneau"},{"v":24}]},{"c":[{"v":"Montgomery"},{"v":26}]},{"c":[{"v":"Little Rock"},{"v":87}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"number","id":"Aaaaaaaaa","label":"Aaaaaaaaa"}]});
#
#         // Add formatters, if any
#
#         // Create ChartWrapper
#         var google_chart_113 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_113_div_id",
#             "dataTable": jooglechart_112_data,
#             "view": {columns: null},
#             "chartType": "ColumnChart",
#             "options": {"fontName": "Helvetica Neue", "bar": {"groupWidth": 55}, "hAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "chartArea": {"width": 440, "top": 20, "height": 295, "left": 60}, "height": 375, "width": 500, "fontSize": 12, "vAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "titleTextStyle": {"fontSize": 16}, "legend": {"position": "top"}}
#         });
#
#         google_chart_113.draw();
#
# 		// -------------- Add chartwrapper senders, if any -------------
#
# 		// -------------------------------------------------------------
#
# 		// -------------- Add chartwrapper receivers, if any -------------
# 		(function(key, chart, datatable, chart_div_id, col, view_cols) {
# 			var func = function(data) {
# 				if (data.sonar_key === key && document.getElementById(chart_div_id) !== null) {
# 					joogle_globals.update_chart(data.sonar_value, datatable, chart, col, view_cols);
# 				}
# 			}
# 			joogle_globals.sonar.add_handler(func);
# 			joogle_globals.sonar.add_one_time_ready_poller(key, func, chart);
# 		})("STM", google_chart_113, jooglechart_112_data, "google_chart_113_div_id", 0, null);
#
# 		// ---------------------------------------------------------------
#
#
#     }
#
# </script>
#
#
#
#
# <div id="google_chart_113_div_id" class="jooglechart_container jooglechart_type_ColumnChart" ></div>
#
#
#     </div>
# </div>
#
#
# <style>
# .joogle_clearfix:after {
#     content:" ";
#     display:block;
#     clear:both;
# }
#
# #joogle_chartrow_110 > .joogle_chartrow_column {
# 	box-sizing: border-box;
# 	float: left;
# }
#
# </style>

# %% [markdown]
# # Standalone filter:  DateRangeFilter

# %%
# Set chart receiver action to "filter_range"

df2 = get_date_df(days=8)
f1 = Filter("DateRangeFilter", data=df2)
f1.add_options(filterColumnIndex=0)
f1.add_sender(key="UK")

chart1 = JoogleChart(df2)
chart1.add_styler(get_styler())
chart1.add_receiver(key="UK", column=0, action="filter_range")

row = ChartRow(chart1, f1, mode="free", padding=20)
row.show()
# Out:
# <div class="joogle_clearfix" id="joogle_chartrow_114" >
#     <div class="joogle_chartrow_column" >
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_115);
# });
#
#     function doStuff_115() {
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jooglechart_115_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"Date(2015,0,1)"},{"v":33.46133218632926},{"v":33.40405816360543},{"v":27.06795840181447},{"v":30.687222879922693}]},{"c":[{"v":"Date(2015,0,2)"},{"v":36.23262750798714},{"v":32.38983578527306},{"v":27.19362457463709},{"v":34.3638563886764}]},{"c":[{"v":"Date(2015,0,3)"},{"v":38.45869615931918},{"v":35.246782887586235},{"v":23.119657682301916},{"v":31.214149127933382}]},{"c":[{"v":"Date(2015,0,4)"},{"v":36.105713590228135},{"v":35.63207637727149},{"v":27.250124101449995},{"v":32.0989124380848}]},{"c":[{"v":"Date(2015,0,5)"},{"v":32.3592404130866},{"v":33.33743211783341},{"v":23.467749622423852},{"v":29.798165198932047}]},{"c":[{"v":"Date(2015,0,6)"},{"v":35.31849161974724},{"v":32.320764987952785},{"v":27.604383319012957},{"v":30.288804248806347}]},{"c":[{"v":"Date(2015,0,7)"},{"v":31.424206720844897},{"v":34.92105233238312},{"v":26.916198644243014},{"v":34.00067005999682}]},{"c":[{"v":"Date(2015,0,8)"},{"v":36.03559305085155},{"v":34.84275429319607},{"v":24.721001600263474},{"v":28.804264489378543}]}],"cols":[{"type":"date","id":"dates","label":"dates"},{"type":"number","id":"A","label":"A"},{"type":"number","id":"B","label":"B"},{"type":"number","id":"C","label":"C"},{"type":"number","id":"D","label":"D"}]});
#
#         // Add formatters, if any
#
#         // Create ChartWrapper
#         var google_chart_116 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_116_div_id",
#             "dataTable": jooglechart_115_data,
#             "view": {columns: null},
#             "chartType": "ColumnChart",
#             "options": {"fontName": "Helvetica Neue", "bar": {"groupWidth": 42}, "hAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "chartArea": {"width": 440, "top": 20, "height": 295, "left": 60}, "height": 375, "width": 500, "fontSize": 12, "vAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "titleTextStyle": {"fontSize": 16}, "legend": {"position": "top"}}
#         });
#
#         google_chart_116.draw();
#
# 		// -------------- Add chartwrapper senders, if any -------------
#
# 		// -------------------------------------------------------------
#
# 		// -------------- Add chartwrapper receivers, if any -------------
# 		(function(key, chart, datatable, chart_div_id, col, view_cols) {
# 			var func = function(data) {
# 				if (data.sonar_key === key && document.getElementById(chart_div_id) !== null) {
# 					joogle_globals.update_chart_range(data.sonar_value[0], data.sonar_value[1], datatable, chart, col, view_cols);
# 				}
# 			}
# 			joogle_globals.sonar.add_handler(func);
# 			joogle_globals.sonar.add_one_time_ready_poller(key, func, chart);
# 		})("UK", google_chart_116, jooglechart_115_data, "google_chart_116_div_id", 0, null);
#
# 		// ---------------------------------------------------------------
#
#
#     }
#
# </script>
#
#
#
#
# <div id="google_chart_116_div_id" class="jooglechart_container jooglechart_type_ColumnChart" ></div>
#
#
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_117);
# });
#
#     function doStuff_117() {
#
# 		var binding_selections = {}; // map of column indexes to selected values
# 		var filter_column_index = 0;
#
# 		var datatable = new google.visualization.DataTable({"rows":[{"c":[{"v":"Date(2015,0,1)"},{"v":33.46133218632926},{"v":33.40405816360543},{"v":27.06795840181447},{"v":30.687222879922693}]},{"c":[{"v":"Date(2015,0,2)"},{"v":36.23262750798714},{"v":32.38983578527306},{"v":27.19362457463709},{"v":34.3638563886764}]},{"c":[{"v":"Date(2015,0,3)"},{"v":38.45869615931918},{"v":35.246782887586235},{"v":23.119657682301916},{"v":31.214149127933382}]},{"c":[{"v":"Date(2015,0,4)"},{"v":36.105713590228135},{"v":35.63207637727149},{"v":27.250124101449995},{"v":32.0989124380848}]},{"c":[{"v":"Date(2015,0,5)"},{"v":32.3592404130866},{"v":33.33743211783341},{"v":23.467749622423852},{"v":29.798165198932047}]},{"c":[{"v":"Date(2015,0,6)"},{"v":35.31849161974724},{"v":32.320764987952785},{"v":27.604383319012957},{"v":30.288804248806347}]},{"c":[{"v":"Date(2015,0,7)"},{"v":31.424206720844897},{"v":34.92105233238312},{"v":26.916198644243014},{"v":34.00067005999682}]},{"c":[{"v":"Date(2015,0,8)"},{"v":36.03559305085155},{"v":34.84275429319607},{"v":24.721001600263474},{"v":28.804264489378543}]}],"cols":[{"type":"date","id":"dates","label":"dates"},{"type":"number","id":"A","label":"A"},{"type":"number","id":"B","label":"B"},{"type":"number","id":"C","label":"C"},{"type":"number","id":"D","label":"D"}]});
#
# 		var google_filter_117 = new google.visualization.ControlWrapper({
# 			'controlType': 'DateRangeFilter',
# 			'containerId': 'google_filter_117_div_id',
# 			'dataTable': datatable,
# 			'options': {"filterColumnIndex": 0},
# 			'state': {}
# 		});
#
# 		// ------------ Add filter senders, if any ---------------
#
# 		// we have to delete any persisten values in the map when rerunning jupyter notebook cells
# 		delete joogle_globals.sonar.message_map["UK"];        google.visualization.events.addListener(google_filter_117, "statechange", function () {
# 			var low_value = google_filter_117.getState().lowValue;
# 			var high_value = google_filter_117.getState().highValue;
# 			joogle_globals.sonar.send("UK", [low_value, high_value]);
# 		});
#
# 				// ------------------------------------------------------
#
# 		// ------------ Add filter receiver, if any ---------------
# 				// ------------------------------------------------------
#
# 		google_filter_117.draw();
#
# 		// fix overflow setting on IPython output area that constrains dropdown.
# 		$("#google_filter_117_div_id").closest("div.output_subarea").css("overflow-x", "inherit");
#
#     }
# </script>
#
# <div id="google_filter_117_div_id"  ></div>
#     </div>
# </div>
#
#
# <style>
# .joogle_clearfix:after {
#     content:" ";
#     display:block;
#     clear:both;
# }
#
# #joogle_chartrow_114 > .joogle_chartrow_column {
# 	box-sizing: border-box;
# 	float: left;
# 	padding-left: 20px;
# 	padding-right: 20px;
# }
#
# </style>

# %% [markdown]
# # Standalone series filter -- Don't use SeriesFilter

# %%
# Set chart receiver action to "filter_columns"

df_dates = get_date_df(days=10, num_series=6)

chart = JoogleChart(df_dates, chart_type="LineChart")
chart.add_styler(get_styler(legend_position="right"))
chart.add_receiver(key="TX", action="filter_columns")
chart.add_chart_options(isStacked=True)

series = chart.get_viewable_series()
f1 = Filter("CategoryFilter", data=pd.Series(series, name="letters"))
f1.add_options(filterColumnIndex=0)
f1.add_sender(key="TX")

row = ChartRow(chart, f1)
row.show()
# Out:
# <div class="row" id="joogle_chartrow_118" >
#     <div class="col-sm-6">
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_119);
# });
#
#     function doStuff_119() {
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jooglechart_119_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"Date(2015,0,1)"},{"v":33.551793575352185},{"v":29.862173466333985},{"v":25.88829376042357},{"v":28.251414304175206},{"v":30.534365714748226},{"v":35.7523878334065}]},{"c":[{"v":"Date(2015,0,2)"},{"v":35.97740414236791},{"v":32.909391686952276},{"v":20.566913692314028},{"v":30.94268926143082},{"v":28.351942876819344},{"v":35.743366308682056}]},{"c":[{"v":"Date(2015,0,3)"},{"v":34.5311569301124},{"v":31.879463355861944},{"v":24.191214569539568},{"v":27.38194542761349},{"v":26.739271844584113},{"v":31.19771978138167}]},{"c":[{"v":"Date(2015,0,4)"},{"v":32.05306053256945},{"v":29.52389070276038},{"v":21.715096928018518},{"v":28.766956404008702},{"v":29.474018549347424},{"v":28.88197394883883}]},{"c":[{"v":"Date(2015,0,5)"},{"v":32.97102539936193},{"v":29.934495155259874},{"v":20.52642192399852},{"v":28.996682400873386},{"v":27.791183163224712},{"v":37.606348597444466}]},{"c":[{"v":"Date(2015,0,6)"},{"v":35.718194386118014},{"v":31.678600587614856},{"v":21.522725691682364},{"v":28.75974716893104},{"v":29.159375590119886},{"v":36.02923684920621}]},{"c":[{"v":"Date(2015,0,7)"},{"v":30.02700129334972},{"v":31.670477337211366},{"v":25.760940080929046},{"v":29.56830702864105},{"v":25.619252657905207},{"v":34.540705300095624}]},{"c":[{"v":"Date(2015,0,8)"},{"v":30.150347180467545},{"v":34.662823016042694},{"v":24.70694292640912},{"v":27.389846285030547},{"v":27.994099436463294},{"v":33.4337287329224}]},{"c":[{"v":"Date(2015,0,9)"},{"v":28.649328640515968},{"v":32.60990512195192},{"v":21.44774775401471},{"v":28.233240846637703},{"v":27.821549369141284},{"v":37.24185129219925}]},{"c":[{"v":"Date(2015,0,10)"},{"v":32.489294184733325},{"v":30.60877499696928},{"v":24.376855934860497},{"v":29.958992481125684},{"v":25.30140391593334},{"v":36.33569313399041}]}],"cols":[{"type":"date","id":"dates","label":"dates"},{"type":"number","id":"A","label":"A"},{"type":"number","id":"B","label":"B"},{"type":"number","id":"C","label":"C"},{"type":"number","id":"D","label":"D"},{"type":"number","id":"E","label":"E"},{"type":"number","id":"F","label":"F"}]});
#
#         // Add formatters, if any
#
#         // Create ChartWrapper
#         var google_chart_120 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_120_div_id",
#             "dataTable": jooglechart_119_data,
#             "view": {columns: null},
#             "chartType": "LineChart",
#             "options": {"isStacked": true, "hAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "chartArea": {"width": 320, "top": 10, "height": 305, "left": 60}, "fontName": "Helvetica Neue", "height": 375, "width": 500, "fontSize": 12, "vAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "titleTextStyle": {"fontSize": 16}, "legend": {"position": "right"}}
#         });
#
#         google_chart_120.draw();
#
# 		// -------------- Add chartwrapper senders, if any -------------
#
# 		// -------------------------------------------------------------
#
# 		// -------------- Add chartwrapper receivers, if any -------------
# 		// handler to filter columns
# 		(function(key, chart, datatable, chart_div_id, col, view_cols) {
# 			var series_cols = joogle_globals.get_viewable_columns(chart);
# 			function update_chart_callback(view, series) {
# 				chart.setDataTable(view);
# 				chart.setOption('series', series);
# 		        chart.draw();
# 			}
# 			var func = function(data) {
# 				if (data.sonar_key === key && document.getElementById(chart_div_id) !== null) {
# 					// joogle_globals.update_chart(data.sonar_value, datatable, chart, col, view_cols);
# 					window.joogle_globals.draw_chart_filtered_columns(datatable, series_cols, data.sonar_value, update_chart_callback);
# 				}
# 			}
# 			joogle_globals.sonar.add_handler(func);
# 			joogle_globals.sonar.add_one_time_ready_poller(key, func, chart);
# 		})("TX", google_chart_120, jooglechart_119_data, "google_chart_120_div_id");
#
# 		// ---------------------------------------------------------------
#
#
#     }
#
# </script>
#
#
#
#
# <div id="google_chart_120_div_id" class="jooglechart_container jooglechart_type_LineChart" ></div>
#
#
#     </div>
#     <div class="col-sm-6">
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_121);
# });
#
#     function doStuff_121() {
#
# 		var binding_selections = {}; // map of column indexes to selected values
# 		var filter_column_index = 0;
#
# 		var datatable = new google.visualization.DataTable({"rows":[{"c":[{"v":"A"}]},{"c":[{"v":"B"}]},{"c":[{"v":"C"}]},{"c":[{"v":"D"}]},{"c":[{"v":"E"}]},{"c":[{"v":"F"}]}],"cols":[{"type":"string","id":"letters","label":"letters"}]});
#
# 		var google_filter_121 = new google.visualization.ControlWrapper({
# 			'controlType': 'CategoryFilter',
# 			'containerId': 'google_filter_121_div_id',
# 			'dataTable': datatable,
# 			'options': {"filterColumnIndex": 0},
# 			'state': {}
# 		});
#
# 		// ------------ Add filter senders, if any ---------------
#
# 		// we have to delete any persisten values in the map when rerunning jupyter notebook cells
# 		delete joogle_globals.sonar.message_map["TX"];        google.visualization.events.addListener(google_filter_121, "statechange", function () {
# 			var selected_values = google_filter_121.getState().selectedValues;
# 			// if the selectedValues is empty, then defer to the binding selections.
# 			// So the chart downstream will still have selections if the binding filter has
# 			// a selection.
# 			if (selected_values.length == 0) {
# 				selected_values = joogle_globals.get_binding_selections(binding_selections, datatable);
# 			}
# 			joogle_globals.sonar.send("TX", selected_values);
#
# 		});
#
# 				// ------------------------------------------------------
#
# 		// ------------ Add filter receiver, if any ---------------
# 				// ------------------------------------------------------
#
# 		google_filter_121.draw();
#
# 		// fix overflow setting on IPython output area that constrains dropdown.
# 		$("#google_filter_121_div_id").closest("div.output_subarea").css("overflow-x", "inherit");
#
#     }
# </script>
#
# <div id="google_filter_121_div_id"  ></div>
#     </div>
# </div>
#
#
# <style>
# .joogle_clearfix:after {
#     content:" ";
#     display:block;
#     clear:both;
# }
#
# #joogle_chartrow_118 > .joogle_chartrow_column {
# 	box-sizing: border-box;
# 	float: left;
# }
#
# </style>

# %% [markdown]
# # Roll your own bound filters!

# %%
# Hook up two filters to each other and to the chart
# One filter has receiver action "update_binding_values"

df3 = get_df(category_column=True, rows=15)
f1 = Filter("CategoryFilter", data = df3)
f1.add_options(filterColumnIndex = 1)
f1.add_sender(key="UM")
    
f2 = Filter("CategoryFilter", data = df3)
f2.add_options(filterColumnIndex = 0)
f2.add_receiver(key="UM", action="update_binding_values", bound_column=1)
f2.add_sender(key="OSU")
    
chart = JoogleChart(df3)
chart.add_styler(get_styler(width="small"))
chart.add_receiver(key="UM", column=1)
chart.add_receiver(key="OSU", column=0)
chart.set_view_cols([0, 2])

box = Box(f1, f2)
row = ChartRow(chart, box, mode="free", padding=20)

row.show()
# Out:
# <div class="joogle_clearfix" id="joogle_chartrow_122" >
#     <div class="joogle_chartrow_column" >
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_123);
# });
#
#     function doStuff_123() {
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jooglechart_123_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"Sacramento"},{"v":"C"},{"v":100}]},{"c":[{"v":"Montpelier"},{"v":"C"},{"v":96}]},{"c":[{"v":"Juneau"},{"v":"A"},{"v":64}]},{"c":[{"v":"Montgomery"},{"v":"A"},{"v":56}]},{"c":[{"v":"Little Rock"},{"v":"C"},{"v":41}]},{"c":[{"v":"Phoenix"},{"v":"C"},{"v":22}]},{"c":[{"v":"Denver"},{"v":"C"},{"v":22}]},{"c":[{"v":"Hartford"},{"v":"A"},{"v":57}]},{"c":[{"v":"Tallahassee"},{"v":"B"},{"v":45}]},{"c":[{"v":"Dover"},{"v":"B"},{"v":50}]},{"c":[{"v":"Atlanta"},{"v":"B"},{"v":92}]},{"c":[{"v":"Honolulu"},{"v":"A"},{"v":62}]},{"c":[{"v":"Austin"},{"v":"B"},{"v":65}]},{"c":[{"v":"Albany"},{"v":"B"},{"v":39}]},{"c":[{"v":"Frankfurt"},{"v":"C"},{"v":21}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"string","id":"categories","label":"categories"},{"type":"number","id":"Aaaaaaaaa","label":"Aaaaaaaaa"}]});
#
#         // Add formatters, if any
#
#         // Create ChartWrapper
#         var google_chart_124 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_124_div_id",
#             "dataTable": jooglechart_123_data,
#             "view": {columns: [0, 2]},
#             "chartType": "ColumnChart",
#             "options": {"fontName": "Helvetica Neue", "bar": {"groupWidth": 12}, "hAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "chartArea": {"width": 290, "top": 20, "height": 295, "left": 60}, "height": 375, "width": 350, "fontSize": 12, "vAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "titleTextStyle": {"fontSize": 16}, "legend": {"position": "top"}}
#         });
#
#         google_chart_124.draw();
#
# 		// -------------- Add chartwrapper senders, if any -------------
#
# 		// -------------------------------------------------------------
#
# 		// -------------- Add chartwrapper receivers, if any -------------
# 		(function(key, chart, datatable, chart_div_id, col, view_cols) {
# 			var func = function(data) {
# 				if (data.sonar_key === key && document.getElementById(chart_div_id) !== null) {
# 					joogle_globals.update_chart(data.sonar_value, datatable, chart, col, view_cols);
# 				}
# 			}
# 			joogle_globals.sonar.add_handler(func);
# 			joogle_globals.sonar.add_one_time_ready_poller(key, func, chart);
# 		})("UM", google_chart_124, jooglechart_123_data, "google_chart_124_div_id", 1, [0, 2]);
# 		(function(key, chart, datatable, chart_div_id, col, view_cols) {
# 			var func = function(data) {
# 				if (data.sonar_key === key && document.getElementById(chart_div_id) !== null) {
# 					joogle_globals.update_chart(data.sonar_value, datatable, chart, col, view_cols);
# 				}
# 			}
# 			joogle_globals.sonar.add_handler(func);
# 			joogle_globals.sonar.add_one_time_ready_poller(key, func, chart);
# 		})("OSU", google_chart_124, jooglechart_123_data, "google_chart_124_div_id", 0, [0, 2]);
#
# 		// ---------------------------------------------------------------
#
#
#     }
#
# </script>
#
#
#
#
# <div id="google_chart_124_div_id" class="jooglechart_container jooglechart_type_ColumnChart" ></div>
#
#
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <div id="joogle_box_125" >
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_126);
# });
#
#     function doStuff_126() {
#
# 		var binding_selections = {}; // map of column indexes to selected values
# 		var filter_column_index = 1;
#
# 		var datatable = new google.visualization.DataTable({"rows":[{"c":[{"v":"Sacramento"},{"v":"C"},{"v":100}]},{"c":[{"v":"Montpelier"},{"v":"C"},{"v":96}]},{"c":[{"v":"Juneau"},{"v":"A"},{"v":64}]},{"c":[{"v":"Montgomery"},{"v":"A"},{"v":56}]},{"c":[{"v":"Little Rock"},{"v":"C"},{"v":41}]},{"c":[{"v":"Phoenix"},{"v":"C"},{"v":22}]},{"c":[{"v":"Denver"},{"v":"C"},{"v":22}]},{"c":[{"v":"Hartford"},{"v":"A"},{"v":57}]},{"c":[{"v":"Tallahassee"},{"v":"B"},{"v":45}]},{"c":[{"v":"Dover"},{"v":"B"},{"v":50}]},{"c":[{"v":"Atlanta"},{"v":"B"},{"v":92}]},{"c":[{"v":"Honolulu"},{"v":"A"},{"v":62}]},{"c":[{"v":"Austin"},{"v":"B"},{"v":65}]},{"c":[{"v":"Albany"},{"v":"B"},{"v":39}]},{"c":[{"v":"Frankfurt"},{"v":"C"},{"v":21}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"string","id":"categories","label":"categories"},{"type":"number","id":"Aaaaaaaaa","label":"Aaaaaaaaa"}]});
#
# 		var google_filter_126 = new google.visualization.ControlWrapper({
# 			'controlType': 'CategoryFilter',
# 			'containerId': 'google_filter_126_div_id',
# 			'dataTable': datatable,
# 			'options': {"filterColumnIndex": 1},
# 			'state': {}
# 		});
#
# 		// ------------ Add filter senders, if any ---------------
#
# 		// we have to delete any persisten values in the map when rerunning jupyter notebook cells
# 		delete joogle_globals.sonar.message_map["UM"];        google.visualization.events.addListener(google_filter_126, "statechange", function () {
# 			var selected_values = google_filter_126.getState().selectedValues;
# 			// if the selectedValues is empty, then defer to the binding selections.
# 			// So the chart downstream will still have selections if the binding filter has
# 			// a selection.
# 			if (selected_values.length == 0) {
# 				selected_values = joogle_globals.get_binding_selections(binding_selections, datatable);
# 			}
# 			joogle_globals.sonar.send("UM", selected_values);
#
# 		});
#
# 				// ------------------------------------------------------
#
# 		// ------------ Add filter receiver, if any ---------------
# 				// ------------------------------------------------------
#
# 		google_filter_126.draw();
#
# 		// fix overflow setting on IPython output area that constrains dropdown.
# 		$("#google_filter_126_div_id").closest("div.output_subarea").css("overflow-x", "inherit");
#
#     }
# </script>
#
# <div id="google_filter_126_div_id"  ></div>
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_127);
# });
#
#     function doStuff_127() {
#
# 		var binding_selections = {}; // map of column indexes to selected values
# 		var filter_column_index = 0;
#
# 		var datatable = new google.visualization.DataTable({"rows":[{"c":[{"v":"Sacramento"},{"v":"C"},{"v":100}]},{"c":[{"v":"Montpelier"},{"v":"C"},{"v":96}]},{"c":[{"v":"Juneau"},{"v":"A"},{"v":64}]},{"c":[{"v":"Montgomery"},{"v":"A"},{"v":56}]},{"c":[{"v":"Little Rock"},{"v":"C"},{"v":41}]},{"c":[{"v":"Phoenix"},{"v":"C"},{"v":22}]},{"c":[{"v":"Denver"},{"v":"C"},{"v":22}]},{"c":[{"v":"Hartford"},{"v":"A"},{"v":57}]},{"c":[{"v":"Tallahassee"},{"v":"B"},{"v":45}]},{"c":[{"v":"Dover"},{"v":"B"},{"v":50}]},{"c":[{"v":"Atlanta"},{"v":"B"},{"v":92}]},{"c":[{"v":"Honolulu"},{"v":"A"},{"v":62}]},{"c":[{"v":"Austin"},{"v":"B"},{"v":65}]},{"c":[{"v":"Albany"},{"v":"B"},{"v":39}]},{"c":[{"v":"Frankfurt"},{"v":"C"},{"v":21}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"string","id":"categories","label":"categories"},{"type":"number","id":"Aaaaaaaaa","label":"Aaaaaaaaa"}]});
#
# 		var google_filter_127 = new google.visualization.ControlWrapper({
# 			'controlType': 'CategoryFilter',
# 			'containerId': 'google_filter_127_div_id',
# 			'dataTable': datatable,
# 			'options': {"filterColumnIndex": 0},
# 			'state': {}
# 		});
#
# 		// ------------ Add filter senders, if any ---------------
#
# 		// we have to delete any persisten values in the map when rerunning jupyter notebook cells
# 		delete joogle_globals.sonar.message_map["OSU"];        google.visualization.events.addListener(google_filter_127, "statechange", function () {
# 			var selected_values = google_filter_127.getState().selectedValues;
# 			// if the selectedValues is empty, then defer to the binding selections.
# 			// So the chart down

# %% [markdown]
# # We've got Widgets!

# %% [markdown]
# # 5. Say "hello" to the ButtonGroup!

# %% [markdown]
# # ButtonGroup basics

# %%
buttons = ButtonGroup(values = df.cities)
buttons.add_sender(key="NYC")

chart = JoogleChart(df)
chart.add_styler(get_styler())
chart.add_receiver(key="NYC", column=0)

buttons.show()
chart.show()
# Out:
# <style>
#
# /*
# 	Setting overflow: scroll prevents buggy behavior in CategoryFilter dropdown
# 	that occurs when the list of menu options is very long.
# */
# .charts-menu {
#     overflow: scroll;
#     max-height: 250px;
# }
#
# .google-visualization-table .google-visualization-table-td-number {
# 	text-align: right;
# }
#
# .jooglechart_container {
# 	margin-bottom: 20px;
# }
#
# h1.jooglechart_global_title {
# 	font-size: 20px;
# 	font-weight: bold;
# 	margin-bottom:8px;
# }
#
# </style>
#
# <script>
#
# $(document).ready(function() {
#
# 	/* GLOBALS AREA >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> */
#
# 	window.addEventListener('message', function(message) {
# 		// listener for sonar message from iframe parent
# 		if (message.data.msg.sonar_key !== undefined && message.data.msg.sonar_value !== undefined &&
# 				message.data.originId !== message.data.destinationId) {
# 			if (joogle_globals.sonar.handler_array !== undefined) {
# 				joogle_globals.sonar.call_handlers(message.data.msg);
# 			}
# 		}
# 	});
#
#
# 	if (typeof window.joogle_globals === "undefined" || window.joogle_globals === null) {
# 		window.joogle_globals = {};
#
# 		window.joogle_globals.sonar = new (function () {
# 			// object for holding all sonar pieces
# 			this.handler_array = [];
# 			this.message_map = {};
# 			this.add_handler = function(handler) { this.handler_array.push(handler)};
# 			this.send = function(key, value) {
# 				this.message_map[key] = value;
# 				var data = { sonar_key: key, sonar_value: value };
# 				if (window.self !== window.top) {
# 					window.parent.postMessage(data, window.location.origin + window.location.pathname);
# 				}
# 				if (joogle_globals.sonar.handler_array !== undefined) {
# 					joogle_globals.sonar.call_handlers(data);
# 				}
# 			}
# 			this.call_handlers = function(data) {
# 				for (var i = 0; i < this.handler_array.length; i++) {
# 					this.handler_array[i](data);
# 				}
# 				this.call_text_receivers(data);
# 			}
# 			this.poll_message_map = function(key) {
# 				if (key in this.message_map) {
# 					return this.message_map[key];
# 				}
# 				else { return null};
# 			}
# 			this.add_one_time_ready_poller = function(key, func, vis) {
# 				/*
# 					Check if a sonar msg was sent before chart was ready, and run function.
# 					Can happen if a sender has been initialized with a value.
# 				*/
# 				google.visualization.events.addOneTimeListener(vis, "ready", function() {
# 					var result = joogle_globals.sonar.poll_message_map(key);
# 					if (result !== null) {
# 						func({"sonar_key": key, "sonar_value": result});
# 					}
# 				});
# 			}
# 			this.call_text_receivers = function (data) {
# 				$(".joogle_text_receiver").each(function() {
# 					var receiver = this;
# 					var key = receiver.dataset.key;
# 					var list_style = receiver.dataset.liststyle;
# 					var sub_text = data.sonar_value;
# 					var default_text = receiver.dataset.default;
# 					if (typeof default_text === "undefined") {
# 						default_text = "";
# 					}
# 					var clear_text = receiver.dataset.clear_text;
# 					if (sub_text.constructor !== Array) {
# 						sub_text = $.trim(sub_text);
# 						if (sub_text.length == 0) {
# 							sub_text = default_text;
# 						}
# 						sub_text = [sub_text];
# 					} else if (sub_text.length === 0) {
# 						sub_text = [default_text];
# 					}
# 					sub_text = joogle_globals.format_list_for_text_receiver(sub_text, list_style);
# 					if (key == data.sonar_key) {
# 						var template = receiver.dataset.template;
# 						template = template.replace("{}", sub_text);
# 						receiver.innerHTML = template;
# 					}
# 				})
# 			}
# 		})();
# 	}
#
# 	window.joogle_globals.format_list_for_text_receiver = function(arr, list_style) {
# 		if (list_style === "colloquial") {
# 			if (arr.length === 1) { return arr[0]; }
# 			var front = "";
# 			var back = "";
# 			var back_arr = arr.slice(arr.length - 2, arr.length);
# 			back = back_arr[0] + " and " + back_arr[1];
# 			if (arr.length > 2) {
# 				var front_arr = arr.slice(0, arr.length - 1);
# 				for (var i = 0; i < front_arr.length; i++) {
# 					front += front_arr[i] + ", ";
# 				}
# 			}
# 			return front + back;
# 		}
# 		else if (list_style === "parens") {
# 			return "(" + arr.join(", ") + ")";
# 		}
# 		else if (list_style === "brackets") {
# 			return "[" + arr.join(", ") + "]";
# 		}
# 	}
#
# 	window.joogle_globals.update_category_filter = function(filter, selected_values) {
# 		// utility function for updating Google Charts filter
# 		var filter_state = filter.getState();
# 		filter_state.selectedValues = selected_values;
# 		filter.setState(filter_state);
# 		filter.draw();
# 	}
# 	window.joogle_globals.update_range_filter = function(filter, range) {
# 		// utility function for updating Google Charts filter
# 		var filter_state = filter.getState();
# 		filter_state.lowValue = range[0];
# 		filter_state.highValue = range[1];
# 		filter_state.lowThumbAtMinimum = false; // buggy without this
# 		filter_state.highThumbAtMaximum = false;
# 		filter.setState(filter_state);
# 		filter.draw();
# 	}
# 	window.joogle_globals.update_filter_binding_selection = function(selected_values, data, filter, column) {
# 		// Method for filtering controlWrapper's dataTable and redrawing.  Used for filter sonar receiver.
#
# 		var filtered_rows = [];
# 		if (selected_values.length == 0) {
# 			filtered_rows = null;
# 		}
# 		else {
# 			for (var i = 0; i < selected_values.length; i++) {
# 				var rows = data.getFilteredRows([{column: column, value: selected_values[i]}]);
# 				filtered_rows = $.merge(filtered_rows, rows);
# 			}
# 		}
# 		// undocumented setView method on control wrappers
# 		filter.setView({
# 			rows: filtered_rows
# 		});
#
# 		filter.draw();
# 	}
# 	window.joogle_globals.update_chart = function(values_arr, data, chartwrapper, column, view_cols) {
# 		var filtered_rows = joogle_globals.get_rows_for_column_selections(column, values_arr, data);
# 		chartwrapper.setView({
# 			rows: filtered_rows,
# 			columns: view_cols
# 		});
# 		chartwrapper.draw();
# 	}
#
# 	window.joogle_globals.update_chart_range = function(minValue, maxValue, data, chartwrapper, column, view_cols) {
# 		var filtered_rows = data.getFilteredRows([{column: column, minValue: minValue, maxValue: maxValue}]);
# 		chartwrapper.setView({
# 			rows: filtered_rows,
# 			columns: view_cols
# 		});
# 		chartwrapper.draw();
# 	}
#
# 	window.joogle_globals.get_rows_for_column_selections = function(column, selections, datatable) {
# 		var rows_total = [];
# 		if (selections.length == 0) {
# 			rows_total = null;
# 		}
# 		else {
# 			for (var i = 0; i < selections.length; i++) {
# 				var rows = datatable.getFilteredRows([{column: parseInt(column), value: selections[i]}]);
# 				rows_total = $.merge(rows_total, rows);
# 			}
# 		}
# 		return rows_total;
# 	}
#
# 	window.joogle_globals.get_binding_selections = function(binding_selections, datatable) {
# 		// A filter's column can be bound by another sender (a filter, typically).
# 		// Need to get the filtering values for the bound column if it had received a filtering messsage.
# 		var binding_rows = [];
# 		var binding_values = [];
# 		for (var column in binding_selections) {
# 			if (binding_selections[column].length > 0) {
# 				var rows = joogle_globals.get_rows_for_column_selections(column, binding_selections[column], datatable);
# 				$.merge(binding_rows, rows);
# 			}
# 		}
# 		// now we've got the binding rows, get the values in the right column
# 		for (var ix in binding_rows) {
# 			binding_values.push(datatable.getValue(binding_rows[ix], 0));
# 		}
# 		return binding_values;
# 	}
#
# 	window.joogle_globals.draw_chart_filtered_columns = function(datatable, viewable_columns, selected_columns, callback) {
# 		// an object of series properties will be passed to the chart wrapper for setting color
# 	    var series = {};
#
# 		// initialize the array of dataTable column indices, e.g, [0, 1, 2, etc.]
# 	    var columns = [];
# 	    for (var i = 0; i < datatable.getNumberOfColumns(); i++) {
# 	        columns.push(i);
# 	    }
#
# 		// Loop through series cols
# 		for (var i = 0; i < viewable_columns.length; i++) {
# 			series[i] = {}	// initialize series object
# 			var ix = viewable_columns[i]	// get series column index in the original data table
#
# 			// check if series has been selected
# 			var test_val = datatable.getColumnLabel(ix);
# 			if ($.inArray(test_val
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_129);
# });
#
#     function doStuff_129() {
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jooglechart_129_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"Sacramento"},{"v":97}]},{"c":[{"v":"Montpelier"},{"v":96}]},{"c":[{"v":"Juneau"},{"v":24}]},{"c":[{"v":"Montgomery"},{"v":26}]},{"c":[{"v":"Little Rock"},{"v":87}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"number","id":"Aaaaaaaaa","label":"Aaaaaaaaa"}]});
#
#         // Add formatters, if any
#
#         // Create ChartWrapper
#         var google_chart_130 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_130_div_id",
#             "dataTable": jooglechart_129_data,
#             "view": {columns: null},
#             "chartType": "ColumnChart",
#             "options": {"fontName": "Helvetica Neue", "bar": {"groupWidth": 55}, "hAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "chartArea": {"width": 440, "top": 20, "height": 295, "left": 60}, "height": 375, "width": 500, "fontSize": 12, "vAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "titleTextStyle": {"fontSize": 16}, "legend": {"position": "top"}}
#         });
#
#         google_chart_130.draw();
#
# 		// -------------- Add chartwrapper senders, if any -------------
#
# 		// -------------------------------------------------------------
#
# 		// -------------- Add chartwrapper receivers, if any -------------
# 		(function(key, chart, datatable, chart_div_id, col, view_cols) {
# 			var func = function(data) {
# 				if (data.sonar_key === key && document.getElementById(chart_div_id) !== null) {
# 					joogle_globals.update_chart(data.sonar_value, datatable, chart, col, view_cols);
# 				}
# 			}
# 			joogle_globals.sonar.add_handler(func);
# 			joogle_globals.sonar.add_one_time_ready_poller(key, func, chart);
# 		})("NYC", google_chart_130, jooglechart_129_data, "google_chart_130_div_id", 0, null);
#
# 		// ---------------------------------------------------------------
#
#
#     }
#
# </script>
#
#
#
#
# <div id="google_chart_130_div_id" class="jooglechart_container jooglechart_type_ColumnChart" ></div>

# %% [markdown]
# # ButtonGroup options

# %%
buttons1 = ButtonGroup(values = df.cities, clear_button=True)
buttons1.add_div_styles({'padding-bottom': "50px"})
buttons1.add_sender(key="SOS")

buttons2 = ButtonGroup(values = df.cities, clear_button=True, title="Cities", type="radio")
buttons2.add_div_styles(padding="5px")
buttons2.add_sender(key="SOS")

box = Box(buttons1, buttons2)

chart = JoogleChart(df)
chart.add_styler(get_styler(width="small"))
chart.add_receiver(key="SOS", column=0)

row = ChartRow(box, chart, mode = "free")

row.show()
# Out:
# <div class="joogle_clearfix" id="joogle_chartrow_131" >
#     <div class="joogle_chartrow_column" >
#
# <div id="joogle_box_132" >
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_133);
#
#     function doStuff_133() {
#
# 		var buttons = new joogle_globals.ButtonGroup({
# 			'container_id': "button_group_133_div_id",
# 			'add_clear': true,
# 			'clear_button_position': "first",
# 			'values': ["Sacramento", "Montpelier", "Juneau", "Montgomery", "Little Rock"],
# 			'type': "checkbox",
# 			'button_group_class': 'btn-group',
# 			'title': null,
# 			'clear_button_bold': false,
# 			'initial_values': null
# 		});
#
# 		// -----------  add buttongroup sonar handlers ------------------
# 		// --------------------------------------------
# 		// --------- Add buttongroup sonar senders, if any ---------
# 		// add senders before before creating checkboxes
# 		// we have to delete any persisten values in the map when rerunning jupyter notebook cells
# 		delete joogle_globals.sonar.message_map["SOS"];        google.visualization.events.addListener(buttons, 'select', function() {
#   			var selection = buttons.get_selected_values();
# 			joogle_globals.sonar.send('SOS', selection);
# 		});
# 				// ---------------------------------------------
#
# 		buttons.draw();
#
#
#     }
# });
# </script>
#
# <div id="button_group_133_div_id" style="padding-bottom: 50px"></div>
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_134);
#
#     function doStuff_134() {
#
# 		var buttons = new joogle_globals.ButtonGroup({
# 			'container_id': "button_group_134_div_id",
# 			'add_clear': true,
# 			'clear_button_position': "first",
# 			'values': ["Sacramento", "Montpelier", "Juneau", "Montgomery", "Little Rock"],
# 			'type': "radio",
# 			'button_group_class': 'btn-group',
# 			'title': "Cities",
# 			'clear_button_bold': false,
# 			'initial_values': null
# 		});
#
# 		// -----------  add buttongroup sonar handlers ------------------
# 		// --------------------------------------------
# 		// --------- Add buttongroup sonar senders, if any ---------
# 		// add senders before before creating checkboxes
# 		// we have to delete any persisten values in the map when rerunning jupyter notebook cells
# 		delete joogle_globals.sonar.message_map["SOS"];        google.visualization.events.addListener(buttons, 'select', function() {
#   			var selection = buttons.get_selected_values();
# 			joogle_globals.sonar.send('SOS', selection);
# 		});
# 				// ---------------------------------------------
#
# 		buttons.draw();
#
#
#     }
# });
# </script>
#
# <div id="button_group_134_div_id" style="padding: 5px"></div>
# </div>
#
# <style>
# #joogle_box_132 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_135);
# });
#
#     function doStuff_135() {
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jooglechart_135_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"Sacramento"},{"v":97}]},{"c":[{"v":"Montpelier"},{"v":96}]},{"c":[{"v":"Juneau"},{"v":24}]},{"c":[{"v":"Montgomery"},{"v":26}]},{"c":[{"v":"Little Rock"},{"v":87}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"number","id":"Aaaaaaaaa","label":"Aaaaaaaaa"}]});
#
#         // Add formatters, if any
#
#         // Create ChartWrapper
#         var google_chart_136 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_136_div_id",
#             "dataTable": jooglechart_135_data,
#             "view": {columns: null},
#             "chartType": "ColumnChart",
#             "options": {"fontName": "Helvetica Neue", "bar": {"groupWidth": 36}, "hAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "chartArea": {"width": 290, "top": 20, "height": 295, "left": 60}, "height": 375, "width": 350, "fontSize": 12, "vAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "titleTextStyle": {"fontSize": 16}, "legend": {"position": "top"}}
#         });
#
#         google_chart_136.draw();
#
# 		// -------------- Add chartwrapper senders, if any -------------
#
# 		// -------------------------------------------------------------
#
# 		// -------------- Add chartwrapper receivers, if any -------------
# 		(function(key, chart, datatable, chart_div_id, col, view_cols) {
# 			var func = function(data) {
# 				if (data.sonar_key === key && document.getElementById(chart_div_id) !== null) {
# 					joogle_globals.update_chart(data.sonar_value, datatable, chart, col, view_cols);
# 				}
# 			}
# 			joogle_globals.sonar.add_handler(func);
# 			joogle_globals.sonar.add_one_time_ready_poller(key, func, chart);
# 		})("SOS", google_chart_136, jooglechart_135_data, "google_chart_136_div_id", 0, null);
#
# 		// ---------------------------------------------------------------
#
#
#     }
#
# </script>
#
#
#
#
# <div id="google_chart_136_div_id" class="jooglechart_container jooglechart_type_ColumnChart" ></div>
#
#
#     </div>
# </div>
#
#
# <style>
# .joogle_clearfix:after {
#     content:" ";
#     display:block;
#     clear:both;
# }
#
# #joogle_chartrow_131 > .joogle_chartrow_column {
# 	box-sizing: border-box;
# 	float: left;
# }
#
# </style>

# %% [markdown]
# # More ButtonGroup Options

# %%
buttons1 = ButtonGroup(values = df.cities, clear_button=True, orientation="vertical", title="Cities")
buttons1.add_sender(key="UCLA")

buttons2 = ButtonGroup(values = df.cities, clear_button=True, clear_button_position="last", orientation="vertical")
buttons2.add_sender(key="UCLA")

buttons3 = ButtonGroup(values = df.cities, clear_button=True, clear_button_position="last", clear_button_bold=True, orientation="vertical")
buttons3.add_sender(key="UCLA")

buttons4 = ButtonGroup(values = df.cities, initial_values = ['Juneau'], clear_button=True, clear_button_position="last", orientation="vertical")
buttons4.add_sender(key="UCB")

buttons5 = ButtonGroup(values = df.cities, initial_values = ['Juneau'], clear_button=True, clear_button_position="last", orientation="vertical")
buttons5.add_sender(key="UCLA")
buttons5.add_receiver(key="UCB")

chart = JoogleChart(df)
chart.add_styler(get_styler(width="small"))
chart.add_receiver(key="UCLA", column=0)

row = ChartRow(buttons1, buttons2, buttons3, buttons4, buttons5, chart, mode = "free", padding=10)

row.show()
# Out:
# <div class="joogle_clearfix" id="joogle_chartrow_137" >
#     <div class="joogle_chartrow_column" >
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_138);
#
#     function doStuff_138() {
#
# 		var buttons = new joogle_globals.ButtonGroup({
# 			'container_id': "button_group_138_div_id",
# 			'add_clear': true,
# 			'clear_button_position': "first",
# 			'values': ["Sacramento", "Montpelier", "Juneau", "Montgomery", "Little Rock"],
# 			'type': "checkbox",
# 			'button_group_class': 'btn-group-vertical',
# 			'title': "Cities",
# 			'clear_button_bold': false,
# 			'initial_values': null
# 		});
#
# 		// -----------  add buttongroup sonar handlers ------------------
# 		// --------------------------------------------
# 		// --------- Add buttongroup sonar senders, if any ---------
# 		// add senders before before creating checkboxes
# 		// we have to delete any persisten values in the map when rerunning jupyter notebook cells
# 		delete joogle_globals.sonar.message_map["UCLA"];        google.visualization.events.addListener(buttons, 'select', function() {
#   			var selection = buttons.get_selected_values();
# 			joogle_globals.sonar.send('UCLA', selection);
# 		});
# 				// ---------------------------------------------
#
# 		buttons.draw();
#
#
#     }
# });
# </script>
#
# <div id="button_group_138_div_id" ></div>
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_139);
#
#     function doStuff_139() {
#
# 		var buttons = new joogle_globals.ButtonGroup({
# 			'container_id': "button_group_139_div_id",
# 			'add_clear': true,
# 			'clear_button_position': "last",
# 			'values': ["Sacramento", "Montpelier", "Juneau", "Montgomery", "Little Rock"],
# 			'type': "checkbox",
# 			'button_group_class': 'btn-group-vertical',
# 			'title': null,
# 			'clear_button_bold': false,
# 			'initial_values': null
# 		});
#
# 		// -----------  add buttongroup sonar handlers ------------------
# 		// --------------------------------------------
# 		// --------- Add buttongroup sonar senders, if any ---------
# 		// add senders before before creating checkboxes
# 		// we have to delete any persisten values in the map when rerunning jupyter notebook cells
# 		delete joogle_globals.sonar.message_map["UCLA"];        google.visualization.events.addListener(buttons, 'select', function() {
#   			var selection = buttons.get_selected_values();
# 			joogle_globals.sonar.send('UCLA', selection);
# 		});
# 				// ---------------------------------------------
#
# 		buttons.draw();
#
#
#     }
# });
# </script>
#
# <div id="button_group_139_div_id" ></div>
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_140);
#
#     function doStuff_140() {
#
# 		var buttons = new joogle_globals.ButtonGroup({
# 			'container_id': "button_group_140_div_id",
# 			'add_clear': true,
# 			'clear_button_position': "last",
# 			'values': ["Sacramento", "Montpelier", "Juneau", "Montgomery", "Little Rock"],
# 			'type': "checkbox",
# 			'button_group_class': 'btn-group-vertical',
# 			'title': null,
# 			'clear_button_bold': true,
# 			'initial_values': null
# 		});
#
# 		// -----------  add buttongroup sonar handlers ------------------
# 		// --------------------------------------------
# 		// --------- Add buttongroup sonar senders, if any ---------
# 		// add senders before before creating checkboxes
# 		// we have to delete any persisten values in the map when rerunning jupyter notebook cells
# 		delete joogle_globals.sonar.message_map["UCLA"];        google.visualization.events.addListener(buttons, 'select', function() {
#   			var selection = buttons.get_selected_values();
# 			joogle_globals.sonar.send('UCLA', selection);
# 		});
# 				// ---------------------------------------------
#
# 		buttons.draw();
#
#
#     }
# });
# </script>
#
# <div id="button_group_140_div_id" ></div>
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_141);
#
#     function doStuff_141() {
#
# 		var buttons = new joogle_globals.ButtonGroup({
# 			'container_id': "button_group_141_div_id",
# 			'add_clear': true,
# 			'clear_button_position': "last",
# 			'values': ["Sacramento", "Montpelier", "Juneau", "Montgomery", "Little Rock"],
# 			'type': "checkbox",
# 			'button_group_class': 'btn-group-vertical',
# 			'title': null,
# 			'clear_button_bold': false,
# 			'initial_values': ["Juneau"]
# 		});
#
# 		// -----------  add buttongroup sonar handlers ------------------
# 		// --------------------------------------------
# 		// --------- Add buttongroup sonar senders, if any ---------
# 		// add senders before before creating checkboxes
# 		// we have to delete any persisten values in the map when rerunning jupyter notebook cells
# 		delete joogle_globals.sonar.message_map["UCB"];        google.visualization.events.addListener(buttons, 'select', function() {
#   			var selection = buttons.get_selected_values();
# 			joogle_globals.sonar.send('UCB', selection);
# 		});
# 				// ---------------------------------------------
#
# 		buttons.draw();
#
#
#     }
# });
# </script>
#
# <div id="button_group_141_div_id" ></div>
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_142);
#
#     function doStuff_142() {
#
# 		var buttons = new joogle_globals.ButtonGroup({
# 			'container_id': "button_group_142_div_id",
# 			'add_clear': true,
# 			'clear_button_position': "last",
# 			'values': ["Sacramento", "Montpelier", "Juneau", "Montgomery", "Little Rock"],
# 			'type': "checkbox",
# 			'button_group_class': 'btn-group-vertical',
# 			'title': null,
# 			'clear_button_bold': false,
# 			'initial_values': ["Juneau"]
# 		});
#
# 		// -----------  add buttongroup sonar handlers ------------------
# 		(function(key, buttons, div_id) {
# 			var func = function(data) {
# 				if (data.sonar_key === key && document.getElementById(div_id) !== null) {
# 					buttons.update_button_group(data.sonar_value);
# 				}
# 			}
# 			joogle_globals.sonar.add_handler(func);
# 			joogle_globals.sonar.add_one_time_ready_poller(key, func, buttons);
# 		})("UCB", buttons, "button_group_142_div_id");
# 		// --------------------------------------------
# 		// --------- Add buttongroup sonar senders, if any ---------
# 		// add senders before before creating checkboxes
# 		// we have to delete any persisten values in the map when rerunning jupyter notebook cells
# 		delete joogle_globals.sonar.message_map["UCLA"];        google.visualization.events.addListener(buttons, 'select', function() {
#   			var selection = buttons.get_selected_values();
# 			joogle_globals.sonar.send('UCLA', selection);
# 		});
# 				// ---------------------------------------------
#
# 		buttons.draw();
#
#
#     }
# });
# </script>
#
# <div id="button_group_142_div_id" ></div>
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_143);
# });
#
#     function doStuff_143() {
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jooglechart_143_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"Sacramento"},{"v":97}]},{"c":[{"v":"Montpelier"},{"v":96}]},{"c":[{"v":"Juneau"},{"v":24}]},{"c":[{"v":"Montgomery"},{"v":26}]},{"c":[{"v":"Little Rock"},{"v":87}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"number","id":"Aaaaaaaaa","label":"Aaaaaaaaa"}]});
#
#         // Add formatters, if any
#
#         // Create ChartWrapper
#         var google_chart_144 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_144_div_id",
#             "dataTable": jooglechart_143_data,
#             "view": {columns: null},
#             "chartType": "ColumnChart",
#             "options": {

# %% [markdown]
# # 6. Meet the CheckboxGroup!

# %% [markdown]
# # CheckboxGroup

# %%
checks = CheckboxGroup(values = df.cities, orientation="horizontal", clear_button=True)
checks.add_sender(key="FBI")

checks2 = CheckboxGroup(values = df.cities, clear_button=True)
checks2.add_sender(key="FBI")

chart = JoogleChart(df)
chart.add_styler(get_styler())
chart.add_receiver(key="FBI", column=0)


box = Box(checks, chart)
row = ChartRow(box, checks2, mode='free', padding=20)
# row = ChartRow(checks, chart, checks2, mode="fixed", widths=[100, 550, 400])

row.show()
# Out:
# <div class="joogle_clearfix" id="joogle_chartrow_145" >
#     <div class="joogle_chartrow_column" >
#
# <div id="joogle_box_146" >
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_147);
# });
#
#     function doStuff_147() {
#
# 		var senders = [];
# 		var values = ['Sacramento', 'Montpelier', 'Juneau', 'Montgomery', 'Little Rock'];
# 		var id = "checkbox_group_147_div_id";
# 		var $main_div = $("#" + id);
# 		var add_clear = true;
#
#
#
# 		// --------- Add checkbox sonar senders, if any ---------
# 		// add senders before before creating checkboxes
# 		// we have to delete any persisten values in the map when rerunning jupyter notebook cells
# 		delete joogle_globals.sonar.message_map["FBI"];		senders.push(function() {
# 			var selected_values = get_selected_values();
# 			joogle_globals.sonar.send("FBI", selected_values);
# 		})
# 		// ------------------------------------------------------
# 		// define call_senders before call to create_checkboxes()
# 		function call_senders() {
# 			for (var i = 0; i < senders.length; i++) {
# 				senders[i]();
# 			}
# 		}
#
# 		function add_clear_button() {
# 			var $clear_all = $("<button>");
# 			$clear_all.addClass("btn btn-default btn-sm").html("clear all").click(function() {
# 				$main_div.find("input").prop('checked', false);
# 				call_senders();
# 			});
# 			var $div = $("<div>");
# 			$div.append($clear_all).prependTo($main_div);
# 		}
#
# 		function create_checkboxes() {
# 			//$main_div.addClass("checkbox");
# 			for (var i = 0; i < values.length; i++) {
# 				var value = values[i];
# 				var $div = $("<div>");
# 				$div.addClass("checkbox");
# 				var $label = $("<label>");
# 				var $input = $("<input>");
# 				$input.attr("type", "checkbox").attr("value", value).click(function(event) {
# 					call_senders();
# 				})
# 				$label.html(value).prepend($input).appendTo($div);
# 				$main_div.append($div);
# 			}
# 			if (add_clear) { add_clear_button(); }
#
# 			if (typeof initial_values != "undefined") {
# 				update_checkboxes(initial_values);
# 			}
# 		}
#
# 		create_checkboxes();
#
# 		function update_checkboxes(values) {
# 			// clear_buttons();
# 			$main_div.find("input").each(function(index, value) {
# 				input = this;
# 				var input_val = input.value;
# 				if ($.inArray(input_val, values) >= 0) {
# 					// $label.addClass("active");
# 					input.checked = true;
# 				}
# 				else {
# 					input.checked = false;
# 				}
# 			});
# 			call_senders();
# 		}
#
# 		function get_selected_values() {
# 			var selected_values = [];
# 			$main_div.find("input:checked").each(function(){
# 				selected_values.push(this.value);
# 			});
# 			return selected_values;
# 		}
#
# 		// --------- Add checkbox sonar receivers, if any ---------
# 		// ------------------------------------------------------
#
#
#
#     }
# </script>
#
# <style>
# #checkbox_group_147_div_id div {
# 	display: inline-block;
# }
# #checkbox_group_147_div_id input {
# 	margin-left: -15px;
# }
# #checkbox_group_147_div_id label {
# 	padding-right: 5px;
# }
# #checkbox_group_147_div_id button {
# 	margin-right: 5px;
# }
# </style>
#
# <div id="checkbox_group_147_div_id" ></div>
#
# <style>
#
#
# </style>
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_148);
# });
#
#     function doStuff_148() {
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jooglechart_148_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"Sacramento"},{"v":97}]},{"c":[{"v":"Montpelier"},{"v":96}]},{"c":[{"v":"Juneau"},{"v":24}]},{"c":[{"v":"Montgomery"},{"v":26}]},{"c":[{"v":"Little Rock"},{"v":87}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"number","id":"Aaaaaaaaa","label":"Aaaaaaaaa"}]});
#
#         // Add formatters, if any
#
#         // Create ChartWrapper
#         var google_chart_149 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_149_div_id",
#             "dataTable": jooglechart_148_data,
#             "view": {columns: null},
#             "chartType": "ColumnChart",
#             "options": {"fontName": "Helvetica Neue", "bar": {"groupWidth": 55}, "hAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "chartArea": {"width": 440, "top": 20, "height": 295, "left": 60}, "height": 375, "width": 500, "fontSize": 12, "vAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "titleTextStyle": {"fontSize": 16}, "legend": {"position": "top"}}
#         });
#
#         google_chart_149.draw();
#
# 		// -------------- Add chartwrapper senders, if any -------------
#
# 		// -------------------------------------------------------------
#
# 		// -------------- Add chartwrapper receivers, if any -------------
# 		(function(key, chart, datatable, chart_div_id, col, view_cols) {
# 			var func = function(data) {
# 				if (data.sonar_key === key && document.getElementById(chart_div_id) !== null) {
# 					joogle_globals.update_chart(data.sonar_value, datatable, chart, col, view_cols);
# 				}
# 			}
# 			joogle_globals.sonar.add_handler(func);
# 			joogle_globals.sonar.add_one_time_ready_poller(key, func, chart);
# 		})("FBI", google_chart_149, jooglechart_148_data, "google_chart_149_div_id", 0, null);
#
# 		// ---------------------------------------------------------------
#
#
#     }
#
# </script>
#
#
#
#
# <div id="google_chart_149_div_id" class="jooglechart_container jooglechart_type_ColumnChart" ></div>
#
#
# </div>
#
# <style>
# #joogle_box_146 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>
#
#
#
#
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_150);
# });
#
#     function doStuff_150() {
#
# 		var senders = [];
# 		var values = ['Sacramento', 'Montpelier', 'Juneau', 'Montgomery', 'Little Rock'];
# 		var id = "checkbox_group_150_div_id";
# 		var $main_div = $("#" + id);
# 		var add_clear = true;
#
#
#
# 		// --------- Add checkbox sonar senders, if any ---------
# 		// add senders before before creating checkboxes
# 		// we have to delete any persisten values in the map when rerunning jupyter notebook cells
# 		delete joogle_globals.sonar.message_map["FBI"];		senders.push(function() {
# 			var selected_values = get_selected_values();
# 			joogle_globals.sonar.send("FBI", selected_values);
# 		})
# 		// ------------------------------------------------------
# 		// define call_senders before call to create_checkboxes()
# 		function call_senders() {
# 			for (var i = 0; i < senders.length; i++) {
# 				senders[i]();
# 			}
# 		}
#
# 		function add_clear_button() {
# 			var $clear_all = $("<button>");
# 			$clear_all.addClass("btn btn-default btn-sm").html("clear all").click(function() {
# 				$main_div.find("input").prop('checked', false);
# 				call_senders();
# 			});
# 			var $div = $("<div>");
# 			$div.append($clear_all).prependTo($main_div);
# 		}
#
# 		function create_checkboxes() {
# 			//$main_div.addClass("checkbox");
# 			for (var i = 0; i < values.length; i++) {
# 				var value = values[i];
# 				var $div = $("<div>");
# 				$div.addClass("checkbox");
# 				var $label = $("<label>");
# 				var $input = $("<input>");
# 				$input.attr("type", "checkbox").attr("value", value).click(function(event) {
# 					call_senders();
# 				})
# 				$label.html(value).prepend($input).appendTo($div);
# 				$main_div.append($div);
# 			}
# 			if (add_clear) { add_clear_button(); }
#
# 			if (typeof initial_values != "undefined") {
# 				update_checkboxes(initial_values);
# 			}
# 		}
#
# 		create_checkboxes();
#
# 		function update_checkboxes(values) {
# 			// clear_buttons();
# 			$main_div.find("input").each(function(index, value) {
# 				input = this;
# 				var input_val = input.value;
# 				if ($.inArray(input_val, values) >= 0) {
# 					// $label.addClass("active");
# 					input.checked = true;
# 				}
# 				else {
# 					input.checked = false;
# 				}
# 			});
# 			call_senders();
# 		}
#
# 		function get_selected_values() {
# 			var selected_values = [];
# 			$main_div.find("input:checked").each(function(){
# 				selected_values.push(this.value);
# 			});
# 			return selected_values;
# 		}

# %% [markdown]
# # 7.  Button chop!

# %% [markdown]
# # Button

# %%
button1 = Button(text="Sactown", value="Sacramento")
button1.add_sender(key="KUT")

button2 = Button(text="Juneau what I'm talkin' 'bout", value="Juneau")
button2.add_sender(key="KUT")

button3 = Button(text="Clear all", value=[])
button3.add_sender(key="KUT")

chart = JoogleChart(df)
chart.add_styler(get_styler())
chart.add_receiver(key="KUT", column=0)

row = ChartRow(button1, button2, button3, padding = 10, mode="free")
box = Box(row, chart)

box.show()
# Out:
# <div id="joogle_box_151" >
#
# <div class="joogle_clearfix" id="joogle_chartrow_152" >
#     <div class="joogle_chartrow_column" >
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_153);
#
#     function doStuff_153() {
#
# 		var style = "button";
# 		var id = "joogle_button_153_div_id";
# 		var $div = $("#" + id);
# 		var $a;
# 		var text = "Sactown";
# 		var value = ['Sacramento'];
# 		var senders = [];
#
# 		function create_button() {
# 			$a = $("<a>");
# 			if (style == "button") {
# 				$a.addClass("btn btn-default");
# 			}
# 			$a.text(text).appendTo($div).click(function() {
# 				call_senders();
# 			});
# 		}
#
# 		function call_senders() {
# 			$.each(senders, function(index, value) { value() });
# 		}
#
# 		// -----------  add button sonar handlers ------------------
# 		// ---------------------------------------------------------
# 		// --------- Add button sonar senders, if any --------------
# 		// add senders before before creating checkboxes
# 		// we have to delete any persisten values in the map when rerunning jupyter notebook cells
# 		delete joogle_globals.sonar.message_map["KUT"];		senders.push(function() {
# 			joogle_globals.sonar.send("KUT", value);
# 		})
# 				// ---------------------------------------------------------
#
# 		create_button();
#
#
#     }
# });
# </script>
#
# <div id="joogle_button_153_div_id" ></div>
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_154);
#
#     function doStuff_154() {
#
# 		var style = "button";
# 		var id = "joogle_button_154_div_id";
# 		var $div = $("#" + id);
# 		var $a;
# 		var text = "Juneau what I'm talkin' 'bout";
# 		var value = ['Juneau'];
# 		var senders = [];
#
# 		function create_button() {
# 			$a = $("<a>");
# 			if (style == "button") {
# 				$a.addClass("btn btn-default");
# 			}
# 			$a.text(text).appendTo($div).click(function() {
# 				call_senders();
# 			});
# 		}
#
# 		function call_senders() {
# 			$.each(senders, function(index, value) { value() });
# 		}
#
# 		// -----------  add button sonar handlers ------------------
# 		// ---------------------------------------------------------
# 		// --------- Add button sonar senders, if any --------------
# 		// add senders before before creating checkboxes
# 		// we have to delete any persisten values in the map when rerunning jupyter notebook cells
# 		delete joogle_globals.sonar.message_map["KUT"];		senders.push(function() {
# 			joogle_globals.sonar.send("KUT", value);
# 		})
# 				// ---------------------------------------------------------
#
# 		create_button();
#
#
#     }
# });
# </script>
#
# <div id="joogle_button_154_div_id" ></div>
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_155);
#
#     function doStuff_155() {
#
# 		var style = "button";
# 		var id = "joogle_button_155_div_id";
# 		var $div = $("#" + id);
# 		var $a;
# 		var text = "Clear all";
# 		var value = [];
# 		var senders = [];
#
# 		function create_button() {
# 			$a = $("<a>");
# 			if (style == "button") {
# 				$a.addClass("btn btn-default");
# 			}
# 			$a.text(text).appendTo($div).click(function() {
# 				call_senders();
# 			});
# 		}
#
# 		function call_senders() {
# 			$.each(senders, function(index, value) { value() });
# 		}
#
# 		// -----------  add button sonar handlers ------------------
# 		// ---------------------------------------------------------
# 		// --------- Add button sonar senders, if any --------------
# 		// add senders before before creating checkboxes
# 		// we have to delete any persisten values in the map when rerunning jupyter notebook cells
# 		delete joogle_globals.sonar.message_map["KUT"];		senders.push(function() {
# 			joogle_globals.sonar.send("KUT", value);
# 		})
# 				// ---------------------------------------------------------
#
# 		create_button();
#
#
#     }
# });
# </script>
#
# <div id="joogle_button_155_div_id" ></div>
#     </div>
# </div>
#
#
# <style>
# .joogle_clearfix:after {
#     content:" ";
#     display:block;
#     clear:both;
# }
#
# #joogle_chartrow_152 > .joogle_chartrow_column {
# 	box-sizing: border-box;
# 	float: left;
# 	padding-left: 10px;
# 	padding-right: 10px;
# }
#
# </style>
#
#
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_156);
# });
#
#     function doStuff_156() {
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jooglechart_156_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"Sacramento"},{"v":97}]},{"c":[{"v":"Montpelier"},{"v":96}]},{"c":[{"v":"Juneau"},{"v":24}]},{"c":[{"v":"Montgomery"},{"v":26}]},{"c":[{"v":"Little Rock"},{"v":87}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"number","id":"Aaaaaaaaa","label":"Aaaaaaaaa"}]});
#
#         // Add formatters, if any
#
#         // Create ChartWrapper
#         var google_chart_157 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_157_div_id",
#             "dataTable": jooglechart_156_data,
#             "view": {columns: null},
#             "chartType": "ColumnChart",
#             "options": {"fontName": "Helvetica Neue", "bar": {"groupWidth": 55}, "hAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "chartArea": {"width": 440, "top": 20, "height": 295, "left": 60}, "height": 375, "width": 500, "fontSize": 12, "vAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "titleTextStyle": {"fontSize": 16}, "legend": {"position": "top"}}
#         });
#
#         google_chart_157.draw();
#
# 		// -------------- Add chartwrapper senders, if any -------------
#
# 		// -------------------------------------------------------------
#
# 		// -------------- Add chartwrapper receivers, if any -------------
# 		(function(key, chart, datatable, chart_div_id, col, view_cols) {
# 			var func = function(data) {
# 				if (data.sonar_key === key && document.getElementById(chart_div_id) !== null) {
# 					joogle_globals.update_chart(data.sonar_value, datatable, chart, col, view_cols);
# 				}
# 			}
# 			joogle_globals.sonar.add_handler(func);
# 			joogle_globals.sonar.add_one_time_ready_poller(key, func, chart);
# 		})("KUT", google_chart_157, jooglechart_156_data, "google_chart_157_div_id", 0, null);
#
# 		// ---------------------------------------------------------------
#
#
#     }
#
# </script>
#
#
#
#
# <div id="google_chart_157_div_id" class="jooglechart_container jooglechart_type_ColumnChart" ></div>
#
#
# </div>
#
# <style>
# #joogle_box_151 > div {
# 	display: default;
# 	vertical-align: default;
# }
# </style>

# %% [markdown]
# # 8. Just send me a TextReceiver!

# %% [markdown]
# # Text Receiver
# ### - requires joogle_include()
# ### - only receives messages, yo

# %%
pretext = "No selection yet"
template = "You have selected {}!"
default = "none selected"
tr = TextReceiver(pretext=pretext, template=template, default=default, key="KMFA")

buttons = ButtonGroup(df.cities, clear_button=True, orientation="vertical")
buttons.add_sender(key="KMFA")

chart = JoogleChart(df)
chart.add_styler(get_styler())
chart.add_receiver(key="KMFA", column=0)

# box = Box(tr, chart)

row = ChartRow(buttons, chart, tr, mode="free", padding=20)

row.show()
# Out:
# <div class="joogle_clearfix" id="joogle_chartrow_158" >
#     <div class="joogle_chartrow_column" >
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_159);
#
#     function doStuff_159() {
#
# 		var buttons = new joogle_globals.ButtonGroup({
# 			'container_id': "button_group_159_div_id",
# 			'add_clear': true,
# 			'clear_button_position': "first",
# 			'values': ["Sacramento", "Montpelier", "Juneau", "Montgomery", "Little Rock"],
# 			'type': "checkbox",
# 			'button_group_class': 'btn-group-vertical',
# 			'title': null,
# 			'clear_button_bold': false,
# 			'initial_values': null
# 		});
#
# 		// -----------  add buttongroup sonar handlers ------------------
# 		// --------------------------------------------
# 		// --------- Add buttongroup sonar senders, if any ---------
# 		// add senders before before creating checkboxes
# 		// we have to delete any persisten values in the map when rerunning jupyter notebook cells
# 		delete joogle_globals.sonar.message_map["KMFA"];        google.visualization.events.addListener(buttons, 'select', function() {
#   			var selection = buttons.get_selected_values();
# 			joogle_globals.sonar.send('KMFA', selection);
# 		});
# 				// ---------------------------------------------
#
# 		buttons.draw();
#
#
#     }
# });
# </script>
#
# <div id="button_group_159_div_id" ></div>
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_160);
# });
#
#     function doStuff_160() {
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jooglechart_160_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"Sacramento"},{"v":97}]},{"c":[{"v":"Montpelier"},{"v":96}]},{"c":[{"v":"Juneau"},{"v":24}]},{"c":[{"v":"Montgomery"},{"v":26}]},{"c":[{"v":"Little Rock"},{"v":87}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"number","id":"Aaaaaaaaa","label":"Aaaaaaaaa"}]});
#
#         // Add formatters, if any
#
#         // Create ChartWrapper
#         var google_chart_161 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_161_div_id",
#             "dataTable": jooglechart_160_data,
#             "view": {columns: null},
#             "chartType": "ColumnChart",
#             "options": {"fontName": "Helvetica Neue", "bar": {"groupWidth": 55}, "hAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "chartArea": {"width": 440, "top": 20, "height": 295, "left": 60}, "height": 375, "width": 500, "fontSize": 12, "vAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "titleTextStyle": {"fontSize": 16}, "legend": {"position": "top"}}
#         });
#
#         google_chart_161.draw();
#
# 		// -------------- Add chartwrapper senders, if any -------------
#
# 		// -------------------------------------------------------------
#
# 		// -------------- Add chartwrapper receivers, if any -------------
# 		(function(key, chart, datatable, chart_div_id, col, view_cols) {
# 			var func = function(data) {
# 				if (data.sonar_key === key && document.getElementById(chart_div_id) !== null) {
# 					joogle_globals.update_chart(data.sonar_value, datatable, chart, col, view_cols);
# 				}
# 			}
# 			joogle_globals.sonar.add_handler(func);
# 			joogle_globals.sonar.add_one_time_ready_poller(key, func, chart);
# 		})("KMFA", google_chart_161, jooglechart_160_data, "google_chart_161_div_id", 0, null);
#
# 		// ---------------------------------------------------------------
#
#
#     }
#
# </script>
#
#
#
#
# <div id="google_chart_161_div_id" class="jooglechart_container jooglechart_type_ColumnChart" ></div>
#
#
#     </div>
#     <div class="joogle_chartrow_column" >
# 		<span class="joogle_text_receiver" data-key="KMFA" data-liststyle="parens" data-template="You have selected {}!" data-default="none selected">No selection yet</span>
#     </div>
# </div>
#
#
# <style>
# .joogle_clearfix:after {
#     content:" ";
#     display:block;
#     clear:both;
# }
#
# #joogle_chartrow_158 > .joogle_chartrow_column {
# 	box-sizing: border-box;
# 	float: left;
# 	padding-left: 20px;
# 	padding-right: 20px;
# }
#
# </style>

# %% [markdown]
# # And now ...

# %% [markdown]
# # the grand finale ...

# %% [markdown]
# # behold ...

# %% [markdown]
# # the Legend!!!

# %%
df = get_df(cols=8)

chart = JoogleChart(df)
chart.add_styler(get_styler(legend_position="none"))
chart.add_receiver(key="CBS", action="filter_columns")
chart.add_receiver(key="NBC", action="focus_column")
chart.add_chart_options(isStacked=True)

series = chart.get_viewable_series()

checks = CheckboxGroup(values=series, clear_button=True, initial_values=series[3:4])
checks.add_sender(key="CBS")

legend = Legend(values=series)
legend.add_receiver(key="CBS")
legend.add_sender(key="NBC")

row = ChartRow(checks, chart, legend, mode="free", padding=20)

row.show()
# Out:
# <div class="joogle_clearfix" id="joogle_chartrow_162" >
#     <div class="joogle_chartrow_column" >
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_163);
# });
#
#     function doStuff_163() {
#
# 		var senders = [];
# 		var values = ['Aaaaaaaaa', 'Bbbbbbbbb', 'Ccccccccc', 'Ddddddddd', 'Eeeeeeeee', 'Fffffffff', 'Ggggggggg', 'Hhhhhhhhh'];
# 		var id = "checkbox_group_163_div_id";
# 		var $main_div = $("#" + id);
# 		var add_clear = true;
# 		var initial_values = ["Ddddddddd"];
#
#
#
# 		// --------- Add checkbox sonar senders, if any ---------
# 		// add senders before before creating checkboxes
# 		// we have to delete any persisten values in the map when rerunning jupyter notebook cells
# 		delete joogle_globals.sonar.message_map["CBS"];		senders.push(function() {
# 			var selected_values = get_selected_values();
# 			joogle_globals.sonar.send("CBS", selected_values);
# 		})
# 		// ------------------------------------------------------
# 		// define call_senders before call to create_checkboxes()
# 		function call_senders() {
# 			for (var i = 0; i < senders.length; i++) {
# 				senders[i]();
# 			}
# 		}
#
# 		function add_clear_button() {
# 			var $clear_all = $("<button>");
# 			$clear_all.addClass("btn btn-default btn-sm").html("clear all").click(function() {
# 				$main_div.find("input").prop('checked', false);
# 				call_senders();
# 			});
# 			var $div = $("<div>");
# 			$div.append($clear_all).prependTo($main_div);
# 		}
#
# 		function create_checkboxes() {
# 			//$main_div.addClass("checkbox");
# 			for (var i = 0; i < values.length; i++) {
# 				var value = values[i];
# 				var $div = $("<div>");
# 				$div.addClass("checkbox");
# 				var $label = $("<label>");
# 				var $input = $("<input>");
# 				$input.attr("type", "checkbox").attr("value", value).click(function(event) {
# 					call_senders();
# 				})
# 				$label.html(value).prepend($input).appendTo($div);
# 				$main_div.append($div);
# 			}
# 			if (add_clear) { add_clear_button(); }
#
# 			if (typeof initial_values != "undefined") {
# 				update_checkboxes(initial_values);
# 			}
# 		}
#
# 		create_checkboxes();
#
# 		function update_checkboxes(values) {
# 			// clear_buttons();
# 			$main_div.find("input").each(function(index, value) {
# 				input = this;
# 				var input_val = input.value;
# 				if ($.inArray(input_val, values) >= 0) {
# 					// $label.addClass("active");
# 					input.checked = true;
# 				}
# 				else {
# 					input.checked = false;
# 				}
# 			});
# 			call_senders();
# 		}
#
# 		function get_selected_values() {
# 			var selected_values = [];
# 			$main_div.find("input:checked").each(function(){
# 				selected_values.push(this.value);
# 			});
# 			return selected_values;
# 		}
#
# 		// --------- Add checkbox sonar receivers, if any ---------
# 		// ------------------------------------------------------
#
#
#
#     }
# </script>
#
#
# <div id="checkbox_group_163_div_id" ></div>
#
# <style>
#
#
# </style>
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_164);
# });
#
#     function doStuff_164() {
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jooglechart_164_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"Sacramento"},{"v":97},{"v":79},{"v":67},{"v":100},{"v":22},{"v":92},{"v":46},{"v":34}]},{"c":[{"v":"Montpelier"},{"v":96},{"v":74},{"v":32},{"v":96},{"v":22},{"v":62},{"v":31},{"v":92}]},{"c":[{"v":"Juneau"},{"v":24},{"v":44},{"v":54},{"v":64},{"v":57},{"v":65},{"v":61},{"v":84}]},{"c":[{"v":"Montgomery"},{"v":26},{"v":69},{"v":51},{"v":56},{"v":45},{"v":39},{"v":100},{"v":79}]},{"c":[{"v":"Little Rock"},{"v":87},{"v":69},{"v":78},{"v":41},{"v":50},{"v":21},{"v":74},{"v":93}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"number","id":"Aaaaaaaaa","label":"Aaaaaaaaa"},{"type":"number","id":"Bbbbbbbbb","label":"Bbbbbbbbb"},{"type":"number","id":"Ccccccccc","label":"Ccccccccc"},{"type":"number","id":"Ddddddddd","label":"Ddddddddd"},{"type":"number","id":"Eeeeeeeee","label":"Eeeeeeeee"},{"type":"number","id":"Fffffffff","label":"Fffffffff"},{"type":"number","id":"Ggggggggg","label":"Ggggggggg"},{"type":"number","id":"Hhhhhhhhh","label":"Hhhhhhhhh"}]});
#
#         // Add formatters, if any
#
#         // Create ChartWrapper
#         var google_chart_165 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_165_div_id",
#             "dataTable": jooglechart_164_data,
#             "view": {columns: null},
#             "chartType": "ColumnChart",
#             "options": {"isStacked": true, "bar": {"groupWidth": 55}, "hAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "chartArea": {"width": 440, "top": 10, "height": 305, "left": 60}, "fontName": "Helvetica Neue", "height": 375, "width": 500, "fontSize": 12, "vAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "titleTextStyle": {"fontSize": 16}, "legend": {"position": "none"}}
#         });
#
#         google_chart_165.draw();
#
# 		// -------------- Add chartwrapper senders, if any -------------
#
# 		// -------------------------------------------------------------
#
# 		// -------------- Add chartwrapper receivers, if any -------------
# 		// handler to filter columns
# 		(function(key, chart, datatable, chart_div_id, col, view_cols) {
# 			var series_cols = joogle_globals.get_viewable_columns(chart);
# 			function update_chart_callback(view, series) {
# 				chart.setDataTable(view);
# 				chart.setOption('series', series);
# 		        chart.draw();
# 			}
# 			var func = function(data) {
# 				if (data.sonar_key === key && document.getElementById(chart_div_id) !== null) {
# 					// joogle_globals.update_chart(data.sonar_value, datatable, chart, col, view_cols);
# 					window.joogle_globals.draw_chart_filtered_columns(datatable, series_cols, data.sonar_value, update_chart_callback);
# 				}
# 			}
# 			joogle_globals.sonar.add_handler(func);
# 			joogle_globals.sonar.add_one_time_ready_poller(key, func, chart);
# 		})("CBS", google_chart_165, jooglechart_164_data, "google_chart_165_div_id");
# 		(function(key, chart, chart_div_id, col) {
# 			// handler to focus chart series for a label name (from legend, say)
# 			// just using the click effect.  Don't know how to get mouseover effect.
# 			var label_index_map = joogle_globals.get_label_index_map(chart);
# 			var hold_column_label;
# 			var func = function(data) {
# 				if (data.sonar_key === key && document.getElementById(chart_div_id) !== null) {
# 					var column;
# 					// if the same label is repeated, unfocus
# 					if (hold_column_label === data.sonar_value[0]) {
# 						hold_column_label = null;
# 						column = null;
# 					}
# 					else {
# 						hold_column_label = data.sonar_value[0];
# 						column = label_index_map[data.sonar_value[0]];
# 					}
# 				    chart.getChart().setSelection([{column: column}]);
# 				    google.visualization.events.trigger(chart, 'select', {});
# 				}
# 			}
# 			joogle_globals.sonar.add_handler(func);
# 		})("NBC", google_chart_165, "google_chart_165_div_id");
#
# 		// ---------------------------------------------------------------
#
#
#     }
#
# </script>
#
#
#
#
# <div id="google_chart_165_div_id" class="jooglechart_container jooglechart_type_ColumnChart" ></div>
#
#
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_166);
#
#     function doStuff_166() {
#
# 		var legend = new joogle_globals.Legend({
# 			'series': ["Aaaaaaaaa", "Bbbbbbbbb", "Ccccccccc", "Ddddddddd", "Eeeeeeeee", "Fffffffff", "Ggggggggg", "Hhhhhhhhh"],
# 			'colors': ["#3366cc", "#dc3912", "#ff9900", "#109618", "#990099", "#0099c6", "#dd4477", "#66aa00", "#b82e2e", "#316395", "#994499", "#22aa99", "#aaaa11", "#6633cc", "#e67300", "#8b0707", "#651067", "#329262", "#5574a6", "#3b3eac", "#b77322", "#16d620", "#b91383", "#f4359e", "#9c5935", "#a9c413", "#2a778d", "#668d1c", "#bea413", "#0c5922", "#743411"],
# 			'div_id': "joogle_legend_16

# %% [markdown]
# # Legend: PieChart with key_style="circle"

# %%
chart = JoogleChart(df1, chart_type="PieChart")
chart.add_styler(get_styler(legend_position="none"))
chart.add_receiver(key="BBC", column=0)
# chart.add_receiver(key="AMC", action="focus_column")
chart.add_chart_options(isStacked=True)

series = chart.get_viewable_series()

checks = CheckboxGroup(values=df1.cities, clear_button=True, initial_values=df1.cities.tolist())
checks.add_sender(key="BBC")

legend = Legend(values=df1.cities.tolist(), key_style="circle")
legend.add_receiver(key="BBC")
legend.add_sender(key="AMC")

row = ChartRow(checks, chart, legend, mode="free", padding=20)

row.show()
# Out:
# <div class="joogle_clearfix" id="joogle_chartrow_167" >
#     <div class="joogle_chartrow_column" >
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_168);
# });
#
#     function doStuff_168() {
#
# 		var senders = [];
# 		var values = ['Sacramento', 'Montpelier', 'Juneau', 'Montgomery', 'Little Rock'];
# 		var id = "checkbox_group_168_div_id";
# 		var $main_div = $("#" + id);
# 		var add_clear = true;
# 		var initial_values = ["Sacramento", "Montpelier", "Juneau", "Montgomery", "Little Rock"];
#
#
#
# 		// --------- Add checkbox sonar senders, if any ---------
# 		// add senders before before creating checkboxes
# 		// we have to delete any persisten values in the map when rerunning jupyter notebook cells
# 		delete joogle_globals.sonar.message_map["BBC"];		senders.push(function() {
# 			var selected_values = get_selected_values();
# 			joogle_globals.sonar.send("BBC", selected_values);
# 		})
# 		// ------------------------------------------------------
# 		// define call_senders before call to create_checkboxes()
# 		function call_senders() {
# 			for (var i = 0; i < senders.length; i++) {
# 				senders[i]();
# 			}
# 		}
#
# 		function add_clear_button() {
# 			var $clear_all = $("<button>");
# 			$clear_all.addClass("btn btn-default btn-sm").html("clear all").click(function() {
# 				$main_div.find("input").prop('checked', false);
# 				call_senders();
# 			});
# 			var $div = $("<div>");
# 			$div.append($clear_all).prependTo($main_div);
# 		}
#
# 		function create_checkboxes() {
# 			//$main_div.addClass("checkbox");
# 			for (var i = 0; i < values.length; i++) {
# 				var value = values[i];
# 				var $div = $("<div>");
# 				$div.addClass("checkbox");
# 				var $label = $("<label>");
# 				var $input = $("<input>");
# 				$input.attr("type", "checkbox").attr("value", value).click(function(event) {
# 					call_senders();
# 				})
# 				$label.html(value).prepend($input).appendTo($div);
# 				$main_div.append($div);
# 			}
# 			if (add_clear) { add_clear_button(); }
#
# 			if (typeof initial_values != "undefined") {
# 				update_checkboxes(initial_values);
# 			}
# 		}
#
# 		create_checkboxes();
#
# 		function update_checkboxes(values) {
# 			// clear_buttons();
# 			$main_div.find("input").each(function(index, value) {
# 				input = this;
# 				var input_val = input.value;
# 				if ($.inArray(input_val, values) >= 0) {
# 					// $label.addClass("active");
# 					input.checked = true;
# 				}
# 				else {
# 					input.checked = false;
# 				}
# 			});
# 			call_senders();
# 		}
#
# 		function get_selected_values() {
# 			var selected_values = [];
# 			$main_div.find("input:checked").each(function(){
# 				selected_values.push(this.value);
# 			});
# 			return selected_values;
# 		}
#
# 		// --------- Add checkbox sonar receivers, if any ---------
# 		// ------------------------------------------------------
#
#
#
#     }
# </script>
#
#
# <div id="checkbox_group_168_div_id" ></div>
#
# <style>
#
#
# </style>
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_169);
# });
#
#     function doStuff_169() {
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jooglechart_169_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"Sacramento"},{"v":97}]},{"c":[{"v":"Montpelier"},{"v":96}]},{"c":[{"v":"Juneau"},{"v":24}]},{"c":[{"v":"Montgomery"},{"v":26}]},{"c":[{"v":"Little Rock"},{"v":87}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"number","id":"Aaaaaaaaa","label":"Aaaaaaaaa"}]});
#
#         // Add formatters, if any
#
#         // Create ChartWrapper
#         var google_chart_170 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_170_div_id",
#             "dataTable": jooglechart_169_data,
#             "view": {columns: null},
#             "chartType": "PieChart",
#             "options": {"isStacked": true, "hAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "chartArea": {"width": 500, "top": 10, "height": 325, "left": 0}, "fontName": "Helvetica Neue", "height": 375, "width": 500, "fontSize": 12, "vAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "titleTextStyle": {"fontSize": 16}, "legend": {"position": "none"}}
#         });
#
#         google_chart_170.draw();
#
# 		// -------------- Add chartwrapper senders, if any -------------
#
# 		// -------------------------------------------------------------
#
# 		// -------------- Add chartwrapper receivers, if any -------------
# 		(function(key, chart, datatable, chart_div_id, col, view_cols) {
# 			var func = function(data) {
# 				if (data.sonar_key === key && document.getElementById(chart_div_id) !== null) {
# 					joogle_globals.update_chart(data.sonar_value, datatable, chart, col, view_cols);
# 				}
# 			}
# 			joogle_globals.sonar.add_handler(func);
# 			joogle_globals.sonar.add_one_time_ready_poller(key, func, chart);
# 		})("BBC", google_chart_170, jooglechart_169_data, "google_chart_170_div_id", 0, null);
#
# 		// ---------------------------------------------------------------
#
#
#     }
#
# </script>
#
#
#
#
# <div id="google_chart_170_div_id" class="jooglechart_container jooglechart_type_PieChart" ></div>
#
#
#     </div>
#     <div class="joogle_chartrow_column" >
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_171);
#
#     function doStuff_171() {
#
# 		var legend = new joogle_globals.Legend({
# 			'series': ["Sacramento", "Montpelier", "Juneau", "Montgomery", "Little Rock"],
# 			'colors': ["#3366cc", "#dc3912", "#ff9900", "#109618", "#990099", "#0099c6", "#dd4477", "#66aa00", "#b82e2e", "#316395", "#994499", "#22aa99", "#aaaa11", "#6633cc", "#e67300", "#8b0707", "#651067", "#329262", "#5574a6", "#3b3eac", "#b77322", "#16d620", "#b91383", "#f4359e", "#9c5935", "#a9c413", "#2a778d", "#668d1c", "#bea413", "#0c5922", "#743411"],
# 			'div_id': "joogle_legend_171_div_id",
# 			'key_style': 'circle',
# 			'initial_values': null
#
# 		});
#
# 		// -----------  add legend sonar handlers ------------------
# 		(function(key, legend, div_id) {
# 			var func = function(data) {
# 				if (data.sonar_key === key && document.getElementById(div_id) !== null) {
# 					legend.update_legend(data.sonar_value);
# 				}
# 			}
# 			joogle_globals.sonar.add_handler(func);
# 			joogle_globals.sonar.add_one_time_ready_poller(key, func, legend);
# 		})("BBC", legend, "joogle_legend_171_div_id");
# 		// --------------------------------------------
# 		// --------- Add legend sonar senders, if any ---------
# 		// we have to delete any persisten values in the map when rerunning jupyter notebook cells
# 		delete joogle_globals.sonar.message_map["AMC"];        google.visualization.events.addListener(legend, 'select', function(message) {
# 			joogle_globals.sonar.send('AMC', message);
# 		});
# 		// ---------------------------------------------
#
# 		legend.draw();
#
#
#     }
# });
# </script>
#
# <div id="joogle_legend_171_div_id" ></div>
#
# <style>
#
# #joogle_legend_171_div_id li {
# 	margin-right:5px;
# }
#
# #joogle_legend_171_div_id ul {
# 	list-style-type: none;
# 	margin:0;
# 	padding:0;
# }
#
# </style>
#     </div>
# </div>
#
#
# <style>
# .joogle_clearfix:after {
#     content:" ";
#     display:block;
#     clear:both;
# }
#
# #joogle_chartrow_167 > .joogle_chartrow_column {
# 	box-sizing: border-box;
# 	float: left;
# 	padding-left: 20px;
# 	padding-right: 20px;
# }
#
# </style>

# %% [markdown]
# # Legend:  inline=False

# %%
df = get_df(cols=8)

chart = JoogleChart(df)
chart.add_styler(get_styler(legend_position="none"))
chart.add_receiver(key="ESPN", action="filter_columns")
chart.add_receiver(key="CNN", action="focus_column")
chart.add_chart_options(isStacked=True)

series = chart.get_viewable_series()

checks = CheckboxGroup(values=series, clear_button=True, initial_values=series[3:4])
checks.add_sender(key="ESPN")

legend = Legend(values=series, inline=True)
legend.add_receiver(key="ESPN")
legend.add_sender(key="CNN")

row = ChartRow(checks, chart, legend, mode="fixed", widths=[125, 520, 350])

row.show()
# Out:
# <div class="joogle_clearfix" id="joogle_chartrow_172" >
#     <div class="joogle_chartrow_column" style="width:125px">
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_173);
# });
#
#     function doStuff_173() {
#
# 		var senders = [];
# 		var values = ['Aaaaaaaaa', 'Bbbbbbbbb', 'Ccccccccc', 'Ddddddddd', 'Eeeeeeeee', 'Fffffffff', 'Ggggggggg', 'Hhhhhhhhh'];
# 		var id = "checkbox_group_173_div_id";
# 		var $main_div = $("#" + id);
# 		var add_clear = true;
# 		var initial_values = ["Ddddddddd"];
#
#
#
# 		// --------- Add checkbox sonar senders, if any ---------
# 		// add senders before before creating checkboxes
# 		// we have to delete any persisten values in the map when rerunning jupyter notebook cells
# 		delete joogle_globals.sonar.message_map["ESPN"];		senders.push(function() {
# 			var selected_values = get_selected_values();
# 			joogle_globals.sonar.send("ESPN", selected_values);
# 		})
# 		// ------------------------------------------------------
# 		// define call_senders before call to create_checkboxes()
# 		function call_senders() {
# 			for (var i = 0; i < senders.length; i++) {
# 				senders[i]();
# 			}
# 		}
#
# 		function add_clear_button() {
# 			var $clear_all = $("<button>");
# 			$clear_all.addClass("btn btn-default btn-sm").html("clear all").click(function() {
# 				$main_div.find("input").prop('checked', false);
# 				call_senders();
# 			});
# 			var $div = $("<div>");
# 			$div.append($clear_all).prependTo($main_div);
# 		}
#
# 		function create_checkboxes() {
# 			//$main_div.addClass("checkbox");
# 			for (var i = 0; i < values.length; i++) {
# 				var value = values[i];
# 				var $div = $("<div>");
# 				$div.addClass("checkbox");
# 				var $label = $("<label>");
# 				var $input = $("<input>");
# 				$input.attr("type", "checkbox").attr("value", value).click(function(event) {
# 					call_senders();
# 				})
# 				$label.html(value).prepend($input).appendTo($div);
# 				$main_div.append($div);
# 			}
# 			if (add_clear) { add_clear_button(); }
#
# 			if (typeof initial_values != "undefined") {
# 				update_checkboxes(initial_values);
# 			}
# 		}
#
# 		create_checkboxes();
#
# 		function update_checkboxes(values) {
# 			// clear_buttons();
# 			$main_div.find("input").each(function(index, value) {
# 				input = this;
# 				var input_val = input.value;
# 				if ($.inArray(input_val, values) >= 0) {
# 					// $label.addClass("active");
# 					input.checked = true;
# 				}
# 				else {
# 					input.checked = false;
# 				}
# 			});
# 			call_senders();
# 		}
#
# 		function get_selected_values() {
# 			var selected_values = [];
# 			$main_div.find("input:checked").each(function(){
# 				selected_values.push(this.value);
# 			});
# 			return selected_values;
# 		}
#
# 		// --------- Add checkbox sonar receivers, if any ---------
# 		// ------------------------------------------------------
#
#
#
#     }
# </script>
#
#
# <div id="checkbox_group_173_div_id" ></div>
#
# <style>
#
#
# </style>
#     </div>
#     <div class="joogle_chartrow_column" style="width:520px">
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_174);
# });
#
#     function doStuff_174() {
#         // Create DataTable object from DataTable constructor or arrayToDatable()
#         var jooglechart_174_data = new google.visualization.DataTable({"rows":[{"c":[{"v":"Sacramento"},{"v":97},{"v":79},{"v":67},{"v":100},{"v":22},{"v":92},{"v":46},{"v":34}]},{"c":[{"v":"Montpelier"},{"v":96},{"v":74},{"v":32},{"v":96},{"v":22},{"v":62},{"v":31},{"v":92}]},{"c":[{"v":"Juneau"},{"v":24},{"v":44},{"v":54},{"v":64},{"v":57},{"v":65},{"v":61},{"v":84}]},{"c":[{"v":"Montgomery"},{"v":26},{"v":69},{"v":51},{"v":56},{"v":45},{"v":39},{"v":100},{"v":79}]},{"c":[{"v":"Little Rock"},{"v":87},{"v":69},{"v":78},{"v":41},{"v":50},{"v":21},{"v":74},{"v":93}]}],"cols":[{"type":"string","id":"cities","label":"cities"},{"type":"number","id":"Aaaaaaaaa","label":"Aaaaaaaaa"},{"type":"number","id":"Bbbbbbbbb","label":"Bbbbbbbbb"},{"type":"number","id":"Ccccccccc","label":"Ccccccccc"},{"type":"number","id":"Ddddddddd","label":"Ddddddddd"},{"type":"number","id":"Eeeeeeeee","label":"Eeeeeeeee"},{"type":"number","id":"Fffffffff","label":"Fffffffff"},{"type":"number","id":"Ggggggggg","label":"Ggggggggg"},{"type":"number","id":"Hhhhhhhhh","label":"Hhhhhhhhh"}]});
#
#         // Add formatters, if any
#
#         // Create ChartWrapper
#         var google_chart_175 = new google.visualization.ChartWrapper({
#             "containerId": "google_chart_175_div_id",
#             "dataTable": jooglechart_174_data,
#             "view": {columns: null},
#             "chartType": "ColumnChart",
#             "options": {"isStacked": true, "bar": {"groupWidth": 55}, "hAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "chartArea": {"width": 440, "top": 10, "height": 305, "left": 60}, "fontName": "Helvetica Neue", "height": 375, "width": 500, "fontSize": 12, "vAxis": {"titleTextStyle": {"bold": true, "italic": false}}, "titleTextStyle": {"fontSize": 16}, "legend": {"position": "none"}}
#         });
#
#         google_chart_175.draw();
#
# 		// -------------- Add chartwrapper senders, if any -------------
#
# 		// -------------------------------------------------------------
#
# 		// -------------- Add chartwrapper receivers, if any -------------
# 		// handler to filter columns
# 		(function(key, chart, datatable, chart_div_id, col, view_cols) {
# 			var series_cols = joogle_globals.get_viewable_columns(chart);
# 			function update_chart_callback(view, series) {
# 				chart.setDataTable(view);
# 				chart.setOption('series', series);
# 		        chart.draw();
# 			}
# 			var func = function(data) {
# 				if (data.sonar_key === key && document.getElementById(chart_div_id) !== null) {
# 					// joogle_globals.update_chart(data.sonar_value, datatable, chart, col, view_cols);
# 					window.joogle_globals.draw_chart_filtered_columns(datatable, series_cols, data.sonar_value, update_chart_callback);
# 				}
# 			}
# 			joogle_globals.sonar.add_handler(func);
# 			joogle_globals.sonar.add_one_time_ready_poller(key, func, chart);
# 		})("ESPN", google_chart_175, jooglechart_174_data, "google_chart_175_div_id");
# 		(function(key, chart, chart_div_id, col) {
# 			// handler to focus chart series for a label name (from legend, say)
# 			// just using the click effect.  Don't know how to get mouseover effect.
# 			var label_index_map = joogle_globals.get_label_index_map(chart);
# 			var hold_column_label;
# 			var func = function(data) {
# 				if (data.sonar_key === key && document.getElementById(chart_div_id) !== null) {
# 					var column;
# 					// if the same label is repeated, unfocus
# 					if (hold_column_label === data.sonar_value[0]) {
# 						hold_column_label = null;
# 						column = null;
# 					}
# 					else {
# 						hold_column_label = data.sonar_value[0];
# 						column = label_index_map[data.sonar_value[0]];
# 					}
# 				    chart.getChart().setSelection([{column: column}]);
# 				    google.visualization.events.trigger(chart, 'select', {});
# 				}
# 			}
# 			joogle_globals.sonar.add_handler(func);
# 		})("CNN", google_chart_175, "google_chart_175_div_id");
#
# 		// ---------------------------------------------------------------
#
#
#     }
#
# </script>
#
#
#
#
# <div id="google_chart_175_div_id" class="jooglechart_container jooglechart_type_ColumnChart" ></div>
#
#
#     </div>
#     <div class="joogle_chartrow_column" style="width:350px">
#
# <script type="text/javascript">
#
# $(document).ready(function() {
#
#
# 	joogle_globals.call_jooglechart_callback(doStuff_176);
#
#     function doStuff_176() {
#
# 		var legend = new joogle_globals.Legend({
# 			'series': ["Aaaaaaaaa", "Bbbbbbbbb", "Ccccccccc", "Ddddddddd", "Eeeeeeeee", "Fffffffff", "Ggggggggg", "Hhhhhhhhh"],
# 			'colors': ["#3366cc", "#dc3912", "#ff9900", "#109618", "#990099", "#0099c6", "#dd4477", "#66aa00", "#b82e2e", "#316395", "#994499", "#22aa99", "#aaaa11", "#6633cc", "#e67300", "#8b0707", "#651067", "#329262", "#5574a6", "#3b3eac", "#b77322", "#16d620", "#b91383", "#f4359e", "#9c5935", "#a9c413", "#2a778d", "#668d1c", "#be
